# %%
import sys
import pathlib
import pickle
from pathlib import Path
sys.path.append(f"{Path.home()}/morpho_repo")
sys.path.append(f"{Path.home()}/morpho_repo/pytorch")
from intro import Struct

# %%
def estimation_simulation(args):
    import numpy as np
    import matplotlib.pyplot as plt
    from scipy import ndimage
    import sys
    import argparse
    import pathlib
    import pickle
    from pathlib import Path
    sys.path.append(f"{Path.home()}/morpho_repo")
    sys.path.append(f"{Path.home()}/morpho_repo/pytorch")
    import torch
    import torch.nn as nn
    from pinns import Net_dense_normalised, Laplacian
    #from local_utils import *
    from intro import create_to, Struct, grad_diff
    
    printer = Printer()
    ######################################
    printer("~"*45)
    printer(f"      start running model '{args.run_name}'.")
    printer("~"*45)
    ######################################
    device = torch.device(f"cuda:{args.device_id}" if torch.cuda.is_available() else "cpu")
    dev_str = f"{device.type}:{device.index}"
    printer(f"The selected device is {dev_str}")
    ######################################
    with open(args.input, "rb") as f:
        (run_params, params, solution) = pickle.load(f)

    run_params = Struct(**run_params)
    params = Struct(**params)
    #####################################
    A_n = solution[1, 0, :, :]
    B_n = solution[1, 1, :, :]
    C_n = solution[1, 2, :, :]
    #############################################################
    #    Inner boundaries
    # By using these slices, we can remove the boundary effects
    # or select a smaller portion of the domain
    #
    #   Important: slices must not be larger than slices(1,-1,1).
    #              Otherwise, the boundary effects of finit difference
    #              Laplacian cannot be removed
    #
    x_slice = slice(1,-1, 1)
    y_slice = slice(1,-1, 1)

    to = create_to(A_n[x_slice,y_slice])
    ########################################
    # Take the average of data points
    kernel =np.array([[1, 1],
                      [1, 1]])
    A_n = ndimage.convolve(A_n, kernel)/4
    B_n = ndimage.convolve(B_n, kernel)/4
    C_n = ndimage.convolve(C_n, kernel)/4
    ######################################
    # Add noise to averaged mesh
    if args.noise_level > 0:
        ampA = np.max(A_n) - np.min(A_n)
        ampB = np.max(B_n) - np.min(B_n)
        ampC = np.max(C_n) - np.min(C_n)
        printer(f"noise level:{args.noise_level}, A amplitude:{ampA}, B amplitude:{ampB}, C amplitude:{ampC},")
        printer(f"A noise std:{ampA*args.noise_level}, B noise std:{ampB*args.noise_level}, C noise std:{ampC*args.noise_level}.")
        np.random.seed(42)
        A_n += np.random.normal(0,ampA*args.noise_level ,A_n.shape)
        B_n += np.random.normal(0,ampB*args.noise_level ,B_n.shape)
        C_n += np.random.normal(0,ampC*args.noise_level ,C_n.shape)
    #######################################
    torch.manual_seed(42)
    np.random.seed(42)
    ###########################################################
    # Inputs
    # restrict to inner boundaries
    x = torch.linspace(0, run_params.Lx, run_params.Ix)[x_slice].to(device)
    y = torch.linspace(0, run_params.Ly, run_params.Jy)[y_slice].to(device)
    X,Y = torch.meshgrid(x, y, indexing='ij')
    data_X = torch.vstack([X.flatten(), Y.flatten()]).T.requires_grad_(True).to(device)
    ##########################################################
    #   Data
    # restrict to inner boundaries
    data_A = torch.from_numpy(A_n[x_slice,y_slice].flatten()).to(device)
    data_B = torch.from_numpy(B_n[x_slice,y_slice].flatten()).to(device)
    data_C = torch.from_numpy(C_n[x_slice,y_slice].flatten()).to(device)
    ###########################################################
    # LoG diffusion instead of Laplacians
    # First, find the Laplacian of the Gaussian on the whole domain,
    # then, select the inner boundaries. This way, the boundaries 
    # effets removed
    diffusion_scale_factor = (run_params.Ix*run_params.Jy/(run_params.Lx*run_params.Ly))
#     laplacianA = diffusion_scale_factor * ndimage.gaussian_laplace(A_n, sigma=args.LoG_sigma)
#     laplacianB = diffusion_scale_factor * ndimage.gaussian_laplace(B_n, sigma=args.LoG_sigma)
    laplacianA = diffusion_scale_factor * grad_diff(A_n)
    laplacianB = diffusion_scale_factor * grad_diff(B_n)

    laplacianA = torch.tensor(laplacianA[x_slice,y_slice].flatten()).to(device)
    laplacianB = torch.tensor(laplacianB[x_slice,y_slice].flatten()).to(device)
    ###########################################################
    # Model
    lb = torch.tensor([torch.min(x).item(), torch.min(y).item()]).to(device)
    ub = torch.tensor([torch.max(x).item(), torch.max(y).item()]).to(device)
    model = Net_dense_normalised([2, 64, 64, 3], lb, ub).to(device)
    ###########################################################
    # optimizer
    optimizer = torch.optim.LBFGS([*model.parameters()], lr=1
                                 ,line_search_fn='strong_wolfe')#.Adam([*model.parameters()], lr=1e-3)#
    ###########################################################
    # Train/Validation splits
    #
    split_ratio = args.train_split_ratio
    # Data
    max_index = data_X.shape[0]
    All_indices = torch.randperm(max_index)
    train_last_index = int(split_ratio*max_index)
    train_indices = All_indices[:train_last_index]
    validation_indices = All_indices[train_last_index:]


    data_X_train = data_X[train_indices,:]
    data_X_validation = data_X[validation_indices,:]
    data_A_train = data_A[train_indices]
    data_A_validation = data_A[validation_indices]
    data_B_train = data_B[train_indices]
    data_B_validation = data_B[validation_indices]
    data_C_train = data_C[train_indices]
    data_C_validation = data_C[validation_indices]

    # Laplacian
    max_Laplacian_index = laplacianA.shape[0]
    All_Laplacian_indices = torch.randperm(max_Laplacian_index)
    laplacian_last_index = int(split_ratio*max_Laplacian_index)
    train_Laplacian_indices = All_Laplacian_indices[:laplacian_last_index]
    validation_Laplacian_indices = All_Laplacian_indices[laplacian_last_index:]

    laplacianA_train = laplacianA[train_Laplacian_indices].to(device)
    laplacianA_validation = laplacianA[validation_Laplacian_indices].to(device)
    laplacianB_train = laplacianB[train_Laplacian_indices].to(device)
    laplacianB_validation = laplacianB[validation_Laplacian_indices].to(device)


    epochs = args.epochs#3000
    loss_data = 0.0
    lambda_data = 1.0
    loss_physics = 0.0
    lambda_physics_laplacian = 1e-2

    losses = np.zeros((5, epochs))
    validations = np.zeros(epochs)

    def act(x, km, n=2):
        return x**n / (x**n + km**n)

    def inh(x, km, n=2):
        return  km**n / (x**n + km**n)

    def moving_average(x, w):
        return np.convolve(x, np.ones(w), 'valid') / w

    for i in range(epochs):    
        def find_data_losses(data_X_input, data_A, data_B, data_C):
            #################################
            # data loss       
            data_f_hat = model(data_X_input).squeeze() 
            data_A_hat = data_f_hat[:,0]
            data_B_hat = data_f_hat[:,1]
            data_C_hat = data_f_hat[:,2]
            loss_A_data = torch.mean((data_A - data_A_hat)**2)
            loss_B_data = torch.mean((data_B - data_B_hat)**2)
            loss_C_data = torch.mean((data_C - data_C_hat)**2)
            return (loss_A_data,loss_B_data,loss_C_data)

        def find_Laplacian_losses(data_X_input, laplacianA, laplacianB,
                                  laplacian_indices):
            #################################
            # physics derivatives
            #        
            physics_f = model(data_X_input).squeeze()         
            A_hat = physics_f[:,0]
            B_hat = physics_f[:,1]        
            # Note: The Laplacian is taken first on all points
            #       and then are selected for the given index
            #       The reason to do it this way is becuase of
            #       The laplacian bounderies effect that we need to remove
            laplacianA_hat = Laplacian(A_hat, data_X_input)
            laplacianB_hat = Laplacian(B_hat, data_X_input)

            laplacianA_hat = laplacianA_hat[laplacian_indices]
            laplacianB_hat = laplacianB_hat[laplacian_indices]

            A_loss_laplacian = torch.mean((laplacianA_hat-laplacianA)**2)
            B_loss_laplacian = torch.mean((laplacianB_hat-laplacianB)**2)                 
            ###############################
            return (A_loss_laplacian, B_loss_laplacian)

        # L-BFGS
        def closure():

            optimizer.zero_grad()
            (loss_A_data,loss_B_data,loss_C_data
            ) = find_data_losses(data_X_train,data_A_train,data_B_train,data_C_train)

            (A_loss_laplacian, B_loss_laplacian
            ) = find_Laplacian_losses(data_X, laplacianA_train,laplacianB_train,
                                      train_Laplacian_indices)

            loss_data = (loss_A_data + loss_B_data + loss_C_data)/3
            loss_laplacian_physics = A_loss_laplacian + B_loss_laplacian
            total_loss = (
                +lambda_data*loss_data            
                +lambda_physics_laplacian*loss_laplacian_physics
                            )

            total_loss.backward(retain_graph=True)


            losses[:,i] = (loss_A_data.item(), loss_B_data.item(), loss_C_data.item(), 
                           A_loss_laplacian.item(), B_loss_laplacian.item())                    

            return total_loss



        optimizer.step(closure)


        (validation_A_data,validation_B_data,validation_C_data,
         ) = find_data_losses(data_X_validation, 
                              data_A_validation,data_B_validation,data_C_validation)

        (A_validation_laplacian, B_validation_laplacian
        ) = find_Laplacian_losses(data_X, laplacianA_validation, laplacianB_validation,
                                  validation_Laplacian_indices)

        validation_loss = (validation_A_data+validation_B_data+validation_C_data+
                           A_validation_laplacian+B_validation_laplacian).item()
        validations[i] = validation_loss

        # Early stop
#         w = args.early_stop_window
#         if i > w:
#             if validations[i] > moving_average(validations[:i], w)[-1]:
#                 printer(f"Earlt stop at epoch:{i+1}.\n"
#                       f" Validation:{validations[i]}, averged validation:{moving_average(validations[:i], w)[-1]}")
#                 break    

        if (i+1)%200 == 0 or i==0 :
            printer("============================================")
            printer(f"Epoch: {i+1} \n data loss:{np.sum(losses[0:3,i]):.6f}, \n"
                  f"data A loss:{losses[0,i]:.6f}, data B loss:{losses[1,i]:.6f}, data C loss:{losses[2,i]:.6f}, \n"
                  f"Laplacian A loss:{losses[3,i]:.6f}, Laplacian B loss:{losses[4,i]:.6f}\n"
                  f"\n"
                  f"Validation loss:{validation_loss:.6f}"
                 )
    #######################################
    # Check the trained model
    printer("~"*45)
    printer(f"      Check the trained model '{args.run_name}' outputs.")
    printer("~"*45)
    physics_f = model(data_X).squeeze()
    A_hat = physics_f[:,0]
    B_hat = physics_f[:,1]
    C_hat = physics_f[:,2]

    laplacianA_hat = Laplacian(A_hat, data_X)
    laplacianB_hat = Laplacian(B_hat, data_X)

    A_hat = to(A_hat.cpu().detach().numpy())
    B_hat = to(B_hat.cpu().detach().numpy())
    C_hat = to(C_hat.cpu().detach().numpy())
    laplacianA_hat = to(laplacianA_hat.cpu().detach().numpy())
    laplacianB_hat = to(laplacianB_hat.cpu().detach().numpy())


    laplacianA = diffusion_scale_factor * grad_diff(A_n)[x_slice,y_slice]
    laplacianB = diffusion_scale_factor * grad_diff(B_n)[x_slice,y_slice]

    n = params["n"]

    A_n = A_n[x_slice,y_slice]
    B_n = B_n[x_slice,y_slice]
    C_n = C_n[x_slice,y_slice]

    F_A =  params["b_A"] + params["V_A"]*act(A_n, params["K_AA"], n)*inh(B_n, params["K_BA"], n) - params["mu_A"] * A_n
    F_A_hat =  params["b_A"] + params["V_A"]*act(A_hat, params["K_AA"], n)*inh(B_hat, params["K_BA"], n) - params["mu_A"] * A_hat
    F_B =  params["b_B"] + params["V_B"]*act(A_n, params["K_AB"], n)*inh(C_n, params["K_CB"], n) - params["mu_B"] * B_n
    F_B_hat =  params["b_B"] + params["V_B"]*act(A_hat, params["K_AB"], n)*inh(C_hat, params["K_CB"], n) - params["mu_B"] * B_hat
    F_C =  params["b_C"] + params["V_C"]*inh(A_n, params["K_AC"], n)*inh(B_n, params["K_BC"], n)*act(C_n, params["K_CC"], n) - params["mu_C"] * C_n
    F_C_hat =  params["b_C"] + params["V_C"]*inh(A_hat, params["K_AC"], n)*inh(B_hat, params["K_BC"], n)*act(C_hat, params["K_CC"], n) - params["mu_C"] * C_hat


    dAdt = params["D_A"]*laplacianA + F_A
    dAdt_hat = params["D_A"]*laplacianA_hat + F_A_hat
    dBdt = params["D_B"]*laplacianB + F_B
    dBdt_hat = params["D_B"]*laplacianB_hat + F_B_hat

    printer(f"A diff:{np.mean((A_hat-A_n)**2)}",
          f"B diff:{np.mean((B_hat-B_n)**2)}",
          f"C diff:{np.mean((C_hat-C_n)**2)}")

    printer(f"F_A actual:{np.mean(F_A**2)}, F_A:{np.mean(F_A_hat**2)}, RMSE: {np.sqrt(np.mean((F_A - F_A_hat)**2))}")
    printer(f"F_B actual:{np.mean(F_B**2)}, F_B:{np.mean(F_B_hat**2)}, RMSE: {np.sqrt(np.mean((F_B - F_B_hat)**2))}")
    printer(f"F_C actual:{np.mean(F_C**2)}, F_C:{np.mean(F_C_hat**2)}, RMSE: {np.sqrt(np.mean((F_C - F_C_hat)**2))}")


    printer()
    printer(f"Laplacian A RMSE: {np.sqrt(np.mean((laplacianA_hat-laplacianA)**2))}")
    printer(f"Laplacian B RMSE: {np.sqrt(np.mean((laplacianB_hat-laplacianB)**2))}")

    printer()
    printer(f"dAdt RMSE: {np.sqrt(np.mean((dAdt-dAdt_hat)**2))}")
    printer(f"dBdt RMSE: {np.sqrt(np.mean((dBdt-dBdt_hat)**2))}")
    printer(f"dCdt RMSE: {np.sqrt(np.mean((F_C-F_C_hat)**2))}")
    ############################################################
    # Find the parameters
    def create_var(init=None):        
        if init is None:
            return torch.nn.Parameter(torch.ones(1, requires_grad=True, device=dev_str))
        else:
            return torch.nn.Parameter(init*torch.ones(1, requires_grad=True, device=dev_str))


    D_A=params["D_A"]
    D_B=params["D_B"]
    b_A = create_var()
    b_B = create_var()
    b_C = create_var()
    V_A = create_var()
    V_B = create_var()
    V_C = create_var()
    mu_A = create_var()
    mu_B = create_var()
    mu_C=params["D_A"]
    K_AA = create_var()
    K_AB = create_var()
    K_AC = create_var()
    K_BA = create_var()
    K_BC = create_var()
    K_CB = create_var()
    K_CC = create_var()
    n = params['n']

    params_name_list = [#"D_A", "D_B", 
                        "b_A", "b_B", "b_C", "V_A", "V_B", "V_C", "mu_A", "mu_B", #"mu_C",
                        "K_AA", "K_AB", "K_AC", "K_BA", "K_BC", "K_CB", 
                        "K_CC"
    ]

    params_list = [#D_A, D_B, 
                   b_A, b_B, b_C, V_A, V_B, V_C, mu_A, mu_B, #mu_C,
                   K_AA, K_AB, K_AC, K_BA, K_BC, K_CB, 
                   K_CC
    ]
    def physics_loss():            
        physics_f = model(data_X).squeeze()
        A_hat = physics_f[:,0]
        B_hat = physics_f[:,1]
        C_hat = physics_f[:,2]

        laplacianA_hat = Laplacian(A_hat, data_X)
        laplacianB_hat = Laplacian(B_hat, data_X)    
        # To make sure the parameters stay positive, we use the exponential function    
        e = torch.exp
        F_A_hat =  e(b_A) + e(V_A)*act(A_hat, e(K_AA), n)*inh(B_hat, e(K_BA), n) - e(mu_A) * A_hat
        #f_A =  e(b_A)/(e(D_A)+1e-6) + e(V_A)*act(A, e(K_AA), n)*inh(B, e(K_BA), n)/(e(D_A)+1e-6) - e(mu_A)*A/(e(D_A)+1e-6)
        F_B_hat =  e(b_B) + e(V_B)*act(A_hat, e(K_AB), n)*inh(C_hat, e(K_CB), n) - e(mu_B) * B_hat
        #f_B =  e(b_B)/(e(D_B)+1e-6) + e(V_B)*act(A, e(K_AB), n)*inh(C, e(K_CB), n)/(e(D_B)+1e-6) - e(mu_B)*B/(e(D_B)+1e-6)
        F_C_hat =  e(b_C) + e(V_C)*inh(A_hat, e(K_AC), n)*inh(B_hat, e(K_BC), n)*act(C_hat, e(K_CC), n) - mu_C * C_hat


        #dAdt = e(D_A) * laplacianA + F_A
        dAdt = D_A * laplacianA_hat + F_A_hat
        #dAdt2 = laplacianA + f_A
        #dBdt = e(D_B) * laplacianB + F_B
        dBdt = D_B * laplacianB_hat + F_B_hat
        #dBdt2 = laplacianB + f_B
        dCdt = F_C_hat
        ################################
        # physics loss
        # Construct the physics loss here
        A_loss_physics = torch.mean(dAdt**2)
        #A2_loss_physics = torch.mean(dAdt2**2)
        B_loss_physics = torch.mean(dBdt**2)
        #B2_loss_physics = torch.mean(dBdt2**2)
        C_loss_physics = torch.mean(dCdt**2)
        return (A_loss_physics + B_loss_physics + C_loss_physics)


    optimizer2 = torch.optim.LBFGS(params_list,
                                   lr=.5,
                                   history_size=10, 
                                   max_iter=20, 
                                   line_search_fn="strong_wolfe")

    # L-BFGS
    def closure():
        if torch.is_grad_enabled():
            optimizer2.zero_grad()
        loss = physics_loss()
        if loss.requires_grad:
            loss.backward()
        return loss
    
    printer("~"*50)
    printer(f"      Estimates the parameters of the model '{args.run_name}'.")
    printer("~"*50)
    history_lbfgs = []
    stored_parameters = np.zeros(len(params_list))
    for i in range(20):
        history_lbfgs.append(physics_loss().item())
        if np.all([not np.isnan(p.item()) for p in params_list]):
            stored_parameters = [np.exp(p.item()) for p in params_list]
        else:
            printer("Nan -- (maybe large learning rate)")
            break

        if i%1 ==0:
            printer(history_lbfgs[-1],", ".join([f"{name}={np.exp(l.item()):.4f}" 
                     for l, name in zip(params_list, params_name_list)]))
            printer()
        optimizer2.step(closure)
    ########################################
    estimated_params = dict()
    for l, name in zip(params_list, params_name_list):    
        estimated_params[name] = np.exp(l.item())
    
    
    printer("name \t Originl \t Estimated \t Difference")
    printer("-------------------------------------------------------------------------------------------------------------")
    printer("\n".join([ f"{name}:\t{params[name]:.3f}\t\t"
                      f"{estimated_params[name]:.3f}\t\t"
                     f"{np.abs(params[name]-estimated_params[name]):.3f}"
          for name in params_name_list
    ]))
    #######################################
    printer("~"*45)
    printer(f"      Save the results at '{args.output}'.")
    printer("~"*45)
    torch.save(model.state_dict(), f"{args.output}/model_{args.run_name}")
    with open(f"{args.output}/model_{args.run_name}_params_name_list.npy", 'wb') as f:
        np.save(f, params_name_list)    
    with open(f"{args.output}/model_{args.run_name}_losses.npy", 'wb') as f:
        np.save(f, losses)    
    with open(f"{args.output}/model_{args.run_name}_estimated_params.pkl", "wb") as f:
        pickle.dump((dict(params), dict(estimated_params)), f) 
    printer("~"*45)
    printer(f"      End of the model '{args.output}'.")
    printer("~"*45)
    
    return printer

# %%
class Printer:
    def __init__(self):
        self.buffer = ""
    def __call__(self, *values):
        for v in values:
            self.buffer += str(v)
        self.buffer += "\n"
    def get(self):
        return self.buffer

def defaults(args):
    args = Struct(**args)
    def condition(name):
        return not hasattr(args, name) or getattr(args, name) is None
    if condition('device_id'):
        args.device_id = 0        
    if condition('input'):
        args.input = './outputs/solution_1.pkl'
    if condition('epochs'):
        args.epochs = 5000
    if condition('noise_level'):
        args.noise_level = 0.0
    if condition('train_split_ratio'):
        args.train_split_ratio = (128*128-10)/(128*128)#15/16
    if condition('LoG_sigma'):
        args.LoG_sigma = 0.9
    if condition('early_stop_window'):
        args.early_stop_window = 50
    if condition('output'):
        args.output = './outputs'
    return args

# %%
((128*128-10)/(128*128)), int(((128*128-10)/(128*128))*128*128),128*128
# Out:
# (0.9993896484375, 16374, 16384)

# %%
identifiables_good_stationary_good_non_stationary = [    
    ('./inputs/solution_31.pkl','spot/dot/in-phase'),#tiny
]
identifiables_good_stationary_bad_non_stationary = [
    ('./inputs/solution_3.pkl','labyrinth-spots/in-phase'),
    ('./inputs/solution_8.pkl','odd'), # very odd
    ('./inputs/solution_9.pkl','spot-line/in-phase'),
    ('./inputs/solution_14.pkl','spot/in-phase'),
    ('./inputs/solution_25.pkl','spot/leopard/in-phase'),
#     ('./inputs/solution_50.pkl','spot/leopard/in-phase'),
#     ('./inputs/solution_84.pkl','spot/leopard/in-phase'),
]
identifiables_bad_stationary = [
    ('./inputs/solution_24.pkl','labyrinth/in-phase'),
#     ('./inputs/solution_48.pkl','labyrinth/in-phase'),
    ('./inputs/solution_56.pkl','oscilate'),
    ('./inputs/solution_60.pkl','spot-line/in-phase'),# odd C field
    ('./inputs/solution_78.pkl','spot-line/in-phase'),
#     ('./inputs/solution_82.pkl','spot-line/in-phase'),
]

# %%
from itertools import chain
run_parameters = [file  for (file, _) in chain(identifiables_good_stationary_good_non_stationary,
                                         identifiables_good_stationary_bad_non_stationary,
                                         identifiables_bad_stationary) ]
def create_args(f, i): 
    args = defaults({});
    args.input = f;
    args.run_name = f.split("/")[-1].split(".pkl")[0]
    args.device_id = i%3
    args.output = "./outputs_zero_noise_identifiable"
    return args
run_parameters = [create_args(f,i)  for i,f in enumerate(run_parameters)]

# %%
from multiprocessing import Pool

with Pool(12)as pool:
    results = pool.map(estimation_simulation, run_parameters)
# Out:
# /tmp/ipykernel_29406/3341459398.py:411: RuntimeWarning: overflow encountered in exp
#   stored_parameters = [np.exp(p.item()) for p in params_list]
# /tmp/ipykernel_29406/3341459398.py:417: RuntimeWarning: overflow encountered in exp
#   printer(history_lbfgs[-1],", ".join([f"{name}={np.exp(l.item()):.4f}"
# /tmp/ipykernel_29406/3341459398.py:411: RuntimeWarning: overflow encountered in exp
#   stored_parameters = [np.exp(p.item()) for p in params_list]
# /tmp/ipykernel_29406/3341459398.py:417: RuntimeWarning: overflow encountered in exp
#   printer(history_lbfgs[-1],", ".join([f"{name}={np.exp(l.item()):.4f}"

# %%
for printer in results:
    print(printer.get())
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       start running model 'solution_31'.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The selected device is cuda:0
# ============================================
# Epoch: 1
#  data loss:0.014964,
# data A loss:0.002051, data B loss:0.000415, data C loss:0.012498,
# Laplacian A loss:29.807781, Laplacian B loss:1.680166
#
# Validation loss:34.985009
# ============================================
# Epoch: 200
#  data loss:0.014457,
# data A loss:0.002022, data B loss:0.000372, data C loss:0.012063,
# Laplacian A loss:29.807662, Laplacian B loss:1.680132
#
# Validation loss:34.990862
# ============================================
# Epoch: 400
#  data loss:0.014457,
# data A loss:0.002022, data B loss:0.000372, data C loss:0.012063,
# Laplacian A loss:29.807662, Laplacian B loss:1.680132
#
# Validation loss:34.990862
# ============================================
# Epoch: 600
#  data loss:0.014457,
# data A loss:0.002022, data B loss:0.000372, data C loss:0.012063,
# Laplacian A loss:29.807662, Laplacian B loss:1.680132
#
# Validation loss:34.990862
# ============================================
# Epoch: 800
#  data loss:0.014457,
# data A loss:0.002022, data B loss:0.000372, data C loss:0.012063,
# Laplacian A loss:29.807662, Laplacian B loss:1.680132
#
# Validation loss:34.990862
# ============================================
# Epoch: 1000
#  data loss:0.014457,
# data A loss:0.002022, data B loss:0.000372, data C loss:0.012063,
# Laplacian A loss:29.807662, Laplacian B loss:1.680132
#
# Validation loss:34.990862
# ============================================
# Epoch: 1200
#  data loss:0.014457,
# data A loss:0.002022, data B loss:0.000372, data C loss:0.012063,
# Laplacian A loss:29.807662, Laplacian B loss:1.680132
#
# Validation loss:34.990862
# ============================================
# Epoch: 1400
#  data loss:0.014457,
# data A loss:0.002022, data B loss:0.000372, data C loss:0.012063,
# Laplacian A loss:29.807662, Laplacian B loss:1.680132
#
# Validation loss:34.990862
# ============================================
# Epoch: 1600
#  data loss:0.014457,
# data A loss:0.002022, data B loss:0.000372, data C loss:0.012063,
# Laplacian A loss:29.807662, Laplacian B loss:1.680132
#
# Validation loss:34.990862
# ============================================
# Epoch: 1800
#  data loss:0.014457,
# data A loss:0.002022, data B loss:0.000372, data C loss:0.012063,
# Laplacian A loss:29.807662, Laplacian B loss:1.680132
#
# Validation loss:34.990862
# ============================================
# Epoch: 2000
#  data loss:0.014457,
# data A loss:0.002022, data B loss:0.000372, data C loss:0.012063,
# Laplacian A loss:29.807662, Laplacian B loss:1.680132
#
# Validation loss:34.990862
# ============================================
# Epoch: 2200
#  data loss:0.014457,
# data A loss:0.002022, data B loss:0.000372, data C loss:0.012063,
# Laplacian A loss:29.807662, Laplacian B loss:1.680132
#
# Validation loss:34.990862
# ============================================
# Epoch: 2400
#  data loss:0.014457,
# data A loss:0.002022, data B loss:0.000372, data C loss:0.012063,
# Laplacian A loss:29.807662, Laplacian B loss:1.680132
#
# Validation loss:34.990862
# ============================================
# Epoch: 2600
#  data loss:0.014457,
# data A loss:0.002022, data B loss:0.000372, data C loss:0.012063,
# Laplacian A loss:29.807662, Laplacian B loss:1.680132
#
# Validation loss:34.990862
# ============================================
# Epoch: 2800
#  data loss:0.014457,
# data A loss:0.002022, data B loss:0.000372, data C loss:0.012063,
# Laplacian A loss:29.807662, Laplacian B loss:1.680132
#
# Validation loss:34.990862
# ============================================
# Epoch: 3000
#  data loss:0.014457,
# data A loss:0.002022, data B loss:0.000372, data C loss:0.012063,
# Laplacian A loss:29.807662, Laplacian B loss:1.680132
#
# Validation loss:34.990862
# ============================================
# Epoch: 3200
#  data loss:0.014457,
# data A loss:0.002022, data B loss:0.000372, data C loss:0.012063,
# Laplacian A loss:29.807662, Laplacian B loss:1.680132
#
# Validation loss:34.990862
# ============================================
# Epoch: 3400
#  data loss:0.014457,
# data A loss:0.002022, data B loss:0.000372, data C loss:0.012063,
# Laplacian A loss:29.807662, Laplacian B loss:1.680132
#
# Validation loss:34.990862
# ============================================
# Epoch: 3600
#  data loss:0.014457,
# data A loss:0.002022, data B loss:0.000372, data C loss:0.012063,
# Laplacian A loss:29.807662, Laplacian B loss:1.680132
#
# Validation loss:34.990862
# ============================================
# Epoch: 3800
#  data loss:0.014457,
# data A loss:0.002022, data B loss:0.000372, data C loss:0.012063,
# Laplacian A loss:29.807662, Laplacian B loss:1.680132
#
# Validation loss:34.990862
# ============================================
# Epoch: 4000
#  data loss:0.014457,
# data A loss:0.002022, data B loss:0.000372, data C loss:0.012063,
# Laplacian A loss:29.807662, Laplacian B loss:1.680132
#
# Validation loss:34.990862
# ============================================
# Epoch: 4200
#  data loss:0.014457,
# data A loss:0.002022, data B loss:0.000372, data C loss:0.012063,
# Laplacian A loss:29.807662, Laplacian B loss:1.680132
#
# Validation loss:34.990862
# ============================================
# Epoch: 4400
#  data loss:0.014457,
# data A loss:0.002022, data B loss:0.000372, data C loss:0.012063,
# Laplacian A loss:29.807662, Laplacian B loss:1.680132
#
# Validation loss:34.990862
# ============================================
# Epoch: 4600
#  data loss:0.014457,
# data A loss:0.002022, data B loss:0.000372, data C loss:0.012063,
# Laplacian A loss:29.807662, Laplacian B loss:1.680132
#
# Validation loss:34.990862
# ============================================
# Epoch: 4800
#  data loss:0.014457,
# data A loss:0.002022, data B loss:0.000372, data C loss:0.012063,
# Laplacian A loss:29.807662, Laplacian B loss:1.680132
#
# Validation loss:34.990862
# ============================================
# Epoch: 5000
#  data loss:0.014457,
# data A loss:0.002022, data B loss:0.000372, data C loss:0.012063,
# Laplacian A loss:29.807662, Laplacian B loss:1.680132
#
# Validation loss:34.990862
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       Check the trained model 'solution_31' outputs.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# A diff:0.002020511411078865B diff:0.0003722872369954267C diff:0.01207172942618578
# F_A actual:0.010401505022327728, F_A:0.0007409709505736828, RMSE: 0.10220700395111382
# F_B actual:1.6687800712546776, F_B:0.020956585183739662, RMSE: 1.3047160869611405
# F_C actual:0.013421393689081572, F_C:0.0028835886623710394, RMSE: 0.10449780239859675
#
# Laplacian A RMSE: 5.459832672439488
# Laplacian B RMSE: 1.2962296370769353
#
# dAdt RMSE: 0.05703245190768075
# dBdt RMSE: 0.19564050337123845
# dCdt RMSE: 0.10449780239859675
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       Estimates the parameters of the model 'solution_31'.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 20.740432739257812b_A=2.7183, b_B=2.7183, b_C=2.7183, V_A=2.7183, V_B=2.7183, V_C=2.7183, mu_A=2.7183, mu_B=2.7183, K_AA=2.7183, K_AB=2.7183, K_AC=2.7183, K_BA=2.7183, K_BC=2.7183, K_CB=2.7183, K_CC=2.7183
#
# 0.0028203753754496574b_A=2.0402, b_B=2.4497, b_C=0.0636, V_A=2.7171, V_B=2.7182, V_C=4.3256, mu_A=4.9526, mu_B=3.1287, K_AA=2.7230, K_AB=2.7186, K_AC=2.7210, K_BA=2.7182, K_BC=2.7542, K_CB=2.7181, K_CC=14.2510
#
# 7.076270412653685e-05b_A=2.1505, b_B=2.4752, b_C=0.0261, V_A=2.7171, V_B=2.7182, V_C=5.1594, mu_A=5.2118, mu_B=3.1212, K_AA=2.7229, K_AB=2.7186, K_AC=2.7220, K_BA=2.7182, K_BC=2.7683, K_CB=2.7181, K_CC=18.7766
#
# 3.992326583102113e-06b_A=0.5623, b_B=0.1878, b_C=0.0263, V_A=2.7337, V_B=2.7179, V_C=4.9376, mu_A=1.3642, mu_B=0.2376, K_AA=2.6575, K_AB=2.7198, K_AC=2.7217, K_BA=2.7187, K_BC=2.7649, K_CB=2.7143, K_CC=18.7428
#
# 1.7637316886975896e-06b_A=0.1189, b_B=0.0094, b_C=0.0264, V_A=2.7490, V_B=2.7017, V_C=4.7019, mu_A=0.2923, mu_B=0.0127, K_AA=2.5988, K_AB=2.7855, K_AC=2.7215, K_BA=2.7192, K_BC=2.7612, K_CB=2.6737, K_CC=18.7177
#
# 1.7037384623108665e-06b_A=0.0811, b_B=0.0045, b_C=0.0264, V_A=2.7492, V_B=2.6751, V_C=4.6486, mu_A=0.2006, mu_B=0.0065, K_AA=2.5982, K_AB=2.8979, K_AC=2.7214, K_BA=2.7192, K_BC=2.7604, K_CB=2.6128, K_CC=18.6972
#
# 1.6718712458896334e-06b_A=0.0334, b_B=0.0008, b_C=0.0265, V_A=2.7390, V_B=2.5606, V_C=4.5342, mu_A=0.0848, mu_B=0.0015, K_AA=2.6370, K_AB=3.4517, K_AC=2.7212, K_BA=2.7189, K_BC=2.7585, K_CB=2.3611, K_CC=18.6244
#
# 1.6710321233404102e-06b_A=0.0301, b_B=0.0006, b_C=0.0265, V_A=2.7358, V_B=2.5372, V_C=4.5219, mu_A=0.0767, mu_B=0.0013, K_AA=2.6494, K_AB=3.5811, K_AC=2.7212, K_BA=2.7188, K_BC=2.7582, K_CB=2.3114, K_CC=18.6053
#
# 1.6700895457688603e-06b_A=0.0290, b_B=0.0006, b_C=0.0265, V_A=2.7345, V_B=2.5284, V_C=4.5176, mu_A=0.0741, mu_B=0.0012, K_AA=2.6545, K_AB=3.6309, K_AC=2.7212, K_BA=2.7188, K_BC=2.7582, K_CB=2.2931, K_CC=18.6013
#
# 1.6693791167199379e-06b_A=0.0257, b_B=0.0005, b_C=0.0265, V_A=2.7314, V_B=2.5051, V_C=4.5031, mu_A=0.0659, mu_B=0.0010, K_AA=2.6666, K_AB=3.7678, K_AC=2.7212, K_BA=2.7187, K_BC=2.7579, K_CB=2.2446, K_CC=18.5891
#
# 1.6693791167199379e-06b_A=0.0257, b_B=0.0005, b_C=0.0265, V_A=2.7314, V_B=2.5051, V_C=4.5031, mu_A=0.0659, mu_B=0.0010, K_AA=2.6666, K_AB=3.7678, K_AC=2.7212, K_BA=2.7187, K_BC=2.7579, K_CB=2.2446, K_CC=18.5891
#
# 1.6693791167199379e-06b_A=0.0257, b_B=0.0005, b_C=0.0265, V_A=2.7314, V_B=2.5051, V_C=4.5031, mu_A=0.0659, mu_B=0.0010, K_AA=2.6666, K_AB=3.7678, K_AC=2.7212, K_BA=2.7187, K_BC=2.7579, K_CB=2.2446, K_CC=18.5891
#
# 1.6693791167199379e-06b_A=0.0257, b_B=0.0005, b_C=0.0265, V_A=2.7314, V_B=2.5051, V_C=4.5031, mu_A=0.0659, mu_B=0.0010, K_AA=2.6666, K_AB=3.7678, K_AC=2.7212, K_BA=2.7187, K_BC=2.7579, K_CB=2.2446, K_CC=18.5891
#
# 1.6693791167199379e-06b_A=0.0257, b_B=0.0005, b_C=0.0265, V_A=2.7314, V_B=2.5051, V_C=4.5031, mu_A=0.0659, mu_B=0.0010, K_AA=2.6666, K_AB=3.7678, K_AC=2.7212, K_BA=2.7187, K_BC=2.7579, K_CB=2.2446, K_CC=18.5891
#
# 1.6693791167199379e-06b_A=0.0257, b_B=0.0005, b_C=0.0265, V_A=2.7314, V_B=2.5051, V_C=4.5031, mu_A=0.0659, mu_B=0.0010, K_AA=2.6666, K_AB=3.7678, K_AC=2.7212, K_BA=2.7187, K_BC=2.7579, K_CB=2.2446, K_CC=18.5891
#
# 1.6693791167199379e-06b_A=0.0257, b_B=0.0005, b_C=0.0265, V_A=2.7314, V_B=2.5051, V_C=4.5031, mu_A=0.0659, mu_B=0.0010, K_AA=2.6666, K_AB=3.7678, K_AC=2.7212, K_BA=2.7187, K_BC=2.7579, K_CB=2.2446, K_CC=18.5891
#
# 1.6693791167199379e-06b_A=0.0257, b_B=0.0005, b_C=0.0265, V_A=2.7314, V_B=2.5051, V_C=4.5031, mu_A=0.0659, mu_B=0.0010, K_AA=2.6666, K_AB=3.7678, K_AC=2.7212, K_BA=2.7187, K_BC=2.7579, K_CB=2.2446, K_CC=18.5891
#
# 1.6693791167199379e-06b_A=0.0257, b_B=0.0005, b_C=0.0265, V_A=2.7314, V_B=2.5051, V_C=4.5031, mu_A=0.0659, mu_B=0.0010, K_AA=2.6666, K_AB=3.7678, K_AC=2.7212, K_BA=2.7187, K_BC=2.7579, K_CB=2.2446, K_CC=18.5891
#
# 1.6693791167199379e-06b_A=0.0257, b_B=0.0005, b_C=0.0265, V_A=2.7314, V_B=2.5051, V_C=4.5031, mu_A=0.0659, mu_B=0.0010, K_AA=2.6666, K_AB=3.7678, K_AC=2.7212, K_BA=2.7187, K_BC=2.7579, K_CB=2.2446, K_CC=18.5891
#
# 1.6693791167199379e-06b_A=0.0257, b_B=0.0005, b_C=0.0265, V_A=2.7314, V_B=2.5051, V_C=4.5031, mu_A=0.0659, mu_B=0.0010, K_AA=2.6666, K_AB=3.7678, K_AC=2.7212, K_BA=2.7187, K_BC=2.7579, K_CB=2.2446, K_CC=18.5891
#
# name 	 Originl 	 Estimated 	 Difference
# -------------------------------------------------------------------------------------------------------------
# b_A:	0.001		0.026		0.025
# b_B:	1.000		0.000		1.000
# b_C:	0.100		0.026		0.074
# V_A:	100.000		2.731		97.269
# V_B:	100.000		2.505		97.495
# V_C:	10.000		4.503		5.497
# mu_A:	1.000		0.066		0.934
# mu_B:	5.000		0.001		4.999
# K_AA:	1.000		2.667		1.667
# K_AB:	1.000		3.768		2.768
# K_AC:	1.000		2.721		1.721
# K_BA:	0.500		2.719		2.219
# K_BC:	0.500		2.758		2.258
# K_CB:	25.000		2.245		22.755
# K_CC:	1.000		18.589		17.589
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       Save the results at './outputs_zero_noise_identifiable'.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       End of the model './outputs_zero_noise_identifiable'.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       start running model 'solution_3'.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The selected device is cuda:1
# ============================================
# Epoch: 1
#  data loss:0.020999,
# data A loss:0.005014, data B loss:0.001728, data C loss:0.014257,
# Laplacian A loss:24.909868, Laplacian B loss:0.076734
#
# Validation loss:38.578556
# ============================================
# Epoch: 200
#  data loss:0.018923,
# data A loss:0.004474, data B loss:0.000453, data C loss:0.013996,
# Laplacian A loss:22.859013, Laplacian B loss:0.070148
#
# Validation loss:41.403317
# ============================================
# Epoch: 400
#  data loss:0.018940,
# data A loss:0.004374, data B loss:0.000579, data C loss:0.013987,
# Laplacian A loss:20.379861, Laplacian B loss:0.063391
#
# Validation loss:42.324828
# ============================================
# Epoch: 600
#  data loss:0.017780,
# data A loss:0.003452, data B loss:0.000491, data C loss:0.013837,
# Laplacian A loss:16.760153, Laplacian B loss:0.051023
#
# Validation loss:16.293473
# ============================================
# Epoch: 800
#  data loss:0.016953,
# data A loss:0.002621, data B loss:0.000523, data C loss:0.013808,
# Laplacian A loss:13.338633, Laplacian B loss:0.044605
#
# Validation loss:10.202972
# ============================================
# Epoch: 1000
#  data loss:0.016298,
# data A loss:0.001982, data B loss:0.000498, data C loss:0.013818,
# Laplacian A loss:10.279998, Laplacian B loss:0.039899
#
# Validation loss:4.713706
# ============================================
# Epoch: 1200
#  data loss:0.016148,
# data A loss:0.001849, data B loss:0.000494, data C loss:0.013806,
# Laplacian A loss:8.268097, Laplacian B loss:0.035225
#
# Validation loss:4.171345
# ============================================
# Epoch: 1400
#  data loss:0.015698,
# data A loss:0.001425, data B loss:0.000473, data C loss:0.013801,
# Laplacian A loss:7.145708, Laplacian B loss:0.033907
#
# Validation loss:4.784619
# ============================================
# Epoch: 1600
#  data loss:0.015738,
# data A loss:0.001415, data B loss:0.000522, data C loss:0.013801,
# Laplacian A loss:6.484328, Laplacian B loss:0.034091
#
# Validation loss:1.961422
# ============================================
# Epoch: 1800
#  data loss:0.015732,
# data A loss:0.001403, data B loss:0.000537, data C loss:0.013792,
# Laplacian A loss:5.986302, Laplacian B loss:0.035455
#
# Validation loss:2.014578
# ============================================
# Epoch: 2000
#  data loss:0.015614,
# data A loss:0.001292, data B loss:0.000539, data C loss:0.013783,
# Laplacian A loss:5.598626, Laplacian B loss:0.034632
#
# Validation loss:2.570679
# ============================================
# Epoch: 2200
#  data loss:0.015590,
# data A loss:0.001266, data B loss:0.000540, data C loss:0.013784,
# Laplacian A loss:5.332899, Laplacian B loss:0.033642
#
# Validation loss:2.798751
# ============================================
# Epoch: 2400
#  data loss:0.015518,
# data A loss:0.001198, data B loss:0.000534, data C loss:0.013786,
# Laplacian A loss:5.129365, Laplacian B loss:0.033692
#
# Validation loss:2.353584
# ============================================
# Epoch: 2600
#  data loss:0.015411,
# data A loss:0.001110, data B loss:0.000515, data C loss:0.013786,
# Laplacian A loss:4.960789, Laplacian B loss:0.032522
#
# Validation loss:3.381205
# ============================================
# Epoch: 2800
#  data loss:0.015401,
# data A loss:0.001167, data B loss:0.000446, data C loss:0.013788,
# Laplacian A loss:4.800749, Laplacian B loss:0.031654
#
# Validation loss:3.219189
# ============================================
# Epoch: 3000
#  data loss:0.015455,
# data A loss:0.001209, data B loss:0.000456, data C loss:0.013789,
# Laplacian A loss:4.667999, Laplacian B loss:0.031678
#
# Validation loss:3.456186
# ============================================
# Epoch: 3200
#  data loss:0.015396,
# data A loss:0.001169, data B loss:0.000437, data C loss:0.013790,
# Laplacian A loss:4.557678, Laplacian B loss:0.031056
#
# Validation loss:3.483174
# ============================================
# Epoch: 3400
#  data loss:0.015263,
# data A loss:0.001132, data B loss:0.000341, data C loss:0.013790,
# Laplacian A loss:4.486096, Laplacian B loss:0.030812
#
# Validation loss:3.270828
# ============================================
# Epoch: 3600
#  data loss:0.015263,
# data A loss:0.001132, data B loss:0.000341, data C loss:0.013790,
# Laplacian A loss:4.486096, Laplacian B loss:0.030812
#
# Validation loss:3.270828
# ============================================
# Epoch: 3800
#  data loss:0.015263,
# data A loss:0.001132, data B loss:0.000341, data C loss:0.013790,
# Laplacian A loss:4.486096, Laplacian B loss:0.030812
#
# Validation loss:3.270828
# ============================================
# Epoch: 4000
#  data loss:0.015263,
# data A loss:0.001132, data B loss:0.000341, data C loss:0.013790,
# Laplacian A loss:4.486096, Laplacian B loss:0.030812
#
# Validation loss:3.270828
# ============================================
# Epoch: 4200
#  data loss:0.015263,
# data A loss:0.001132, data B loss:0.000341, data C loss:0.013790,
# Laplacian A loss:4.486096, Laplacian B loss:0.030812
#
# Validation loss:3.270828
# ============================================
# Epoch: 4400
#  data loss:0.015263,
# data A loss:0.001132, data B loss:0.000341, data C loss:0.013790,
# Laplacian A loss:4.486096, Laplacian B loss:0.030812
#
# Validation loss:3.270828
# ============================================
# Epoch: 4600
#  data loss:0.015263,
# data A loss:0.001132, data B loss:0.000341, data C loss:0.013790,
# Laplacian A loss:4.486096, Laplacian B loss:0.030812
#
# Validation loss:3.270828
# ============================================
# Epoch: 4800
#  data loss:0.015263,
# data A loss:0.001132, data B loss:0.000341, data C loss:0.013790,
# Laplacian A loss:4.486096, Laplacian B loss:0.030812
#
# Validation loss:3.270828
# ============================================
# Epoch: 5000
#  data loss:0.015263,
# data A loss:0.001132, data B loss:0.000341, data C loss:0.013790,
# Laplacian A loss:4.486096, Laplacian B loss:0.030812
#
# Validation loss:3.270828
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       Check the trained model 'solution_3' outputs.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# A diff:0.00113123131009432B diff:0.00034076984552109177C diff:0.013787348211185312
# F_A actual:0.0001562277168320191, F_A:0.00018978881416842341, RMSE: 0.006429554513748275
# F_B actual:0.07467431176220166, F_B:0.0844603106379509, RMSE: 0.1329435081597662
# F_C actual:0.00015668521146330435, F_C:4.028428520541638e-05, RMSE: 0.01114878925397552
#
# Laplacian A RMSE: 2.117853520186963
# Laplacian B RMSE: 0.17553422793072943
#
# dAdt RMSE: 0.019869263217364985
# dBdt RMSE: 0.20472371295814246
# dCdt RMSE: 0.01114878925397552
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       Estimates the parameters of the model 'solution_3'.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 960.0231323242188b_A=2.7183, b_B=2.7183, b_C=2.7183, V_A=2.7183, V_B=2.7183, V_C=2.7183, mu_A=2.7183, mu_B=2.7183, K_AA=2.7183, K_AB=2.7183, K_AC=2.7183, K_BA=2.7183, K_BC=2.7183, K_CB=2.7183, K_CC=2.7183
#
# 0.15868818759918213b_A=3.7693, b_B=4.3275, b_C=0.3401, V_A=2.7201, V_B=3.5192, V_C=2.7155, mu_A=0.9800, mu_B=0.5497, K_AA=2.7171, K_AB=2.3613, K_AC=2.7094, K_BA=2.7254, K_BC=2.7072, K_CB=3.7810, K_CC=2.7245
#
# 0.04704839736223221b_A=2.1143, b_B=2.6199, b_C=0.0013, V_A=2.7197, V_B=3.1110, V_C=2.6995, mu_A=0.5493, mu_B=0.3337, K_AA=2.7200, K_AB=3.5434, K_AC=2.6585, K_BA=2.7241, K_BC=2.6441, K_CB=3.8546, K_CC=2.7605
#
# 0.03967811539769173b_A=0.5933, b_B=0.8810, b_C=0.0000, V_A=2.7177, V_B=5.9244, V_C=2.6749, mu_A=0.1604, mu_B=0.1723, K_AA=2.7339, K_AB=5.2396, K_AC=2.5817, K_BA=2.7160, K_BC=2.5491, K_CB=5.9457, K_CC=2.8171
#
# 0.0298810712993145b_A=0.5830, b_B=0.7840, b_C=0.0000, V_A=2.7155, V_B=11.3448, V_C=2.6824, mu_A=0.1521, mu_B=0.3049, K_AA=2.7417, K_AB=4.9645, K_AC=2.6054, K_BA=2.7071, K_BC=2.5779, K_CB=8.3853, K_CC=2.7991
#
# 0.029232490807771683b_A=0.0850, b_B=0.1424, b_C=0.0000, V_A=2.7091, V_B=46.8430, V_C=2.6551, mu_A=0.0224, mu_B=0.1895, K_AA=2.7741, K_AB=8.1737, K_AC=2.5223, K_BA=2.6817, K_BC=2.4749, K_CB=20.9772, K_CC=2.8623
#
# 0.02913893572986126b_A=0.0049, b_B=0.0115, b_C=0.0000, V_A=2.6895, V_B=712.2840, V_C=2.6265, mu_A=0.0015, mu_B=0.1755, K_AA=2.8393, K_AB=16.4092, K_AC=2.4379, K_BA=2.6053, K_BC=2.3700, K_CB=111.6622, K_CC=2.9296
#
# nanb_A=inf, b_B=inf, b_C=inf, V_A=0.0000, V_B=0.0000, V_C=inf, mu_A=inf, mu_B=inf, K_AA=0.0000, K_AB=0.0000, K_AC=inf, K_BA=0.0000, K_BC=inf, K_CB=0.0000, K_CC=0.0000
#
# Nan -- (maybe large learning rate)
# name 	 Originl 	 Estimated 	 Difference
# -------------------------------------------------------------------------------------------------------------
# b_A:	0.001		nan		nan
# b_B:	1.000		nan		nan
# b_C:	1.000		nan		nan
# V_A:	5.000		nan		nan
# V_B:	20.000		nan		nan
# V_C:	20.000		nan		nan
# mu_A:	0.100		nan		nan
# mu_B:	0.500		nan		nan
# K_AA:	5.000		nan		nan
# K_AB:	5.000		nan		nan
# K_AC:	5.000		nan		nan
# K_BA:	10.000		nan		nan
# K_BC:	10.000		nan		nan
# K_CB:	100.000		nan		nan
# K_CC:	5.000		nan		nan
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       Save the results at './outputs_zero_noise_identifiable'.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       End of the model './outputs_zero_noise_identifiable'.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       start running model 'solution_8'.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The selected device is cuda:2
# ============================================
# Epoch: 1
#  data loss:0.009424,
# data A loss:0.007155, data B loss:0.000555, data C loss:0.001713,
# Laplacian A loss:29.185472, Laplacian B loss:0.011348
#
# Validation loss:20.414565
# ============================================
# Epoch: 200
#  data loss:0.007976,
# data A loss:0.006338, data B loss:0.000225, data C loss:0.001413,
# Laplacian A loss:26.503295, Laplacian B loss:0.013243
#
# Validation loss:21.399053
# ============================================
# Epoch: 400
#  data loss:0.009062,
# data A loss:0.007455, data B loss:0.000206, data C loss:0.001401,
# Laplacian A loss:24.734039, Laplacian B loss:0.010054
#
# Validation loss:27.140896
# ============================================
# Epoch: 600
#  data loss:0.009119,
# data A loss:0.007506, data B loss:0.000204, data C loss:0.001410,
# Laplacian A loss:23.409180, Laplacian B loss:0.009736
#
# Validation loss:20.928420
# ============================================
# Epoch: 800
#  data loss:0.010671,
# data A loss:0.009073, data B loss:0.000198, data C loss:0.001400,
# Laplacian A loss:21.185964, Laplacian B loss:0.009302
#
# Validation loss:23.395654
# ============================================
# Epoch: 1000
#  data loss:0.010438,
# data A loss:0.008829, data B loss:0.000214, data C loss:0.001394,
# Laplacian A loss:19.544113, Laplacian B loss:0.010686
#
# Validation loss:27.182066
# ============================================
# Epoch: 1200
#  data loss:0.011163,
# data A loss:0.009548, data B loss:0.000204, data C loss:0.001411,
# Laplacian A loss:18.305066, Laplacian B loss:0.009643
#
# Validation loss:24.586230
# ============================================
# Epoch: 1400
#  data loss:0.011157,
# data A loss:0.009563, data B loss:0.000201, data C loss:0.001393,
# Laplacian A loss:17.418932, Laplacian B loss:0.008445
#
# Validation loss:25.483481
# ============================================
# Epoch: 1600
#  data loss:0.010720,
# data A loss:0.009135, data B loss:0.000201, data C loss:0.001384,
# Laplacian A loss:17.043953, Laplacian B loss:0.008352
#
# Validation loss:23.640002
# ============================================
# Epoch: 1800
#  data loss:0.010166,
# data A loss:0.008584, data B loss:0.000200, data C loss:0.001382,
# Laplacian A loss:16.664729, Laplacian B loss:0.008344
#
# Validation loss:21.653252
# ============================================
# Epoch: 2000
#  data loss:0.010232,
# data A loss:0.008651, data B loss:0.000200, data C loss:0.001382,
# Laplacian A loss:16.261010, Laplacian B loss:0.008150
#
# Validation loss:21.185589
# ============================================
# Epoch: 2200
#  data loss:0.010431,
# data A loss:0.008857, data B loss:0.000198, data C loss:0.001376,
# Laplacian A loss:15.905097, Laplacian B loss:0.008211
#
# Validation loss:21.251812
# ============================================
# Epoch: 2400
#  data loss:0.010270,
# data A loss:0.008686, data B loss:0.000202, data C loss:0.001381,
# Laplacian A loss:15.672182, Laplacian B loss:0.008450
#
# Validation loss:21.013028
# ============================================
# Epoch: 2600
#  data loss:0.010215,
# data A loss:0.008628, data B loss:0.000202, data C loss:0.001385,
# Laplacian A loss:15.140078, Laplacian B loss:0.008978
#
# Validation loss:23.285645
# ============================================
# Epoch: 2800
#  data loss:0.010318,
# data A loss:0.008728, data B loss:0.000205, data C loss:0.001384,
# Laplacian A loss:15.047983, Laplacian B loss:0.009114
#
# Validation loss:22.936339
# ============================================
# Epoch: 3000
#  data loss:0.010318,
# data A loss:0.008728, data B loss:0.000205, data C loss:0.001384,
# Laplacian A loss:15.047983, Laplacian B loss:0.009114
#
# Validation loss:22.936339
# ============================================
# Epoch: 3200
#  data loss:0.010318,
# data A loss:0.008728, data B loss:0.000205, data C loss:0.001384,
# Laplacian A loss:15.047983, Laplacian B loss:0.009114
#
# Validation loss:22.936339
# ============================================
# Epoch: 3400
#  data loss:0.010318,
# data A loss:0.008728, data B loss:0.000205, data C loss:0.001384,
# Laplacian A loss:15.047983, Laplacian B loss:0.009114
#
# Validation loss:22.936339
# ============================================
# Epoch: 3600
#  data loss:0.010318,
# data A loss:0.008728, data B loss:0.000205, data C loss:0.001384,
# Laplacian A loss:15.047983, Laplacian B loss:0.009114
#
# Validation loss:22.936339
# ============================================
# Epoch: 3800
#  data loss:0.010318,
# data A loss:0.008728, data B loss:0.000205, data C loss:0.001384,
# Laplacian A loss:15.047983, Laplacian B loss:0.009114
#
# Validation loss:22.936339
# ============================================
# Epoch: 4000
#  data loss:0.010318,
# data A loss:0.008728, data B loss:0.000205, data C loss:0.001384,
# Laplacian A loss:15.047983, Laplacian B loss:0.009114
#
# Validation loss:22.936339
# ============================================
# Epoch: 4200
#  data loss:0.010318,
# data A loss:0.008728, data B loss:0.000205, data C loss:0.001384,
# Laplacian A loss:15.047983, Laplacian B loss:0.009114
#
# Validation loss:22.936339
# ============================================
# Epoch: 4400
#  data loss:0.010318,
# data A loss:0.008728, data B loss:0.000205, data C loss:0.001384,
# Laplacian A loss:15.047983, Laplacian B loss:0.009114
#
# Validation loss:22.936339
# ============================================
# Epoch: 4600
#  data loss:0.010318,
# data A loss:0.008728, data B loss:0.000205, data C loss:0.001384,
# Laplacian A loss:15.047983, Laplacian B loss:0.009114
#
# Validation loss:22.936339
# ============================================
# Epoch: 4800
#  data loss:0.010318,
# data A loss:0.008728, data B loss:0.000205, data C loss:0.001384,
# Laplacian A loss:15.047983, Laplacian B loss:0.009114
#
# Validation loss:22.936339
# ============================================
# Epoch: 5000
#  data loss:0.010318,
# data A loss:0.008728, data B loss:0.000205, data C loss:0.001384,
# Laplacian A loss:15.047983, Laplacian B loss:0.009114
#
# Validation loss:22.936339
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       Check the trained model 'solution_8' outputs.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# A diff:0.008734478978097137B diff:0.00020491872821020463C diff:0.0013838312508564772
# F_A actual:8.700854126690215e-05, F_A:0.0001373489067191258, RMSE: 0.010898148859508435
# F_B actual:0.0109750995368004, F_B:0.012747800908982754, RMSE: 0.11437780871051663
# F_C actual:0.005634111525862939, F_C:0.0007101068622432649, RMSE: 0.07228062661749696
#
# Laplacian A RMSE: 3.879810925530036
# Laplacian B RMSE: 0.09547484896181949
#
# dAdt RMSE: 0.03550186763315854
# dBdt RMSE: 0.10078734136145713
# dCdt RMSE: 0.07228062661749696
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       Estimates the parameters of the model 'solution_8'.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 362.60797119140625b_A=2.7183, b_B=2.7183, b_C=2.7183, V_A=2.7183, V_B=2.7183, V_C=2.7183, mu_A=2.7183, mu_B=2.7183, K_AA=2.7183, K_AB=2.7183, K_AC=2.7183, K_BA=2.7183, K_BC=2.7183, K_CB=2.7183, K_CC=2.7183
#
# 0.04962296783924103b_A=4.1428, b_B=4.7871, b_C=0.2188, V_A=2.7425, V_B=2.8614, V_C=2.6837, mu_A=0.8919, mu_B=0.7642, K_AA=2.7119, K_AB=2.6707, K_AC=2.5947, K_BA=2.8141, K_BC=2.5853, K_CB=3.2820, K_CC=2.7318
#
# 0.009307329542934895b_A=0.4153, b_B=1.9796, b_C=0.0000, V_A=2.7007, V_B=2.7168, V_C=2.3428, mu_A=0.0955, mu_B=0.3322, K_AA=2.9273, K_AB=3.1768, K_AC=1.5781, K_BA=2.6520, K_BC=1.5175, K_CB=3.0336, K_CC=2.8808
#
# 0.008112434297800064b_A=0.0079, b_B=0.5209, b_C=0.0000, V_A=2.2940, V_B=2.9302, V_C=1.9428, mu_A=0.0040, mu_B=0.1246, K_AA=3.7483, K_AB=6.1309, K_AC=0.7954, K_BA=1.3971, K_BC=0.7282, K_CB=4.4548, K_CC=3.0994
#
# 0.00775706022977829b_A=0.0004, b_B=0.1482, b_C=0.0000, V_A=2.0706, V_B=4.2786, V_C=1.7067, mu_A=0.0003, mu_B=0.0954, K_AA=4.4975, K_AB=7.7313, K_AC=0.4950, K_BA=0.9346, K_BC=0.4381, K_CB=10.3997, K_CC=3.2603
#
# 0.0077520208433270454b_A=0.0000, b_B=0.0239, b_C=0.0000, V_A=1.7828, V_B=8.5945, V_C=1.4271, mu_A=0.0000, mu_B=0.0727, K_AA=5.8872, K_AB=9.6426, K_AC=0.2571, K_BA=0.5196, K_BC=0.2172, K_CB=46.3295, K_CC=3.4964
#
# 0.0077495272271335125b_A=0.0000, b_B=0.0002, b_C=0.0000, V_A=0.9619, V_B=167.1401, V_C=0.9500, mu_A=0.0000, mu_B=0.0655, K_AA=15.4279, K_AB=20.8223, K_AC=0.0579, K_BA=0.0459, K_BC=0.0440, K_CB=37937.6848, K_CC=4.0988
#
# nanb_A=0.0000, b_B=0.0000, b_C=0.0000, V_A=0.0000, V_B=inf, V_C=0.0000, mu_A=0.0000, mu_B=0.0000, K_AA=inf, K_AB=inf, K_AC=0.0000, K_BA=0.0000, K_BC=0.0000, K_CB=inf, K_CC=inf
#
# Nan -- (maybe large learning rate)
# name 	 Originl 	 Estimated 	 Difference
# -------------------------------------------------------------------------------------------------------------
# b_A:	0.001		nan		nan
# b_B:	1.000		nan		nan
# b_C:	20.000		nan		nan
# V_A:	5.000		nan		nan
# V_B:	10.000		nan		nan
# V_C:	100.000		nan		nan
# mu_A:	0.100		nan		nan
# mu_B:	0.500		nan		nan
# K_AA:	5.000		nan		nan
# K_AB:	5.000		nan		nan
# K_AC:	10.000		nan		nan
# K_BA:	5.000		nan		nan
# K_BC:	10.000		nan		nan
# K_CB:	5.000		nan		nan
# K_CC:	10.000		nan		nan
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       Save the results at './outputs_zero_noise_identifiable'.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       End of the model './outputs_zero_noise_identifiable'.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       start running model 'solution_9'.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The selected device is cuda:0
# ============================================
# Epoch: 1
#  data loss:0.006390,
# data A loss:0.005039, data B loss:0.001159, data C loss:0.000192,
# Laplacian A loss:24.591630, Laplacian B loss:0.021803
#
# Validation loss:37.970437
# ============================================
# Epoch: 200
#  data loss:0.005819,
# data A loss:0.005172, data B loss:0.000492, data C loss:0.000155,
# Laplacian A loss:23.448596, Laplacian B loss:0.021126
#
# Validation loss:38.608544
# ============================================
# Epoch: 400
#  data loss:0.005530,
# data A loss:0.004997, data B loss:0.000474, data C loss:0.000060,
# Laplacian A loss:23.209459, Laplacian B loss:0.020557
#
# Validation loss:39.663110
# ============================================
# Epoch: 600
#  data loss:0.005530,
# data A loss:0.004997, data B loss:0.000474, data C loss:0.000060,
# Laplacian A loss:23.209459, Laplacian B loss:0.020557
#
# Validation loss:39.663110
# ============================================
# Epoch: 800
#  data loss:0.005530,
# data A loss:0.004997, data B loss:0.000474, data C loss:0.000060,
# Laplacian A loss:23.209459, Laplacian B loss:0.020557
#
# Validation loss:39.663110
# ============================================
# Epoch: 1000
#  data loss:0.005530,
# data A loss:0.004997, data B loss:0.000474, data C loss:0.000060,
# Laplacian A loss:23.209459, Laplacian B loss:0.020557
#
# Validation loss:39.663110
# ============================================
# Epoch: 1200
#  data loss:0.005530,
# data A loss:0.004997, data B loss:0.000474, data C loss:0.000060,
# Laplacian A loss:23.209459, Laplacian B loss:0.020557
#
# Validation loss:39.663110
# ============================================
# Epoch: 1400
#  data loss:0.005530,
# data A loss:0.004997, data B loss:0.000474, data C loss:0.000060,
# Laplacian A loss:23.209459, Laplacian B loss:0.020557
#
# Validation loss:39.663110
# ============================================
# Epoch: 1600
#  data loss:0.005530,
# data A loss:0.004997, data B loss:0.000474, data C loss:0.000060,
# Laplacian A loss:23.209459, Laplacian B loss:0.020557
#
# Validation loss:39.663110
# ============================================
# Epoch: 1800
#  data loss:0.005530,
# data A loss:0.004997, data B loss:0.000474, data C loss:0.000060,
# Laplacian A loss:23.209459, Laplacian B loss:0.020557
#
# Validation loss:39.663110
# ============================================
# Epoch: 2000
#  data loss:0.005530,
# data A loss:0.004997, data B loss:0.000474, data C loss:0.000060,
# Laplacian A loss:23.209459, Laplacian B loss:0.020557
#
# Validation loss:39.663110
# ============================================
# Epoch: 2200
#  data loss:0.005530,
# data A loss:0.004997, data B loss:0.000474, data C loss:0.000060,
# Laplacian A loss:23.209459, Laplacian B loss:0.020557
#
# Validation loss:39.663110
# ============================================
# Epoch: 2400
#  data loss:0.005530,
# data A loss:0.004997, data B loss:0.000474, data C loss:0.000060,
# Laplacian A loss:23.209459, Laplacian B loss:0.020557
#
# Validation loss:39.663110
# ============================================
# Epoch: 2600
#  data loss:0.005530,
# data A loss:0.004997, data B loss:0.000474, data C loss:0.000060,
# Laplacian A loss:23.209459, Laplacian B loss:0.020557
#
# Validation loss:39.663110
# ============================================
# Epoch: 2800
#  data loss:0.005530,
# data A loss:0.004997, data B loss:0.000474, data C loss:0.000060,
# Laplacian A loss:23.209459, Laplacian B loss:0.020557
#
# Validation loss:39.663110
# ============================================
# Epoch: 3000
#  data loss:0.005530,
# data A loss:0.004997, data B loss:0.000474, data C loss:0.000060,
# Laplacian A loss:23.209459, Laplacian B loss:0.020557
#
# Validation loss:39.663110
# ============================================
# Epoch: 3200
#  data loss:0.005530,
# data A loss:0.004997, data B loss:0.000474, data C loss:0.000060,
# Laplacian A loss:23.209459, Laplacian B loss:0.020557
#
# Validation loss:39.663110
# ============================================
# Epoch: 3400
#  data loss:0.005530,
# data A loss:0.004997, data B loss:0.000474, data C loss:0.000060,
# Laplacian A loss:23.209459, Laplacian B loss:0.020557
#
# Validation loss:39.663110
# ============================================
# Epoch: 3600
#  data loss:0.005530,
# data A loss:0.004997, data B loss:0.000474, data C loss:0.000060,
# Laplacian A loss:23.209459, Laplacian B loss:0.020557
#
# Validation loss:39.663110
# ============================================
# Epoch: 3800
#  data loss:0.005530,
# data A loss:0.004997, data B loss:0.000474, data C loss:0.000060,
# Laplacian A loss:23.209459, Laplacian B loss:0.020557
#
# Validation loss:39.663110
# ============================================
# Epoch: 4000
#  data loss:0.005530,
# data A loss:0.004997, data B loss:0.000474, data C loss:0.000060,
# Laplacian A loss:23.209459, Laplacian B loss:0.020557
#
# Validation loss:39.663110
# ============================================
# Epoch: 4200
#  data loss:0.005530,
# data A loss:0.004997, data B loss:0.000474, data C loss:0.000060,
# Laplacian A loss:23.209459, Laplacian B loss:0.020557
#
# Validation loss:39.663110
# ============================================
# Epoch: 4400
#  data loss:0.005530,
# data A loss:0.004997, data B loss:0.000474, data C loss:0.000060,
# Laplacian A loss:23.209459, Laplacian B loss:0.020557
#
# Validation loss:39.663110
# ============================================
# Epoch: 4600
#  data loss:0.005530,
# data A loss:0.004997, data B loss:0.000474, data C loss:0.000060,
# Laplacian A loss:23.209459, Laplacian B loss:0.020557
#
# Validation loss:39.663110
# ============================================
# Epoch: 4800
#  data loss:0.005530,
# data A loss:0.004997, data B loss:0.000474, data C loss:0.000060,
# Laplacian A loss:23.209459, Laplacian B loss:0.020557
#
# Validation loss:39.663110
# ============================================
# Epoch: 5000
#  data loss:0.005530,
# data A loss:0.004997, data B loss:0.000474, data C loss:0.000060,
# Laplacian A loss:23.209459, Laplacian B loss:0.020557
#
# Validation loss:39.663110
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       Check the trained model 'solution_9' outputs.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# A diff:0.0049965747943329876B diff:0.000473559288436859C diff:6.0209130040880996e-05
# F_A actual:0.00015518482741352783, F_A:5.213902113609947e-05, RMSE: 0.013169290229047588
# F_B actual:0.02110386387410565, F_B:0.006521440576761961, RMSE: 0.14848257181944252
# F_C actual:2.1690838656555972e-05, F_C:0.001081134658306837, RMSE: 0.03317886046617079
#
# Laplacian A RMSE: 4.818692467600858
# Laplacian B RMSE: 0.1434085751225222
#
# dAdt RMSE: 0.04037950582899076
# dBdt RMSE: 0.07325277306686179
# dCdt RMSE: 0.03317886046617079
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       Estimates the parameters of the model 'solution_9'.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 221.0997772216797b_A=2.7183, b_B=2.7183, b_C=2.7183, V_A=2.7183, V_B=2.7183, V_C=2.7183, mu_A=2.7183, mu_B=2.7183, K_AA=2.7183, K_AB=2.7183, K_AC=2.7183, K_BA=2.7183, K_BC=2.7183, K_CB=2.7183, K_CC=2.7183
#
# 0.04294008016586304b_A=3.5584, b_B=3.5906, b_C=0.1738, V_A=2.7426, V_B=3.2383, V_C=2.6818, mu_A=0.9811, mu_B=0.9779, K_AA=2.7001, K_AB=2.3763, K_AC=2.6026, K_BA=2.8134, K_BC=2.5800, K_CB=3.2146, K_CC=2.8323
#
# 0.0037594519089907408b_A=2.7698, b_B=2.9809, b_C=0.0117, V_A=2.7337, V_B=2.8509, V_C=2.6313, mu_A=0.7460, mu_B=0.8122, K_AA=2.7122, K_AB=2.4799, K_AC=2.4472, K_BA=2.7793, K_BC=2.3969, K_CB=3.1530, K_CC=3.0021
#
# 0.003083650255575776b_A=0.8044, b_B=1.3636, b_C=0.0000, V_A=2.6909, V_B=1.7532, V_C=2.4294, mu_A=0.2279, mu_B=0.3693, K_AA=2.8189, K_AB=3.3343, K_AC=1.8903, K_BA=2.6192, K_BC=1.7600, K_CB=3.0628, K_CC=3.8317
#
# 0.002816204447299242b_A=0.2078, b_B=0.6288, b_C=0.0000, V_A=2.5939, V_B=1.8997, V_C=2.2910, mu_A=0.0625, mu_B=0.2725, K_AA=3.3225, K_AB=3.5534, K_AC=1.5696, K_BA=2.2751, K_BC=1.4037, K_CB=5.0919, K_CC=4.5642
#
# 0.002726264763623476b_A=0.2374, b_B=0.7175, b_C=0.0000, V_A=2.5560, V_B=3.6987, V_C=2.3773, mu_A=0.0672, mu_B=0.5626, K_AA=3.7484, K_AB=2.9068, K_AC=1.7760, K_BA=2.1483, K_BC=1.6210, K_CB=9.0795, K_CC=4.0577
#
# 0.0027128446381539106b_A=0.1561, b_B=0.5558, b_C=0.0000, V_A=2.5388, V_B=3.2303, V_C=2.3187, mu_A=0.0450, mu_B=0.4483, K_AA=3.8306, K_AB=3.1354, K_AC=1.6389, K_BA=2.0938, K_BC=1.4720, K_CB=9.3126, K_CC=4.3775
#
# 0.0026981725823134184b_A=0.0423, b_B=0.2571, b_C=0.0000, V_A=2.4597, V_B=2.7988, V_C=2.1758, mu_A=0.0131, mu_B=0.2996, K_AA=4.3517, K_AB=3.5605, K_AC=1.3379, K_BA=1.8549, K_BC=1.1515, K_CB=13.0412, K_CC=5.2999
#
# 0.002693441230803728b_A=0.0035, b_B=0.0605, b_C=0.0000, V_A=2.2993, V_B=2.9138, V_C=1.9542, mu_A=0.0012, mu_B=0.1924, K_AA=5.9122, K_AB=4.2860, K_AC=0.9522, K_BA=1.4323, K_BC=0.7610, K_CB=33.4526, K_CC=7.2975
#
# 0.0026931585744023323b_A=0.0011, b_B=0.0308, b_C=0.0000, V_A=2.2253, V_B=3.1933, V_C=1.8633, mu_A=0.0004, mu_B=0.1676, K_AA=6.9209, K_AB=4.6432, K_AC=0.8195, K_BA=1.2637, K_BC=0.6334, K_CB=55.7855, K_CC=8.4029
#
# 0.0026930510066449642b_A=0.0004, b_B=0.0167, b_C=0.0000, V_A=2.1589, V_B=3.5865, V_C=1.7868, mu_A=0.0001, mu_B=0.1535, K_AA=8.0362, K_AB=4.9662, K_AC=0.7183, K_BA=1.1251, K_BC=0.5390, K_CB=91.7610, K_CC=9.5101
#
# 0.0026930170133709908b_A=0.0002, b_B=0.0122, b_C=0.0000, V_A=2.1256, V_B=3.8289, V_C=1.7496, mu_A=0.0001, mu_B=0.1479, K_AA=8.6810, K_AB=5.1317, K_AC=0.6723, K_BA=1.0600, K_BC=0.4970, K_CB=118.9256, K_CC=10.1190
#
# 0.002692988608032465b_A=0.0001, b_B=0.0086, b_C=0.0000, V_A=2.0884, V_B=4.1459, V_C=1.7088, mu_A=0.0000, mu_B=0.1427, K_AA=9.4833, K_AB=5.3194, K_AC=0.6244, K_BA=0.9905, K_BC=0.4539, K_CB=160.4305, K_CC=10.8475
#
# 0.0026929685845971107b_A=0.0001, b_B=0.0064, b_C=0.0000, V_A=2.0569, V_B=4.4556, V_C=1.6750, mu_A=0.0000, mu_B=0.1391, K_AA=10.2341, K_AB=5.4801, K_AC=0.5865, K_BA=0.9346, K_BC=0.4203, K_CB=208.0318, K_CC=11.5040
#
# 0.0026929667219519615b_A=0.0001, b_B=0.0061, b_C=0.0000, V_A=2.0533, V_B=4.4948, V_C=1.6712, mu_A=0.0000, mu_B=0.1388, K_AA=10.3249, K_AB=5.4984, K_AC=0.5823, K_BA=0.9284, K_BC=0.4166, K_CB=214.4411, K_CC=11.5810
#
# 0.002692964393645525b_A=0.0001, b_B=0.0058, b_C=0.0000, V_A=2.0475, V_B=4.5580, V_C=1.6649, mu_A=0.0000, mu_B=0.1382, K_AA=10.4751, K_AB=5.5289, K_AC=0.5755, K_BA=0.9182, K_BC=0.4107, K_CB=225.3053, K_CC=11.7095
#
# 0.0026929574087262154b_A=0.0000, b_B=0.0052, b_C=0.0000, V_A=2.0354, V_B=4.6879, V_C=1.6520, mu_A=0.0000, mu_B=0.1368, K_AA=10.7910, K_AB=5.5926, K_AC=0.5616, K_BA=0.8977, K_BC=0.3985, K_CB=249.3232, K_CC=11.9810
#
# 0.002692955080419779b_A=0.0000, b_B=0.0050, b_C=0.0000, V_A=2.0311, V_B=4.7349, V_C=1.6475, mu_A=0.0000, mu_B=0.1363, K_AA=10.9055, K_AB=5.6153, K_AC=0.5568, K_BA=0.8905, K_BC=0.3943, K_CB=258.4600, K_CC=12.0790
#
# 0.002692954149097204b_A=0.0000, b_B=0.0048, b_C=0.0000, V_A=2.0275, V_B=4.7764, V_C=1.6436, mu_A=0.0000, mu_B=0.1359, K_AA=11.0043, K_AB=5.6346, K_AC=0.5527, K_BA=0.8844, K_BC=0.3908, K_CB=266.5638, K_CC=12.1626
#
# 0.0026929457671940327b_A=0.0000, b_B=0.0039, b_C=0.0000, V_A=2.0074, V_B=5.0243, V_C=1.6225, mu_A=0.0000, mu_B=0.1343, K_AA=11.5735, K_AB=5.7407, K_AC=0.5308, K_BA=0.8512, K_BC=0.3718, K_CB=317.0841, K_CC=12.6325
#
# name 	 Originl 	 Estimated 	 Difference
# -------------------------------------------------------------------------------------------------------------
# b_A:	0.001		0.000		0.001
# b_B:	1.000		0.004		0.996
# b_C:	10.000		0.000		10.000
# V_A:	5.000		2.007		2.993
# V_B:	100.000		5.024		94.976
# V_C:	50.000		1.623		48.377
# mu_A:	0.100		0.000		0.100
# mu_B:	0.500		0.134		0.366
# K_AA:	5.000		11.574		6.574
# K_AB:	10.000		5.741		4.259
# K_AC:	5.000		0.531		4.469
# K_BA:	5.000		0.851		4.149
# K_BC:	5.000		0.372		4.628
# K_CB:	10.000		317.084		307.084
# K_CC:	5.000		12.633		7.633
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       Save the results at './outputs_zero_noise_identifiable'.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       End of the model './outputs_zero_noise_identifiable'.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       start running model 'solution_14'.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The selected device is cuda:1
# ============================================
# Epoch: 1
#  data loss:0.019346,
# data A loss:0.014991, data B loss:0.004127, data C loss:0.000228,
# Laplacian A loss:130.483497, Laplacian B loss:4.682597
#
# Validation loss:112.883244
# ============================================
# Epoch: 200
#  data loss:0.021299,
# data A loss:0.016959, data B loss:0.004070, data C loss:0.000269,
# Laplacian A loss:125.210596, Laplacian B loss:4.471269
#
# Validation loss:112.921033
# ============================================
# Epoch: 400
#  data loss:0.021449,
# data A loss:0.017220, data B loss:0.003893, data C loss:0.000336,
# Laplacian A loss:121.640804, Laplacian B loss:4.323419
#
# Validation loss:111.298335
# ============================================
# Epoch: 600
#  data loss:0.023536,
# data A loss:0.018888, data B loss:0.003814, data C loss:0.000833,
# Laplacian A loss:117.795391, Laplacian B loss:4.205147
#
# Validation loss:111.919431
# ============================================
# Epoch: 800
#  data loss:0.024501,
# data A loss:0.020077, data B loss:0.003814, data C loss:0.000611,
# Laplacian A loss:113.375525, Laplacian B loss:4.072757
#
# Validation loss:110.419347
# ============================================
# Epoch: 1000
#  data loss:0.023642,
# data A loss:0.019508, data B loss:0.003773, data C loss:0.000361,
# Laplacian A loss:111.091354, Laplacian B loss:4.012306
#
# Validation loss:113.224300
# ============================================
# Epoch: 1200
#  data loss:0.024160,
# data A loss:0.020193, data B loss:0.003784, data C loss:0.000183,
# Laplacian A loss:109.326703, Laplacian B loss:3.975504
#
# Validation loss:110.833369
# ============================================
# Epoch: 1400
#  data loss:0.024362,
# data A loss:0.020355, data B loss:0.003810, data C loss:0.000196,
# Laplacian A loss:108.284387, Laplacian B loss:3.949419
#
# Validation loss:109.431247
# ============================================
# Epoch: 1600
#  data loss:0.024148,
# data A loss:0.020158, data B loss:0.003795, data C loss:0.000195,
# Laplacian A loss:108.013992, Laplacian B loss:3.944849
#
# Validation loss:109.149759
# ============================================
# Epoch: 1800
#  data loss:0.024148,
# data A loss:0.020158, data B loss:0.003795, data C loss:0.000195,
# Laplacian A loss:108.013992, Laplacian B loss:3.944849
#
# Validation loss:109.149759
# ============================================
# Epoch: 2000
#  data loss:0.024148,
# data A loss:0.020158, data B loss:0.003795, data C loss:0.000195,
# Laplacian A loss:108.013992, Laplacian B loss:3.944849
#
# Validation loss:109.149759
# ============================================
# Epoch: 2200
#  data loss:0.024148,
# data A loss:0.020158, data B loss:0.003795, data C loss:0.000195,
# Laplacian A loss:108.013992, Laplacian B loss:3.944849
#
# Validation loss:109.149759
# ============================================
# Epoch: 2400
#  data loss:0.024148,
# data A loss:0.020158, data B loss:0.003795, data C loss:0.000195,
# Laplacian A loss:108.013992, Laplacian B loss:3.944849
#
# Validation loss:109.149759
# ============================================
# Epoch: 2600
#  data loss:0.024148,
# data A loss:0.020158, data B loss:0.003795, data C loss:0.000195,
# Laplacian A loss:108.013992, Laplacian B loss:3.944849
#
# Validation loss:109.149759
# ============================================
# Epoch: 2800
#  data loss:0.024148,
# data A loss:0.020158, data B loss:0.003795, data C loss:0.000195,
# Laplacian A loss:108.013992, Laplacian B loss:3.944849
#
# Validation loss:109.149759
# ============================================
# Epoch: 3000
#  data loss:0.024148,
# data A loss:0.020158, data B loss:0.003795, data C loss:0.000195,
# Laplacian A loss:108.013992, Laplacian B loss:3.944849
#
# Validation loss:109.149759
# ============================================
# Epoch: 3200
#  data loss:0.024148,
# data A loss:0.020158, data B loss:0.003795, data C loss:0.000195,
# Laplacian A loss:108.013992, Laplacian B loss:3.944849
#
# Validation loss:109.149759
# ============================================
# Epoch: 3400
#  data loss:0.024148,
# data A loss:0.020158, data B loss:0.003795, data C loss:0.000195,
# Laplacian A loss:108.013992, Laplacian B loss:3.944849
#
# Validation loss:109.149759
# ============================================
# Epoch: 3600
#  data loss:0.024148,
# data A loss:0.020158, data B loss:0.003795, data C loss:0.000195,
# Laplacian A loss:108.013992, Laplacian B loss:3.944849
#
# Validation loss:109.149759
# ============================================
# Epoch: 3800
#  data loss:0.024148,
# data A loss:0.020158, data B loss:0.003795, data C loss:0.000195,
# Laplacian A loss:108.013992, Laplacian B loss:3.944849
#
# Validation loss:109.149759
# ============================================
# Epoch: 4000
#  data loss:0.024148,
# data A loss:0.020158, data B loss:0.003795, data C loss:0.000195,
# Laplacian A loss:108.013992, Laplacian B loss:3.944849
#
# Validation loss:109.149759
# ============================================
# Epoch: 4200
#  data loss:0.024148,
# data A loss:0.020158, data B loss:0.003795, data C loss:0.000195,
# Laplacian A loss:108.013992, Laplacian B loss:3.944849
#
# Validation loss:109.149759
# ============================================
# Epoch: 4400
#  data loss:0.024148,
# ...
#
# 1.0476435422897339b_A=0.0036, b_B=0.0352, b_C=0.0000, V_A=2.6562, V_B=1837840.5561, V_C=2.7181, mu_A=0.0022, mu_B=0.6654, K_AA=6.2789, K_AB=91.3488, K_AC=2.7177, K_BA=2.5706, K_BC=2.7175, K_CB=2.7212, K_CC=2.7191
#
# 1.0476435422897339b_A=0.0034, b_B=0.0333, b_C=0.0000, V_A=2.6565, V_B=2126796.6536, V_C=2.7181, mu_A=0.0021, mu_B=0.6651, K_AA=6.3284, K_AB=94.7469, K_AC=2.7177, K_BA=2.5728, K_BC=2.7175, K_CB=2.7213, K_CC=2.7191
#
# 1.0476435422897339b_A=0.0033, b_B=0.0329, b_C=0.0000, V_A=2.6568, V_B=2198678.0510, V_C=2.7181, mu_A=0.0021, mu_B=0.6650, K_AA=6.3381, K_AB=95.5373, K_AC=2.7177, K_BA=2.5740, K_BC=2.7175, K_CB=2.7213, K_CC=2.7191
#
# 1.0476434230804443b_A=0.0032, b_B=0.0323, b_C=0.0000, V_A=2.6571, V_B=2319871.7831, V_C=2.7181, mu_A=0.0020, mu_B=0.6649, K_AA=6.3554, K_AB=96.8275, K_AC=2.7177, K_BA=2.5753, K_BC=2.7175, K_CB=2.7213, K_CC=2.7191
#
# 1.0476434230804443b_A=0.0032, b_B=0.0323, b_C=0.0000, V_A=2.6571, V_B=2319871.7831, V_C=2.7181, mu_A=0.0020, mu_B=0.6649, K_AA=6.3554, K_AB=96.8275, K_AC=2.7177, K_BA=2.5753, K_BC=2.7175, K_CB=2.7213, K_CC=2.7191
#
# 1.0476434230804443b_A=0.0032, b_B=0.0323, b_C=0.0000, V_A=2.6571, V_B=2319871.7831, V_C=2.7181, mu_A=0.0020, mu_B=0.6649, K_AA=6.3554, K_AB=96.8275, K_AC=2.7177, K_BA=2.5753, K_BC=2.7175, K_CB=2.7213, K_CC=2.7191
#
# 1.0476434230804443b_A=0.0032, b_B=0.0323, b_C=0.0000, V_A=2.6571, V_B=2319871.7831, V_C=2.7181, mu_A=0.0020, mu_B=0.6649, K_AA=6.3554, K_AB=96.8275, K_AC=2.7177, K_BA=2.5753, K_BC=2.7175, K_CB=2.7213, K_CC=2.7191
#
# 1.0476434230804443b_A=0.0032, b_B=0.0323, b_C=0.0000, V_A=2.6571, V_B=2319871.7831, V_C=2.7181, mu_A=0.0020, mu_B=0.6649, K_AA=6.3554, K_AB=96.8275, K_AC=2.7177, K_BA=2.5753, K_BC=2.7175, K_CB=2.7213, K_CC=2.7191
#
# 1.0476434230804443b_A=0.0032, b_B=0.0323, b_C=0.0000, V_A=2.6571, V_B=2319871.7831, V_C=2.7181, mu_A=0.0020, mu_B=0.6649, K_AA=6.3554, K_AB=96.8275, K_AC=2.7177, K_BA=2.5753, K_BC=2.7175, K_CB=2.7213, K_CC=2.7191
#
# 1.0476434230804443b_A=0.0032, b_B=0.0323, b_C=0.0000, V_A=2.6571, V_B=2319871.7831, V_C=2.7181, mu_A=0.0020, mu_B=0.6649, K_AA=6.3554, K_AB=96.8275, K_AC=2.7177, K_BA=2.5753, K_BC=2.7175, K_CB=2.7213, K_CC=2.7191
#
# 1.0476434230804443b_A=0.0032, b_B=0.0323, b_C=0.0000, V_A=2.6571, V_B=2319871.7831, V_C=2.7181, mu_A=0.0020, mu_B=0.6649, K_AA=6.3554, K_AB=96.8275, K_AC=2.7177, K_BA=2.5753, K_BC=2.7175, K_CB=2.7213, K_CC=2.7191
#
# 1.0476434230804443b_A=0.0032, b_B=0.0323, b_C=0.0000, V_A=2.6571, V_B=2319871.7831, V_C=2.7181, mu_A=0.0020, mu_B=0.6649, K_AA=6.3554, K_AB=96.8275, K_AC=2.7177, K_BA=2.5753, K_BC=2.7175, K_CB=2.7213, K_CC=2.7191
#
# 1.0476434230804443b_A=0.0032, b_B=0.0323, b_C=0.0000, V_A=2.6571, V_B=2319871.7831, V_C=2.7181, mu_A=0.0020, mu_B=0.6649, K_AA=6.3554, K_AB=96.8275, K_AC=2.7177, K_BA=2.5753, K_BC=2.7175, K_CB=2.7213, K_CC=2.7191
#
# 1.0476434230804443b_A=0.0032, b_B=0.0323, b_C=0.0000, V_A=2.6571, V_B=2319871.7831, V_C=2.7181, mu_A=0.0020, mu_B=0.6649, K_AA=6.3554, K_AB=96.8275, K_AC=2.7177, K_BA=2.5753, K_BC=2.7175, K_CB=2.7213, K_CC=2.7191
#
# 1.0476434230804443b_A=0.0032, b_B=0.0323, b_C=0.0000, V_A=2.6571, V_B=2319871.7831, V_C=2.7181, mu_A=0.0020, mu_B=0.6649, K_AA=6.3554, K_AB=96.8275, K_AC=2.7177, K_BA=2.5753, K_BC=2.7175, K_CB=2.7213, K_CC=2.7191
#
# name 	 Originl 	 Estimated 	 Difference
# -------------------------------------------------------------------------------------------------------------
# b_A:	0.001		0.003		0.002
# b_B:	10.000		0.032		9.968
# b_C:	0.100		0.000		0.100
# V_A:	25.000		2.657		22.343
# V_B:	100.000		2319871.783		2319771.783
# V_C:	10.000		2.718		7.282
# mu_A:	0.500		0.002		0.498
# mu_B:	5.000		0.665		4.335
# K_AA:	5.000		6.355		1.355
# K_AB:	5.000		96.827		91.827
# K_AC:	1.000		2.718		1.718
# K_BA:	5.000		2.575		2.425
# K_BC:	5.000		2.718		2.282
# K_CB:	50.000		2.721		47.279
# K_CC:	1.000		2.719		1.719
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       Save the results at './outputs_zero_noise_identifiable'.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       End of the model './outputs_zero_noise_identifiable'.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       start running model 'solution_78'.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The selected device is cuda:0
# ============================================
# Epoch: 1
#  data loss:0.018125,
# data A loss:0.013324, data B loss:0.004707, data C loss:0.000095,
# Laplacian A loss:100.754473, Laplacian B loss:3.193304
#
# Validation loss:103.892584
# ============================================
# Epoch: 200
#  data loss:0.018294,
# data A loss:0.014592, data B loss:0.003238, data C loss:0.000464,
# Laplacian A loss:92.987935, Laplacian B loss:2.870092
#
# Validation loss:98.811717
# ============================================
# Epoch: 400
#  data loss:0.019919,
# data A loss:0.016498, data B loss:0.003249, data C loss:0.000172,
# Laplacian A loss:83.849570, Laplacian B loss:2.581869
#
# Validation loss:94.007776
# ============================================
# Epoch: 600
#  data loss:0.022743,
# data A loss:0.019377, data B loss:0.003199, data C loss:0.000167,
# Laplacian A loss:70.981258, Laplacian B loss:2.191528
#
# Validation loss:95.065241
# ============================================
# Epoch: 800
#  data loss:0.021770,
# data A loss:0.018613, data B loss:0.003111, data C loss:0.000046,
# Laplacian A loss:60.066611, Laplacian B loss:1.892430
#
# Validation loss:86.081328
# ============================================
# Epoch: 1000
#  data loss:0.023168,
# data A loss:0.019927, data B loss:0.003070, data C loss:0.000171,
# Laplacian A loss:54.547722, Laplacian B loss:1.748227
#
# Validation loss:72.914538
# ============================================
# Epoch: 1200
#  data loss:0.021281,
# data A loss:0.018163, data B loss:0.003032, data C loss:0.000086,
# Laplacian A loss:51.156111, Laplacian B loss:1.676001
#
# Validation loss:72.157346
# ============================================
# Epoch: 1400
#  data loss:0.020914,
# data A loss:0.017818, data B loss:0.003024, data C loss:0.000072,
# Laplacian A loss:48.280218, Laplacian B loss:1.616889
#
# Validation loss:38.862706
# ============================================
# Epoch: 1600
#  data loss:0.020511,
# data A loss:0.017345, data B loss:0.003117, data C loss:0.000049,
# Laplacian A loss:45.727379, Laplacian B loss:1.567079
#
# Validation loss:47.393590
# ============================================
# Epoch: 1800
#  data loss:0.019473,
# data A loss:0.016409, data B loss:0.002975, data C loss:0.000090,
# Laplacian A loss:44.321014, Laplacian B loss:1.539807
#
# Validation loss:54.481684
# ============================================
# Epoch: 2000
#  data loss:0.019040,
# data A loss:0.016060, data B loss:0.002913, data C loss:0.000066,
# Laplacian A loss:43.057124, Laplacian B loss:1.495417
#
# Validation loss:58.426768
# ============================================
# Epoch: 2200
#  data loss:0.019736,
# data A loss:0.016729, data B loss:0.002954, data C loss:0.000053,
# Laplacian A loss:41.862274, Laplacian B loss:1.478824
#
# Validation loss:57.171933
# ============================================
# Epoch: 2400
#  data loss:0.021116,
# data A loss:0.017846, data B loss:0.003217, data C loss:0.000053,
# Laplacian A loss:40.861211, Laplacian B loss:1.461515
#
# Validation loss:43.414284
# ============================================
# Epoch: 2600
#  data loss:0.021021,
# data A loss:0.017895, data B loss:0.003074, data C loss:0.000053,
# Laplacian A loss:38.857036, Laplacian B loss:1.383919
#
# Validation loss:45.830657
# ============================================
# Epoch: 2800
#  data loss:0.020927,
# data A loss:0.017822, data B loss:0.003065, data C loss:0.000041,
# Laplacian A loss:37.499206, Laplacian B loss:1.361478
#
# Validation loss:41.232921
# ============================================
# Epoch: 3000
#  data loss:0.021200,
# data A loss:0.018102, data B loss:0.003048, data C loss:0.000050,
# Laplacian A loss:35.772611, Laplacian B loss:1.302259
#
# Validation loss:61.617014
# ============================================
# Epoch: 3200
#  data loss:0.021569,
# data A loss:0.018555, data B loss:0.002974, data C loss:0.000040,
# Laplacian A loss:34.854113, Laplacian B loss:1.282947
#
# Validation loss:54.695915
# ============================================
# Epoch: 3400
#  data loss:0.021538,
# data A loss:0.018560, data B loss:0.002939, data C loss:0.000039,
# Laplacian A loss:33.806180, Laplacian B loss:1.263637
#
# Validation loss:42.949313
# ============================================
# Epoch: 3600
#  data loss:0.022943,
# data A loss:0.019921, data B loss:0.002981, data C loss:0.000041,
# Laplacian A loss:32.681917, Laplacian B loss:1.255972
#
# Validation loss:41.917300
# ============================================
# Epoch: 3800
#  data loss:0.023279,
# data A loss:0.020301, data B loss:0.002938, data C loss:0.000040,
# Laplacian A loss:32.004642, Laplacian B loss:1.246702
#
# Validation loss:44.718338
# ============================================
# Epoch: 4000
#  data loss:0.022818,
# data A loss:0.019800, data B loss:0.002980, data C loss:0.000039,
# Laplacian A loss:31.434067, Laplacian B loss:1.238043
#
# Validation loss:45.396904
# ============================================
# Epoch: 4200
#  data loss:0.022791,
# data A loss:0.019765, data B loss:0.002988, data C loss:0.000038,
# Laplacian A loss:30.837767, Laplacian B loss:1.226370
#
# Validation loss:71.567638
# ============================================
# Epoch: 4400
#  data loss:0.022110,
# data A loss:0.019093, data B loss:0.002977, data C loss:0.000040,
# Laplacian A loss:30.179023, Laplacian B loss:1.207424
#
# Validation loss:67.684284
# ============================================
# Epoch: 4600
#  data loss:0.022109,
# data A loss:0.019091, data B loss:0.002980, data C loss:0.000038,
# Laplacian A loss:29.242604, Laplacian B loss:1.175754
#
# Validation loss:64.324759
# ============================================
# Epoch: 4800
#  data loss:0.021919,
# data A loss:0.018903, data B loss:0.002978, data C loss:0.000038,
# Laplacian A loss:28.716923, Laplacian B loss:1.169271
#
# Validation loss:63.672353
# ============================================
# Epoch: 5000
#  data loss:0.021684,
# data A loss:0.018687, data B loss:0.002955, data C loss:0.000043,
# Laplacian A loss:28.105331, Laplacian B loss:1.150058
#
# Validation loss:79.137603
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       Check the trained model 'solution_78' outputs.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# A diff:0.01867996938103589B diff:0.002954401628468338C diff:4.257393961692578e-05
# F_A actual:0.009733868295953303, F_A:0.027371622622013092, RMSE: 0.13941700583988909
# F_B actual:3.1367060667097206, F_B:7.530172348022461, RMSE: 2.262961086751208
# F_C actual:9.083394376932987e-06, F_C:1.4205726301952382e-06, RMSE: 0.0032291030870832183
#
# Laplacian A RMSE: 5.304366374341393
# Laplacian B RMSE: 1.0726138839163235
#
# dAdt RMSE: 0.13148218762273478
# dBdt RMSE: 2.276668562845727
# dCdt RMSE: 0.0032291030870832183
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       Estimates the parameters of the model 'solution_78'.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 168.9889678955078b_A=2.7183, b_B=2.7183, b_C=2.7183, V_A=2.7183, V_B=2.7183, V_C=2.7183, mu_A=2.7183, mu_B=2.7183, K_AA=2.7183, K_AB=2.7183, K_AC=2.7183, K_BA=2.7183, K_BC=2.7183, K_CB=2.7183, K_CC=2.7183
#
# 1.6828035116195679b_A=2.6813, b_B=3.0081, b_C=0.0744, V_A=2.7521, V_B=7.7127, V_C=2.7183, mu_A=0.7922, mu_B=1.0360, K_AA=2.7834, K_AB=3.8585, K_AC=2.7182, K_BA=2.8538, K_BC=2.7182, K_CB=2.7186, K_CC=2.7183
#
# 1.4227548837661743b_A=1.0658, b_B=1.7509, b_C=0.0019, V_A=2.7905, V_B=44.0822, V_C=2.7182, mu_A=0.3375, mu_B=1.1994, K_AA=3.2402, K_AB=5.7530, K_AC=2.7182, K_BA=3.0232, K_BC=2.7181, K_CB=2.7192, K_CC=2.7184
#
# 1.4032626152038574b_A=0.2290, b_B=2.0051, b_C=0.0018, V_A=3.1886, V_B=18.1362, V_C=2.7182, mu_A=0.1023, mu_B=1.7371, K_AA=5.9628, K_AB=3.6762, K_AC=2.7182, K_BA=5.0945, K_BC=2.7182, K_CB=2.7193, K_CC=2.7184
#
# 1.402665376663208b_A=0.0689, b_B=2.0041, b_C=0.0006, V_A=3.5441, V_B=17.9403, V_C=2.7182, mu_A=0.0473, mu_B=1.7733, K_AA=7.6751, K_AB=3.6144, K_AC=2.7182, K_BA=7.2422, K_BC=2.7181, K_CB=2.7197, K_CC=2.7184
#
# 1.4023302793502808b_A=0.1191, b_B=1.8671, b_C=0.0010, V_A=3.4327, V_B=18.2610, V_C=2.7182, mu_A=0.0925, mu_B=1.7942, K_AA=6.0140, K_AB=3.5918, K_AC=2.7182, K_BA=6.3229, K_BC=2.7181, K_CB=2.7204, K_CC=2.7184
#
# 1.401149034500122b_A=0.1028, b_B=1.6000, b_C=0.0011, V_A=3.5837, V_B=17.8682, V_C=2.7182, mu_A=0.2116, mu_B=1.7268, K_AA=4.4650, K_AB=3.5792, K_AC=2.7182, K_BA=6.7649, K_BC=2.7182, K_CB=2.7227, K_CC=2.7184
#
# 1.401149034500122b_A=0.1028, b_B=1.6000, b_C=0.0011, V_A=3.5837, V_B=17.8682, V_C=2.7182, mu_A=0.2116, mu_B=1.7268, K_AA=4.4650, K_AB=3.5792, K_AC=2.7182, K_BA=6.7649, K_BC=2.7182, K_CB=2.7227, K_CC=2.7184
#
# 1.401149034500122b_A=0.1028, b_B=1.6000, b_C=0.0011, V_A=3.5837, V_B=17.8682, V_C=2.7182, mu_A=0.2116, mu_B=1.7268, K_AA=4.4650, K_AB=3.5792, K_AC=2.7182, K_BA=6.7649, K_BC=2.7182, K_CB=2.7227, K_CC=2.7184
#
# 1.401149034500122b_A=0.1028, b_B=1.6000, b_C=0.0011, V_A=3.5837, V_B=17.8682, V_C=2.7182, mu_A=0.2116, mu_B=1.7268, K_AA=4.4650, K_AB=3.5792, K_AC=2.7182, K_BA=6.7649, K_BC=2.7182, K_CB=2.7227, K_CC=2.7184
#
# 1.401149034500122b_A=0.1028, b_B=1.6000, b_C=0.0011, V_A=3.5837, V_B=17.8682, V_C=2.7182, mu_A=0.2116, mu_B=1.7268, K_AA=4.4650, K_AB=3.5792, K_AC=2.7182, K_BA=6.7649, K_BC=2.7182, K_CB=2.7227, K_CC=2.7184
#
# 1.401149034500122b_A=0.1028, b_B=1.6000, b_C=0.0011, V_A=3.5837, V_B=17.8682, V_C=2.7182, mu_A=0.2116, mu_B=1.7268, K_AA=4.4650, K_AB=3.5792, K_AC=2.7182, K_BA=6.7649, K_BC=2.7182, K_CB=2.7227, K_CC=2.7184
#
# 1.401149034500122b_A=0.1028, b_B=1.6000, b_C=0.0011, V_A=3.5837, V_B=17.8682, V_C=2.7182, mu_A=0.2116, mu_B=1.7268, K_AA=4.4650, K_AB=3.5792, K_AC=2.7182, K_BA=6.7649, K_BC=2.7182, K_CB=2.7227, K_CC=2.7184
#
# 1.401149034500122b_A=0.1028, b_B=1.6000, b_C=0.0011, V_A=3.5837, V_B=17.8682, V_C=2.7182, mu_A=0.2116, mu_B=1.7268, K_AA=4.4650, K_AB=3.5792, K_AC=2.7182, K_BA=6.7649, K_BC=2.7182, K_CB=2.7227, K_CC=2.7184
#
# 1.401149034500122b_A=0.1028, b_B=1.6000, b_C=0.0011, V_A=3.5837, V_B=17.8682, V_C=2.7182, mu_A=0.2116, mu_B=1.7268, K_AA=4.4650, K_AB=3.5792, K_AC=2.7182, K_BA=6.7649, K_BC=2.7182, K_CB=2.7227, K_CC=2.7184
#
# 1.401149034500122b_A=0.1028, b_B=1.6000, b_C=0.0011, V_A=3.5837, V_B=17.8682, V_C=2.7182, mu_A=0.2116, mu_B=1.7268, K_AA=4.4650, K_AB=3.5792, K_AC=2.7182, K_BA=6.7649, K_BC=2.7182, K_CB=2.7227, K_CC=2.7184
#
# 1.401149034500122b_A=0.1028, b_B=1.6000, b_C=0.0011, V_A=3.5837, V_B=17.8682, V_C=2.7182, mu_A=0.2116, mu_B=1.7268, K_AA=4.4650, K_AB=3.5792, K_AC=2.7182, K_BA=6.7649, K_BC=2.7182, K_CB=2.7227, K_CC=2.7184
#
# 1.401149034500122b_A=0.1028, b_B=1.6000, b_C=0.0011, V_A=3.5837, V_B=17.8682, V_C=2.7182, mu_A=0.2116, mu_B=1.7268, K_AA=4.4650, K_AB=3.5792, K_AC=2.7182, K_BA=6.7649, K_BC=2.7182, K_CB=2.7227, K_CC=2.7184
#
# 1.401149034500122b_A=0.1028, b_B=1.6000, b_C=0.0011, V_A=3.5837, V_B=17.8682, V_C=2.7182, mu_A=0.2116, mu_B=1.7268, K_AA=4.4650, K_AB=3.5792, K_AC=2.7182, K_BA=6.7649, K_BC=2.7182, K_CB=2.7227, K_CC=2.7184
#
# 1.401149034500122b_A=0.1028, b_B=1.6000, b_C=0.0011, V_A=3.5837, V_B=17.8682, V_C=2.7182, mu_A=0.2116, mu_B=1.7268, K_AA=4.4650, K_AB=3.5792, K_AC=2.7182, K_BA=6.7649, K_BC=2.7182, K_CB=2.7227, K_CC=2.7184
#
# name 	 Originl 	 Estimated 	 Difference
# -------------------------------------------------------------------------------------------------------------
# b_A:	0.001		0.103		0.102
# b_B:	10.000		1.600		8.400
# b_C:	0.100		0.001		0.099
# V_A:	25.000		3.584		21.416
# V_B:	100.000		17.868		82.132
# V_C:	25.000		2.718		22.282
# mu_A:	0.500		0.212		0.288
# mu_B:	5.000		1.727		3.273
# K_AA:	5.000		4.465		0.535
# K_AB:	5.000		3.579		1.421
# K_AC:	1.000		2.718		1.718
# K_BA:	5.000		6.765		1.765
# K_BC:	10.000		2.718		7.282
# K_CB:	25.000		2.723		22.277
# K_CC:	1.000		2.718		1.718
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       Save the results at './outputs_zero_noise_identifiable'.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       End of the model './outputs_zero_noise_identifiable'.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
