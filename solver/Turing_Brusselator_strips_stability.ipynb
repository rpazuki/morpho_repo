# %% [markdown]
# > The equations are as follows
#
# <h3><center>$\partial_t u = D_u (\partial_x^2 + \partial_y^2)u + A - (B+1)u + u^2v$</center></h3>
#
# <h3><center>$\partial_t v = D_v (\partial_x^2 + \partial_y^2)v + Bu - u^2 v$</center></h3>
#
# With parameters  :
# - $D_u = 0.001, \quad D_v=0.1$.
# - $A = 1.0$.
# - $B = 1.21$.

# %%
# %config Completer.use_jedi = False
import numpy as np
import numba
import sys
sys.path.append("/end/home/rh2310/morpho_repo/turing_codebase")
from solvers.explicit_Euler import integrate
from solvers.turing_models import Brusselator

from matplotlib import pyplot as plt

# %%
n = (64, 64)
L = (.05, .05)

D_u = .001
D_v = 0.1
print(D_u/D_v)
A = 1.0
B = 1.21 - 0.05
Ds = np.array([D_u, D_v])
print(Ds)
print("A=", A)
print("B=", B)

#c0 = np.random.normal(scale=.1, size=(2, n[0], n[1]))
c0 = np.zeros((2, n[0], n[1]))
c0[0, :,:] += A
c0[1, :,:] += B/A
c0[0, :,:] += np.eye(n[0], n[1]) * .001
c0[1, :,:] += np.eye(n[0], n[1]) * .001


f_args = (A, B)
t = np.linspace(0, 100, 100)

dt = 0.0005

sol = integrate(c0, t, dt, n, L, Ds, Brusselator, f_args)
# Out:
# 0.01
# [0.001 0.1  ]
# A= 1.0
# B= 1.16

# %%
index =0
_ = plt.figure(figsize=(8,4))
plt.subplot(121)
plt.imshow(sol[0,:,:, index], cmap='BuGn', interpolation='gaussian')
plt.colorbar(shrink=.75)
plt.subplot(122)
plt.imshow(sol[1,:,:, index], cmap='BuGn', interpolation='gaussian')
plt.colorbar(shrink=.75)
plt.tight_layout()
plt.show()

index =-1
_ = plt.figure(figsize=(8,4))
plt.subplot(121)
plt.imshow(sol[0,:,:, index], cmap='BuGn', interpolation='gaussian')
plt.colorbar(shrink=.75)
plt.subplot(122)
plt.imshow(sol[1,:,:, index], cmap='BuGn', interpolation='gaussian')
plt.colorbar(shrink=.75)
plt.tight_layout()
plt.show()

# %%
n = (64, 64)
L = (.05, .05)

D_u = .001
D_v = 0.1
print(D_u/D_v)
A = 1.061
B = 1.21 
Ds = np.array([D_u, D_v])
print(Ds)
print("A=", A)
print("B=", B)


f_args = (A, B)
t = np.linspace(0, 100, 100)

dt = 0.0005

sol2 = integrate(c0, t, dt, n, L, Ds, Brusselator, f_args)
# Out:
# 0.01
# [0.001 0.1  ]
# A= 1.061
# B= 1.21

# %%
index =0
_ = plt.figure(figsize=(8,4))
plt.subplot(121)
plt.imshow(sol2[0,:,:, index], cmap='BuGn', interpolation='gaussian')
plt.colorbar(shrink=.75)
plt.subplot(122)
plt.imshow(sol2[1,:,:, index], cmap='BuGn', interpolation='gaussian')
plt.colorbar(shrink=.75)
plt.tight_layout()
plt.show()

index =-1
_ = plt.figure(figsize=(8,4))
plt.subplot(121)
plt.imshow(sol2[0,:,:, index], cmap='BuGn', interpolation='gaussian')
plt.colorbar(shrink=.75)
plt.subplot(122)
plt.imshow(sol2[1,:,:, index], cmap='BuGn', interpolation='gaussian')
plt.colorbar(shrink=.75)
plt.tight_layout()
plt.show()

# %%
n = (64, 64)
L = (.05, .05)

D_u = .001
D_v = 0.1
print(D_u/D_v)
A = 1.0
B = 1.21 + 0.05
Ds = np.array([D_u, D_v])
print(Ds)
print("A=", A)
print("B=", B)


f_args = (A, B)
t = np.linspace(0, 100, 100)

dt = 0.0005

sol3 = integrate(c0, t, dt, n, L, Ds, Brusselator, f_args)
# Out:
# 0.01
# [0.001 0.1  ]
# A= 1.0
# B= 1.26

# %%
index =0
_ = plt.figure(figsize=(8,4))
plt.subplot(121)
plt.imshow(sol3[0,:,:, index], cmap='BuGn', interpolation='gaussian')
plt.colorbar(shrink=.75)
plt.subplot(122)
plt.imshow(sol3[1,:,:, index], cmap='BuGn', interpolation='gaussian')
plt.colorbar(shrink=.75)
plt.tight_layout()
plt.show()

index =-1
_ = plt.figure(figsize=(8,4))
plt.subplot(121)
plt.imshow(sol3[0,:,:, index], cmap='BuGn', interpolation='gaussian')
plt.colorbar(shrink=.75)
plt.subplot(122)
plt.imshow(sol3[1,:,:, index], cmap='BuGn', interpolation='gaussian')
plt.colorbar(shrink=.75)
plt.tight_layout()
plt.show()

# %%
n = (64, 64)
L = (.05, .05)

D_u = .001
D_v = 0.1
print(D_u/D_v)
A = 1.0
B = 1.21 + 0.05
Ds = np.array([D_u, D_v])
print(Ds)
print("A=", A)
print("B=", B)


f_args = (A, B)
t = np.linspace(0, 100, 100)

dt = 0.0005

c0 = np.random.normal(scale=.1, size=(2, n[0], n[1]))
c0[0, :,:] += A
c0[1, :,:] += B/A

sol4 = integrate(c0, t, dt, n, L, Ds, Brusselator, f_args)
# Out:
# 0.01
# [0.001 0.1  ]
# A= 1.0
# B= 1.26

# %%
index =0
_ = plt.figure(figsize=(8,4))
plt.subplot(121)
plt.imshow(sol4[0,:,:, index], cmap='BuGn', interpolation='gaussian')
plt.colorbar(shrink=.75)
plt.subplot(122)
plt.imshow(sol4[1,:,:, index], cmap='BuGn', interpolation='gaussian')
plt.colorbar(shrink=.75)
plt.tight_layout()
plt.show()

index =-1
_ = plt.figure(figsize=(8,4))
plt.subplot(121)
plt.imshow(sol4[0,:,:, index], cmap='BuGn', interpolation='gaussian')
plt.colorbar(shrink=.75)
plt.subplot(122)
plt.imshow(sol4[1,:,:, index], cmap='BuGn', interpolation='gaussian')
plt.colorbar(shrink=.75)
plt.tight_layout()
plt.show()
