# %%
# %config Completer.use_jedi = False
import numpy as np
import numba
import sys
sys.path.append("/end/home/rh2310/morpho_repo/turing_codebase")
from solvers.explicit_Euler import integrate
from solvers.turing_models import Brusselator

from matplotlib import pyplot as plt

# %% [markdown]
# # Brusselator model
#
# > The equations are as follows
#
# <h3><center>$\partial_t u = D_u (\partial_x^2 + \partial_y^2)u + A - (B+1)u + u^2v$</center></h3>
#
# <h3><center>$\partial_t v = D_v (\partial_x^2 + \partial_y^2)v + Bu - u^2 v$</center></h3>
#
# With parameters  :
# - $D_u = 0.001, \quad D_v=1/900=0.00111111$
# - $A = 20$
# - $B = 400$
# - $n = (100, 100)$
# - $L = (0.005, 0.005)$
# - $dt = 10^{-4}$

# %%
n = (64, 64)
L = (.05, .05)

D_u = .001
D_v = 0.1#.002
print(D_u/D_v)
A = 1#9.002250562640661

Ds = np.array([D_u, D_v])
print(Ds)
#Bs = [1.13049110640674-.2, 1.13049110640674+.001, 1.13049110640674+.2]
Bs = [10, 15, 20, 25, 35]#np.linspace(1, 40, num=10, endpoint=True)
sols = []
for B in Bs:
    #B = B + 1.13049110640674
    print(f"B={B}")
    #c0 = np.random.normal(scale=.1, size=(2, n[0], n[1]))
    c0 = np.zeros((2, n[0], n[1]))
    c0[0, :,:] += A
    c0[1, :,:] += B/A
    c0[0, :,:] += np.eye(n[0], n[1]) * .001
    c0[1, :,:] += np.eye(n[0], n[1]) * .001


    f_args = (A, B)
    t = np.linspace(0, 50, 100)

    dt = 0.00001

    sol = integrate(c0, t, dt, n, L, Ds, Brusselator, f_args)
    index =0
    _ = plt.figure(figsize=(8,4))
    plt.subplot(121)
    plt.imshow(sol[0,:,:, index], cmap='BuGn', interpolation='gaussian')
    plt.colorbar(shrink=.75)
    plt.subplot(122)
    plt.imshow(sol[1,:,:, index], cmap='BuGn', interpolation='gaussian')
    plt.colorbar(shrink=.75)
    plt.show()

    index =-1
    _ = plt.figure(figsize=(8,4))
    plt.subplot(121)
    vmin = np.min(sol[0, :, :, 0])
    vmax = np.max(sol[0, :, :, 0])
    plt.imshow(sol[0,:,:, index], 
               cmap='BuGn',
               vmin=vmin,
               vmax=vmax,
               interpolation='gaussian')
    plt.colorbar(shrink=.75)
    plt.subplot(122)
    vmin = np.min(sol[1, :, :, 0])
    vmax = np.max(sol[1, :, :, 0])
    plt.imshow(sol[1,:,:, index],
               cmap='BuGn',
               vmin=vmin,
               vmax=vmax,
               interpolation='gaussian')
    plt.colorbar(shrink=.75)
    plt.show()
    
    sols += [sol]
# Out:
# 0.01
# [0.001 0.1  ]
# B=10
# B=15
# B=20
# B=25
# B=35

# %%
for B in [37, 40, 42]:
    #B = B + 1.13049110640674
    print(f"B={B}")
    #c0 = np.random.normal(scale=.1, size=(2, n[0], n[1]))
    c0 = np.zeros((2, n[0], n[1]))
    c0[0, :,:] += A
    c0[1, :,:] += B/A
    c0[0, :,:] += np.eye(n[0], n[1]) * .001
    c0[1, :,:] += np.eye(n[0], n[1]) * .001


    f_args = (A, B)
    t = np.linspace(0, 50, 100)

    dt = 0.00001

    sol = integrate(c0, t, dt, n, L, Ds, Brusselator, f_args)
    index =0
    _ = plt.figure(figsize=(8,4))
    plt.subplot(121)
    plt.imshow(sol[0,:,:, index], cmap='BuGn', interpolation='gaussian')
    plt.colorbar(shrink=.75)
    plt.subplot(122)
    plt.imshow(sol[1,:,:, index], cmap='BuGn', interpolation='gaussian')
    plt.colorbar(shrink=.75)
    plt.show()

    index =-1
    _ = plt.figure(figsize=(8,4))
    plt.subplot(121)
    vmin = np.min(sol[0, :, :, 0])
    vmax = np.max(sol[0, :, :, 0])
    plt.imshow(sol[0,:,:, index], 
               cmap='BuGn',
               vmin=vmin,
               vmax=vmax,
               interpolation='gaussian')
    plt.colorbar(shrink=.75)
    plt.subplot(122)
    vmin = np.min(sol[1, :, :, 0])
    vmax = np.max(sol[1, :, :, 0])
    plt.imshow(sol[1,:,:, index],
               cmap='BuGn',
               vmin=vmin,
               vmax=vmax,
               interpolation='gaussian')
    plt.colorbar(shrink=.75)
    plt.show()
    
    sols += [sol]
# Out:
# B=37
# The history saving thread hit an unexpected error (OperationalError('disk I/O error')).History will not be written to the database.
# B=40
# B=42

# %%
n = (64, 64)
L = (.05, .05)

D_u = .001
D_v = 0.1#.002
print(D_u/D_v)
A = .75#9.002250562640661
#R = 2.0
B =  31.5#2*R + A*A*(D_u/D_v) + 1 #3.04#81.9704926231558
Ds = np.array([D_u, D_v])
print(Ds)
print("A=", A)
#print("R=", R)
print("B=", B)

#c0 = np.random.normal(scale=.001, size=(2, n[0], n[1]))
c0 = np.zeros((2, n[0], n[1]))
c0[0, :,:] += A
c0[1, :,:] += B/A
c0[0, :,:] += np.eye(n[0], n[1]) * .001
c0[1, :,:] += np.eye(n[0], n[1]) * .001


f_args = (A, B)
t = np.linspace(0, 100, 100)

dt = 0.0001

sol = integrate(c0, t, dt, n, L, Ds, Brusselator, f_args)
# Out:
# 0.01
# [0.001 0.1  ]
# A= 0.75
# B= 31.5

# %%
# index =0
# _ = plt.figure(figsize=(8,4))
# plt.subplot(121)
# plt.imshow(sol[0,:,:, index], cmap='BuGn', interpolation='gaussian')
# plt.colorbar(shrink=.75)
# plt.subplot(122)
# plt.imshow(sol[1,:,:, index], cmap='BuGn', interpolation='gaussian')
# plt.colorbar(shrink=.75)
# plt.show()
index =7
_ = plt.figure(figsize=(8,4))
plt.subplot(121)
plt.imshow(sol[0,:,:, index], cmap='BuGn', interpolation='gaussian')
plt.colorbar(shrink=.75)
plt.subplot(122)
plt.imshow(sol[1,:,:, index], cmap='BuGn', interpolation='gaussian')
plt.colorbar(shrink=.75)
plt.show()
index =-1
_ = plt.figure(figsize=(8,4))
plt.subplot(121)
plt.imshow(sol[0,:,:, index], cmap='BuGn', interpolation='gaussian')
plt.colorbar(shrink=.75)
plt.subplot(122)
plt.imshow(sol[1,:,:, index], cmap='BuGn', interpolation='gaussian')
plt.colorbar(shrink=.75)
plt.show()

# %%
index =0
_ = plt.figure(figsize=(8,4))
plt.subplot(121)
plt.imshow(sol[0,:,:, index], cmap='BuGn', interpolation='gaussian')
plt.colorbar(shrink=.75)
plt.subplot(122)
plt.imshow(sol[1,:,:, index], cmap='BuGn', interpolation='gaussian')
plt.colorbar(shrink=.75)
plt.show()
index =-70
_ = plt.figure(figsize=(8,4))
plt.subplot(121)
plt.imshow(sol[0,:,:, index], cmap='BuGn', interpolation='gaussian')
plt.colorbar(shrink=.75)
plt.subplot(122)
plt.imshow(sol[1,:,:, index], cmap='BuGn', interpolation='gaussian')
plt.colorbar(shrink=.75)
plt.show()
index =-50
_ = plt.figure(figsize=(8,4))
plt.subplot(121)
plt.imshow(sol[0,:,:, index], cmap='BuGn', interpolation='gaussian')
plt.colorbar(shrink=.75)
plt.subplot(122)
plt.imshow(sol[1,:,:, index], cmap='BuGn', interpolation='gaussian')
plt.colorbar(shrink=.75)
plt.show()

# %%
import matplotlib as mpl
from matplotlib.animation import FuncAnimation
from matplotlib.animation import PillowWriter

fig = plt.figure()

index = 1
first_or_last = -1
vmin = np.min(sol[index, :, :, first_or_last])
vmax = np.max(sol[index, :, :, first_or_last])
levels=np.linspace(vmin, vmax, 10, endpoint = True)

im = plt.imshow(sol[index, :, :, 0], 
                cmap='BuGn',
                vmin=vmin,
                vmax=vmax,
                interpolation='gaussian')#, alpha=0.8)#  ,interpolation='none'

norm = mpl.colors.Normalize(vmin=vmin, vmax=vmax)
cb = fig.colorbar(mpl.cm.ScalarMappable(norm=norm, cmap='BuGn'))


def init():
    im.set_array(sol[index, :, :, 0] ) 
    return im,
   
def animate(i):
    #im.set_array(sol[index, :, :, i] ) 
    fig.clear()
    im = plt.imshow(sol[index, :, :, i], 
                    cmap='BuGn',
                    vmin=vmin,
                    vmax=vmax,
                    interpolation='gaussian')#, alpha=0.8)#  ,interpolation='none'
    cb = fig.colorbar(mpl.cm.ScalarMappable(norm=norm, cmap='BuGn'))
    return im,

anim = FuncAnimation(fig, animate, init_func=init,
                     frames=len(t), interval=20, blit=False, repeat=False)


anim.save('Brusselator_strips.gif', writer='imagemagick', fps = 30)
#writergif = PillowWriter(fps=20) 
#anim.save('Brusselator_strips.gif', writer=writergif, dpi=100)

# %%
import matplotlib as mpl
from matplotlib.animation import FuncAnimation
from matplotlib.animation import PillowWriter

fig = plt.figure()

index = 1
first_or_last = -1
vmin = np.min(sol[index, :, :, first_or_last])
vmax = np.max(sol[index, :, :, first_or_last])
levels=np.linspace(vmin, vmax, 10, endpoint = True)

im = plt.imshow(sol[index, :, :, 0], 
                cmap='BuGn',
                vmin=vmin,
                vmax=vmax,
                interpolation='gaussian')#, alpha=0.8)#  ,interpolation='none'

norm = mpl.colors.Normalize(vmin=vmin, vmax=vmax)
cb = fig.colorbar(mpl.cm.ScalarMappable(norm=norm, cmap='BuGn'))


def init():
    im.set_array(sol[index, :, :, 0] ) 
    return im,
   
def animate(i):
    #im.set_array(sol[index, :, :, i] ) 
    fig.clear()
    vmin = np.min(sol[index, :, :, i])
    vmax = np.max(sol[index, :, :, i])
    im = plt.imshow(sol[index, :, :, i], 
                    cmap='BuGn',
                    vmin=vmin,
                    vmax=vmax,
                    interpolation='gaussian')#, alpha=0.8)#  ,interpolation='none'
    norm = mpl.colors.Normalize(vmin=vmin, vmax=vmax)
    cb = fig.colorbar(mpl.cm.ScalarMappable(norm=norm, cmap='BuGn'))
    return im,

anim = FuncAnimation(fig, animate, init_func=init,
                     frames=len(t), interval=20, blit=False, repeat=False)


anim.save('Brusselator_strips.gif', writer='imagemagick', fps = 5)
#writergif = PillowWriter(fps=20) 
#anim.save('Brusselator_strips.gif', writer=writergif, dpi=100)
