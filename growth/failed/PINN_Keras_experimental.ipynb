# %%
# %config Completer.use_jedi = False
import sys
import warnings
warnings.filterwarnings('ignore')
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
import scipy.io
import time
import threading
import gc
import copy

sys.path.append("/end/home/rh2310/morpho_repo")
import turing as tu
from turing.utils import *
import turing.loss_functions as tu_loss

GPU = False
import os

if GPU:
    txt_device = 'gpu:0'
else:
    txt_device = 'cpu:0'    
    os.environ["CUDA_VISIBLE_DEVICES"]="-1"

# %%
def print_vals(name, value, actual=None):    
    
    if actual is not None and actual > 0:
        print(f"{name}: {value:0.8f}, actual: {actual:.3f}, "
              f"difference: {np.abs(actual-value):0.8f}, "
              f"relative: %{100*np.abs(actual-value)/(actual):0.8f}")
    elif actual is not None and actual == 0:
        print(f"{name}: {value:0.8f}, actual: {actual:.3f}, "
              f"difference: {np.abs(actual-value):0.8f} ")
        
    else:
        print(f"{name}: {value:0.8f}")
def print_model(model, D_a = 0.005, D_s = 0.2, kappa_def = 0.25, sigma_s_def= 0.02):
    
    
    sigma_s = model.losses[1].sigma_s.numpy()[0]
    rho_s = model.losses[1].rho_s.numpy()[0]

    sigma_a = model.losses[1].sigma_a.numpy()[0]
    rho_a = model.losses[1].rho_a.numpy()[0]
    mu_a = model.losses[1].mu_a.numpy()[0]
    kappa_a = model.losses[1].kappa_a.numpy()[0]



    print_vals("sigma_s", sigma_s*D_s, sigma_s_def)
    print_vals("rho_s", rho_s*D_s, 0.02)
    print()    
    print_vals("sigma_a", sigma_a*D_a, 0.0)
    print_vals("rho_a", rho_a*D_a,0.01)
    print_vals("mu_a", mu_a*D_a, 0.01 )
    print_vals("kappa_a", kappa_a, kappa_def)

# %%
def create_dataset(data,
                   T,
                   L,
                   training_data_size,
                   pde_data_size,
                   boundary_data_size,
                   with_boundary = True,
                   signal_to_noise = 0):
    x_domain = L*np.linspace(0,1,x_size)
    y_domain = L*np.linspace(0,1,y_size)

    X,Y = np.meshgrid(x_domain, y_domain, sparse=False, indexing='ij')
    XX = np.tile(X.flatten(), T) # N x T
    YY = np.tile(Y.flatten(), T) # N x T
    TT = np.repeat(t_star[-T:], N) # T x N

    AA = np.einsum('ijk->kij', data[0, :, :, -T:]).flatten() # N x T
    SS = np.einsum('ijk->kij', data[1, :, :, -T:]).flatten() # N x T


    x = XX[:, np.newaxis] # NT x 1
    y = YY[:, np.newaxis] # NT x 1
    t = TT[:, np.newaxis] # NT x 1

    a = AA[:, np.newaxis] # NT x 1
    s = SS[:, np.newaxis] # NT x 1

    boundary_x_LB = np.concatenate((x_domain, 
                                    np.repeat(x_domain[0], y_size)))
    boundary_x_RT = np.concatenate((x_domain, 
                                    np.repeat(x_domain[-1], y_size))) 

    boundary_y_LB = np.concatenate((np.repeat(y_domain[0], x_size),
                                    y_domain))
    boundary_y_RT = np.concatenate((np.repeat(y_domain[-1], x_size),
                                    y_domain)) 

    boundary_XX_LB = np.tile(boundary_x_LB.flatten(), T)[:, np.newaxis] # (x_size + y_size) x T, 1
    boundary_XX_RT = np.tile(boundary_x_RT.flatten(), T)[:, np.newaxis] # (x_size + y_size) x T, 1
    boundary_YY_LB = np.tile(boundary_y_LB.flatten(), T)[:, np.newaxis] # (x_size + y_size) x T, 1
    boundary_YY_RT = np.tile(boundary_y_RT.flatten(), T)[:, np.newaxis] # (x_size + y_size) x T, 1
    boundary_TT = np.repeat(t_star[-T:], (x_size + y_size))[:, np.newaxis] # T x (x_size + y_size), 1
    ##########################################
    # Including noise
    if signal_to_noise > 0:
        signal_amp_a = (np.max(AA)-np.min(AA))/2.0
        signal_amp_s = (np.max(SS)-np.min(SS))/2.0  
        sigma_a =  signal_amp_a*signal_to_noise
        sigma_s =  signal_amp_s*signal_to_noise
    # Observed data
    idx_data = np.random.choice(N*T, training_data_size, replace=False)
    # PDE colocations
    idx_pde = np.random.choice(N*T, pde_data_size, replace=False)
    # Periodic boundary condition
    idx_boundary = np.random.choice((x_size + y_size)*T, boundary_data_size, replace=False)
    
    # Lower/Upper bounds
    lb, ub = lower_upper_bounds([np.c_[XX, YY, TT]])
    
    ret = {'obs_input': np.c_[XX[idx_data], YY[idx_data],TT[idx_data]],
           'obs_output': np.c_[AA[idx_data], SS[idx_data]],
           'pde':   np.c_[XX[idx_pde], YY[idx_pde], TT[idx_pde]],
           'lb': lb,
           'ub': ub
          }
    
    if signal_to_noise > 0:        
        ret['obs_output'][0] += sigma_a * np.random.randn(len(idx_data), a.shape[1])
        ret['obs_output'][1] += sigma_s * np.random.randn(len(idx_data), s.shape[1])
    
    if with_boundary:
        ret = {**ret,
               **{'boundary_LB': np.c_[boundary_XX_LB[idx_boundary], 
                                       boundary_YY_LB[idx_boundary],
                                       boundary_TT[idx_boundary]],
                  'boundary_RT': np.c_[boundary_XX_RT[idx_boundary],
                                       boundary_YY_RT[idx_boundary],
                                       boundary_TT[idx_boundary]]
                 }
              }
    
    
    return ret

# %% [markdown]
# # Dataset 1

# %%
layers = [3, 64, 64, 64, 64, 2]
#layers = [3, 128, 128, 128, 128, 2]

#layers = [3, 100, 100, 100, 100, 2]

# Load Data
import os
data_path = os.path.abspath("turing.npy")
with open(data_path, 'rb') as f:
    data = np.load(f)
    
data_path = os.path.abspath("turing_t.npy")
with open(data_path, 'rb') as f:
    t_star = np.load(f) 
    
T = t_star.shape[0]    
    
L = 50
x_size = data.shape[1]
y_size = data.shape[2]
N = x_size*y_size

# %%
model_params_1 = {'training_data_size': T*32,
                'pde_data_size': (T*N)//(32),
                'boundary_data_size':((x_size + y_size)*T)//(8)}

dataset = create_dataset(data, T, L,**model_params_1)
lb = dataset['lb']
ub = dataset['ub']
obs_X = dataset['obs_input']
obs_Y = dataset['obs_output']
pde_X = dataset['pde']

# %%
pinn = tu.NN(layers, lb, ub)
loss_stack_1 = [tu_loss.Observations(pinn, obs_X, obs_Y),
                tu_loss.ASDM(pinn, pde_X)
               ]
model_1 = tu.TINN(pinn, loss_stack_1, optimizer=keras.optimizers.Adam())

# %%
arr_losses_1, samples_params_1 = \
         model_1.train_experimental(20000,
                       batch_size=dataset['obs_input'].shape[0]//8, 
                       print_iter=500,
                       sample_stats = True,
                       sample_params = True,
                       init_warmup = 100,
                       observation_index = 0,
                       pde_index = 1,
                       observation_error_threshold = 1e-4,
                       gradient_ratio = 10,
                       loss_update_ratio=1.2)
# Out:
# Epoch: 1, loss:73792.76
# Loss_observations:43157.16943359
# Loss_ASDM:30635.59155273 sigma_a:0:0.99203748, sigma_s:0:0.99200225, rho_a:0:0.99381524, rho_s:0:1.00302207, mu_a:0:1.00355315, kappa_a:0:1.00212133
# Time:2.65
#
# Epoch: 500, loss:65744.14
# Loss_observations:65717.18652344
# Loss_ASDM:26.95542145 sigma_a:0:0.78129876, sigma_s:0:0.81094199, rho_a:0:0.73110110, rho_s:0:1.28033423, mu_a:0:1.24262929, kappa_a:0:1.00834215
# Time:315.24
#
# Epoch: 1000, loss:59379.09
# Loss_observations:59153.50195312
# Loss_ASDM:225.59653854 sigma_a:0:0.00000000, sigma_s:0:0.51535320, rho_a:0:0.97160685, rho_s:0:0.74170983, mu_a:0:0.65649128, kappa_a:0:0.80761421
# Time:333.91
#
# Epoch: 1500, loss:12234.61
# Loss_observations:11564.41735840
# Loss_ASDM:670.19649506 sigma_a:0:0.00000000, sigma_s:0:0.09139833, rho_a:0:0.83746570, rho_s:0:0.07822527, mu_a:0:0.96236140, kappa_a:0:0.12244744
# Time:324.75
#
# Epoch: 2000, loss:4631.63
# Loss_observations:4110.28829956
# Loss_ASDM:521.33768845 sigma_a:0:0.00000000, sigma_s:0:0.08616466, rho_a:0:1.19762015, rho_s:0:0.08154863, mu_a:0:1.26361477, kappa_a:0:0.19552737
# Time:318.63
#
# Epoch: 2500, loss:2741.30
# Loss_observations:2256.76388550
# Loss_ASDM:484.53470612 sigma_a:0:0.00000000, sigma_s:0:0.08736377, rho_a:0:1.40521157, rho_s:0:0.08449868, mu_a:0:1.44739640, kappa_a:0:0.21997055
# Time:321.16
#
# Epoch: 3000, loss:1785.59
# Loss_observations:1325.65780640
# Loss_ASDM:459.93514633 sigma_a:0:0.00000000, sigma_s:0:0.08747688, rho_a:0:1.50994873, rho_s:0:0.08544816, mu_a:0:1.53943157, kappa_a:0:0.22960800
# Time:321.70
#
# Epoch: 3500, loss:1555.76
# Loss_observations:1111.42649841
# Loss_ASDM:444.32905197 sigma_a:0:0.00000000, sigma_s:0:0.08765119, rho_a:0:1.57245791, rho_s:0:0.08593890, mu_a:0:1.59505248, kappa_a:0:0.23511066
# Time:323.76
#
# Epoch: 4000, loss:1135.49
# Loss_observations:709.30959320
# Loss_ASDM:426.17875671 sigma_a:0:0.00000000, sigma_s:0:0.08732307, rho_a:0:1.61713409, rho_s:0:0.08643724, mu_a:0:1.63681459, kappa_a:0:0.23797251
# Time:325.28
#
# Epoch: 4500, loss:1027.96
# Loss_observations:607.16604614
# Loss_ASDM:420.79525375 sigma_a:0:0.00000000, sigma_s:0:0.08733894, rho_a:0:1.65847623, rho_s:0:0.08650303, mu_a:0:1.67540371, kappa_a:0:0.23973735
# Time:324.06
#
# Epoch: 5000, loss:1988.84
# Loss_observations:1522.72947693
# Loss_ASDM:466.11090088 sigma_a:0:0.00000000, sigma_s:0:0.08862668, rho_a:0:1.63414431, rho_s:0:0.08758458, mu_a:0:1.64880538, kappa_a:0:0.24050957
# Time:327.34
#
# Epoch: 5500, loss:1941.03
# Loss_observations:1470.94046021
# Loss_ASDM:470.08651352 sigma_a:0:0.00000000, sigma_s:0:0.08935668, rho_a:0:1.62092912, rho_s:0:0.08744785, mu_a:0:1.63717759, kappa_a:0:0.23875991
# Time:324.06
#
# Epoch: 6000, loss:1871.86
# Loss_observations:1404.35984802
# Loss_ASDM:467.49721527 sigma_a:0:0.00000000, sigma_s:0:0.08911026, rho_a:0:1.62785077, rho_s:0:0.08773874, mu_a:0:1.64463890, kappa_a:0:0.23954740
# Time:326.61
#
# Epoch: 6500, loss:1358.50
# Loss_observations:893.77571869
# Loss_ASDM:464.72778320 sigma_a:0:0.00000000, sigma_s:0:0.08878706, rho_a:0:1.64234591, rho_s:0:0.08807182, mu_a:0:1.65768373, kappa_a:0:0.24057408
# Time:327.94
#
# Epoch: 7000, loss:1307.08
# Loss_observations:844.09392548
# Loss_ASDM:462.98677826 sigma_a:0:0.00000000, sigma_s:0:0.08849730, rho_a:0:1.65925741, rho_s:0:0.08743846, mu_a:0:1.67319167, kappa_a:0:0.24249116
# Time:329.05
#
# Epoch: 7500, loss:1169.60
# Loss_observations:708.14103699
# Loss_ASDM:461.45925140 sigma_a:0:0.00000000, sigma_s:0:0.08890964, rho_a:0:1.68026066, rho_s:0:0.08794700, mu_a:0:1.69026220, kappa_a:0:0.24337105
# Time:328.13
#
# Epoch: 8000, loss:1173.59
# Loss_observations:712.71445465
# Loss_ASDM:460.87557983 sigma_a:0:0.00000000, sigma_s:0:0.08877481, rho_a:0:1.70159519, rho_s:0:0.08875736, mu_a:0:1.70858181, kappa_a:0:0.24486704
# Time:333.14
#
# Epoch: 8500, loss:1057.10
# Loss_observations:597.99412537
# Loss_ASDM:459.10950089 sigma_a:0:0.00000000, sigma_s:0:0.08893698, rho_a:0:1.72338998, rho_s:0:0.08821908, mu_a:0:1.72674000, kappa_a:0:0.24634250
# Time:336.06
#
# Epoch: 9000, loss:2177.81
# Loss_observations:1690.88993835
# Loss_ASDM:486.91804504 sigma_a:0:0.00000000, sigma_s:0:0.09001298, rho_a:0:1.68894267, rho_s:0:0.08887688, mu_a:0:1.69381928, kappa_a:0:0.24581085
# Time:341.92
#
# Epoch: 9500, loss:2152.31
# Loss_observations:1664.22932434
# Loss_ASDM:488.08408737 sigma_a:0:0.00000000, sigma_s:0:0.08937545, rho_a:0:1.69129074, rho_s:0:0.08897538, mu_a:0:1.69538200, kappa_a:0:0.24619962
# Time:341.46
#
# Epoch: 10000, loss:2451.78
# Loss_observations:1963.11248779
# Loss_ASDM:488.66405487 sigma_a:0:0.00000000, sigma_s:0:0.08949307, rho_a:0:1.70217907, rho_s:0:0.08958121, mu_a:0:1.70475340, kappa_a:0:0.24722193
# Time:342.67
#
# Epoch: 10500, loss:1978.20
# Loss_observations:1490.49093628
# Loss_ASDM:487.70798874 sigma_a:0:0.00000000, sigma_s:0:0.08963930, rho_a:0:1.71414816, rho_s:0:0.08948424, mu_a:0:1.71439373, kappa_a:0:0.24830407
# Time:346.38
#
# Epoch: 11000, loss:2186.74
# Loss_observations:1698.96720886
# Loss_ASDM:487.77718353 sigma_a:0:0.00000000, sigma_s:0:0.09003720, rho_a:0:1.72397935, rho_s:0:0.08963090, mu_a:0:1.72421622, kappa_a:0:0.24940436
# Time:345.82
#
# Epoch: 11500, loss:1977.04
# Loss_observations:1490.42897034
# Loss_ASDM:486.61169434 sigma_a:0:0.00000000, sigma_s:0:0.08998004, rho_a:0:1.73405159, rho_s:0:0.08978456, mu_a:0:1.73211110, kappa_a:0:0.25015575
# Time:348.94
#
# Epoch: 12000, loss:1661.36
# Loss_observations:1174.43760681
# Loss_ASDM:486.92057037 sigma_a:0:0.00000000, sigma_s:0:0.08975403, rho_a:0:1.74278450, rho_s:0:0.09045411, mu_a:0:1.73956764, kappa_a:0:0.25081944
# Time:350.90
#
# Epoch: 12500, loss:1640.34
# Loss_observations:1153.92440033
# Loss_ASDM:486.42043304 sigma_a:0:0.00000000, sigma_s:0:0.08975106, rho_a:0:1.75058162, rho_s:0:0.09054672, mu_a:0:1.74665034, kappa_a:0:0.25178564
# Time:352.01
#
# Epoch: 13000, loss:1502.82
# Loss_observations:1017.10927582
# Loss_ASDM:485.71316528 sigma_a:0:0.00046885, sigma_s:0:0.08981619, rho_a:0:1.75852561, rho_s:0:0.09070214, mu_a:0:1.75267351, kappa_a:0:0.25194189
# Time:353.74
#
# Epoch: 13500, loss:1732.33
# Loss_observations:1245.94596100
# Loss_ASDM:486.38771439 sigma_a:0:0.00000000, sigma_s:0:0.09021369, rho_a:0:1.76494765, rho_s:0:0.09038933, mu_a:0:1.75827265, kappa_a:0:0.25223187
# Time:355.07
#
# Epoch: 14000, loss:1586.62
# Loss_observations:1101.21012878
# Loss_ASDM:485.40508270 sigma_a:0:0.00003974, sigma_s:0:0.09021265, rho_a:0:1.77088463, rho_s:0:0.09057381, mu_a:0:1.76383042, kappa_a:0:0.25270846
# Time:355.60
#
# Epoch: 14500, loss:1406.20
# Loss_observations:921.77359009
# Loss_ASDM:484.42424774 sigma_a:0:0.00030413, sigma_s:0:0.09021153, rho_a:0:1.77679288, rho_s:0:0.09055582, mu_a:0:1.76841009, kappa_a:0:0.25280437
# Time:359.27
#
# Epoch: 15000, loss:1429.81
# Loss_observations:945.43859863
# Loss_ASDM:484.37562943 sigma_a:0:0.00062001, sigma_s:0:0.09019385, rho_a:0:1.78191495, rho_s:0:0.09061890, mu_a:0:1.77255714, kappa_a:0:0.25308022
# Time:355.27
#
# Epoch: 15500, loss:1232.69
# Loss_observations:748.24815369
# Loss_ASDM:484.44007492 sigma_a:0:0.00028694, sigma_s:0:0.09044228, rho_a:0:1.78627932, rho_s:0:0.09051481, mu_a:0:1.77772272, kappa_a:0:0.25375572
# Time:353.38
#
# Epoch: 16000, loss:1234.89
# Loss_observations:750.60231018
# Loss_ASDM:484.28763199 sigma_a:0:0.00062476, sigma_s:0:0.09020566, rho_a:0:1.79145908, rho_s:0:0.09113193, mu_a:0:1.78323913, kappa_a:0:0.25377244
# Time:354.15
#
# Epoch: 16500, loss:1340.49
# Loss_observations:856.54669952
# Loss_ASDM:483.94135666 sigma_a:0:0.00297728, sigma_s:0:0.09036940, rho_a:0:1.79862380, rho_s:0:0.09061913, mu_a:0:1.79162383, kappa_a:0:0.25337037
# Time:354.50
#
# Epoch: 17000, loss:1326.59
# Loss_observations:841.90621948
# Loss_ASDM:484.67929840 sigma_a:0:0.00452907, sigma_s:0:0.09059206, rho_a:0:1.80729830, rho_s:0:0.09066309, mu_a:0:1.80287755, kappa_a:0:0.25340599
# Time:358.17
#
# Epoch: 17500, loss:1246.81
# Loss_observations:761.54154205
# Loss_ASDM:485.26599121 sigma_a:0:0.00678811, sigma_s:0:0.09052075, rho_a:0:1.81671631, rho_s:0:0.09057519, mu_a:0:1.81448662, kappa_a:0:0.25329494
# Time:360.93
#
# Epoch: 18000, loss:1355.76
# Loss_observations:871.98777008
# Loss_ASDM:483.77645874 sigma_a:0:0.00866072, sigma_s:0:0.09010892, rho_a:0:1.82625198, rho_s:0:0.09065036, mu_a:0:1.82713914, kappa_a:0:0.25379699
# Time:356.83
#
# WARNING:tensorflow:5 out of the last 5 calls to <function TINN._train_batch_experimental_.<locals>.update_weights at 0x7f5bcc0bf7f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function TINN._train_batch_experimental_.<locals>.update_weights at 0x7f5bd0567130> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Epoch: 18500, loss:1200.74
# Loss_observations:715.55178833
# Loss_ASDM:485.19000626 sigma_a:0:0.01101387, sigma_s:0:0.09037556, rho_a:0:1.83667159, rho_s:0:0.09093998, mu_a:0:1.83973587, kappa_a:0:0.25323442
# Time:452.77
#
# Epoch: 19000, loss:1221.20
# Loss_observations:736.76722717
# Loss_ASDM:484.43512344 sigma_a:0:0.01305993, sigma_s:0:0.08997899, rho_a:0:1.84144366, rho_s:0:0.09088990, mu_a:0:1.84451461, kappa_a:0:0.25292584
# Time:359.89
#
# Epoch: 19500, loss:1169.25
# Loss_observations:684.03926849
# Loss_ASDM:485.20642090 sigma_a:0:0.01417008, sigma_s:0:0.09022687, rho_a:0:1.84706354, rho_s:0:0.09086074, mu_a:0:1.85139883, kappa_a:0:0.25252670
# Time:361.43
#
# Epoch: 20000, loss:1194.21
# Loss_observations:708.65875244
# Loss_ASDM:485.55369568 sigma_a:0:0.01517139, sigma_s:0:0.09004617, rho_a:0:1.85279965, rho_s:0:0.09099248, mu_a:0:1.85943842, kappa_a:0:0.25277999
# Time:359.84

# %%
param_names = [v.name for v in loss_stack_1[1].trainable_vars()]
params_len = len(param_names)
W_n = len(layers)-1

start = 0

_ = plt.figure(figsize=(16,5))
#plt.subplot(2,1,1)
for j in range(params_len):
    plt.plot(samples_params_1[start:,j], label=f"{param_names[j]}")

#plt.ylim([0,.28])
plt.grid()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

#plt.subplot(2,1,2)
fig = plt.figure(figsize=(16,5))
fig.patch.set_facecolor('white')
plt.plot(arr_losses_1[start:,0], label="Obs Loss")
plt.plot(arr_losses_1[start:,1], label="PDE Loss")
plt.grid()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
#plt.ylim([0,8000])

plt.show()

# %%
print_model(model_1)
# Out:
# sigma_s: 0.01800923, actual: 0.020, difference: 0.00199077, relative: %9.95382518
# rho_s: 0.01819850, actual: 0.020, difference: 0.00180150, relative: %9.00751948
#
# sigma_a: 0.00007586, actual: 0.000, difference: 0.00007586
# rho_a: 0.00926400, actual: 0.010, difference: 0.00073600, relative: %7.36001730
# mu_a: 0.00929719, actual: 0.010, difference: 0.00070281, relative: %7.02807903
# kappa_a: 0.25277999, actual: 0.250, difference: 0.00277999, relative: %1.11199617

# %% [markdown]
# # Dataset 2

# %%
data_path = os.path.abspath("turing_sigma_s_0_02_kappa_0.npy")
with open(data_path, 'rb') as f:
    data2 = np.load(f)
    
data_path = os.path.abspath("turing_t_sigma_s_0_02_kappa_0.npy")
with open(data_path, 'rb') as f:
    t_star2 = np.load(f) 
    
T2 = t_star2.shape[0]    
    
L2 = 50
x_size2 = data2.shape[1]
y_size2 = data2.shape[2]
N2 = x_size2*y_size2

# %%
model_params_2 = {'training_data_size': T2*32,
                'pde_data_size': (T2*N2)//(32),
                'boundary_data_size':((x_size2 + y_size2)*T2)//(8)}

dataset2 = create_dataset(data2, T2, L2,**model_params_2)
lb2 = dataset2['lb']
ub2 = dataset2['ub']
obs_X2 = dataset2['obs_input']
obs_Y2 = dataset2['obs_output']
pde_X2 = dataset2['pde']

# %%
pinn2 = tu.NN(layers, lb2, ub2)
loss_stack_2 = [tu_loss.Observations(pinn2, obs_X2, obs_Y2),
                tu_loss.ASDM(pinn2, pde_X2)
               ]
model_2 = tu.TINN(pinn2, loss_stack_2, optimizer=keras.optimizers.Adam())

# %%
arr_losses_2, samples_params_2 = \
         model_2.train_experimental(20000,
                       batch_size=dataset2['obs_input'].shape[0]//8, 
                       print_iter=500,
                       sample_stats = True,
                       sample_params = True,
                       init_warmup = 50,
                       observation_index = 0,
                       pde_index = 1,
                       observation_error_threshold = 1e-4,
                       gradient_ratio = 10,
                       loss_update_ratio=1.2)
# Out:
# Epoch: 1, loss:68493.22
# Loss_observations:38601.70849609
# Loss_ASDM:29891.51879883 sigma_a:0:0.99205494, sigma_s:0:0.99200237, rho_a:0:0.99781168, rho_s:0:1.00240445, mu_a:0:1.00475562, kappa_a:0:0.99408877
# Time:1.87
#
# Epoch: 500, loss:370143.16
# Loss_observations:370074.83203125
# Loss_ASDM:68.33126926 sigma_a:0:0.69653082, sigma_s:0:0.61062592, rho_a:0:0.85993570, rho_s:0:1.28174186, mu_a:0:1.10376894, kappa_a:0:0.69634181
# Time:323.78
#
# Epoch: 1000, loss:241470.38
# Loss_observations:239065.04687500
# Loss_ASDM:2405.31910706 sigma_a:0:0.00000000, sigma_s:0:0.06780713, rho_a:0:0.76221627, rho_s:0:0.07249776, mu_a:0:0.65820754, kappa_a:0:0.00000000
# Time:324.17
#
# Epoch: 1500, loss:60470.35
# Loss_observations:45902.83154297
# Loss_ASDM:14567.51586914 sigma_a:0:0.00000000, sigma_s:0:0.09790309, rho_a:0:1.69459307, rho_s:0:0.09449363, mu_a:0:1.67357767, kappa_a:0:0.00000000
# Time:327.07
#
# Epoch: 2000, loss:38079.48
# Loss_observations:25050.27783203
# Loss_ASDM:13029.19738770 sigma_a:0:0.00000000, sigma_s:0:0.10631692, rho_a:0:1.92297494, rho_s:0:0.09826870, mu_a:0:1.94643128, kappa_a:0:0.00000000
# Time:332.58
#
# Epoch: 2500, loss:30582.89
# Loss_observations:18617.76757812
# Loss_ASDM:11965.12744141 sigma_a:0:0.04212533, sigma_s:0:0.10301644, rho_a:0:2.14217901, rho_s:0:0.09606520, mu_a:0:2.21676850, kappa_a:0:0.00000000
# Time:332.49
#
# Epoch: 3000, loss:25840.73
# Loss_observations:14649.82470703
# Loss_ASDM:11190.90136719 sigma_a:0:0.14960913, sigma_s:0:0.10234269, rho_a:0:2.43809533, rho_s:0:0.09549730, mu_a:0:2.57176638, kappa_a:0:0.00000000
# Time:336.08
#
# Epoch: 3500, loss:240124.16
# Loss_observations:224720.54296875
# Loss_ASDM:15403.62524414 sigma_a:0:0.15013826, sigma_s:0:0.10259212, rho_a:0:2.38734341, rho_s:0:0.09861106, mu_a:0:2.54163790, kappa_a:0:0.00000000
# Time:338.27
#
# Epoch: 4000, loss:182550.64
# Loss_observations:167267.46484375
# Loss_ASDM:15283.15844727 sigma_a:0:0.07875612, sigma_s:0:0.10190348, rho_a:0:2.18149734, rho_s:0:0.09849902, mu_a:0:2.26527858, kappa_a:0:0.00000000
# Time:335.73
#
# Epoch: 4500, loss:147584.66
# Loss_observations:131701.51953125
# Loss_ASDM:15883.13598633 sigma_a:0:0.04886214, sigma_s:0:0.09968407, rho_a:0:2.08733511, rho_s:0:0.09868485, mu_a:0:2.13342428, kappa_a:0:0.00000000
# Time:342.00
#
# Epoch: 5000, loss:125052.18
# Loss_observations:107862.77050781
# Loss_ASDM:17189.41040039 sigma_a:0:0.04075225, sigma_s:0:0.09985033, rho_a:0:2.05902672, rho_s:0:0.09985026, mu_a:0:2.08527184, kappa_a:0:0.00000000
# Time:342.03
#
# Epoch: 5500, loss:116872.59
# Loss_observations:98264.62304688
# Loss_ASDM:18607.97265625 sigma_a:0:0.03917480, sigma_s:0:0.09912767, rho_a:0:2.05498219, rho_s:0:0.10035732, mu_a:0:2.07481170, kappa_a:0:0.00000000
# Time:343.78
#
# Epoch: 6000, loss:103160.88
# Loss_observations:84010.34179688
# Loss_ASDM:19150.53320312 sigma_a:0:0.05131677, sigma_s:0:0.09919738, rho_a:0:2.09178495, rho_s:0:0.10113348, mu_a:0:2.11944532, kappa_a:0:0.00000000
# Time:339.94
#
# Epoch: 6500, loss:92648.44
# Loss_observations:72887.77636719
# Loss_ASDM:19760.66723633 sigma_a:0:0.07527582, sigma_s:0:0.09945958, rho_a:0:2.16045237, rho_s:0:0.10173205, mu_a:0:2.20927668, kappa_a:0:0.00000000
# Time:342.42
#
# Epoch: 7000, loss:87210.48
# Loss_observations:66808.50195312
# Loss_ASDM:20401.97985840 sigma_a:0:0.10751481, sigma_s:0:0.09865928, rho_a:0:2.24303913, rho_s:0:0.10209534, mu_a:0:2.32388568, kappa_a:0:0.00000000
# Time:339.63
#
# Epoch: 7500, loss:82109.16
# Loss_observations:61043.43603516
# Loss_ASDM:21065.72094727 sigma_a:0:0.14371343, sigma_s:0:0.09889599, rho_a:0:2.33554411, rho_s:0:0.10163317, mu_a:0:2.45280266, kappa_a:0:0.00000000
# Time:339.21
#
# Epoch: 8000, loss:77190.34
# Loss_observations:55792.94726562
# Loss_ASDM:21397.39550781 sigma_a:0:0.17848730, sigma_s:0:0.09879462, rho_a:0:2.42394090, rho_s:0:0.10183017, mu_a:0:2.57462096, kappa_a:0:0.00000000
# Time:341.35
#
# Epoch: 8500, loss:76582.92
# Loss_observations:54900.87060547
# Loss_ASDM:21682.05224609 sigma_a:0:0.20761111, sigma_s:0:0.09918875, rho_a:0:2.49804592, rho_s:0:0.10147327, mu_a:0:2.67738485, kappa_a:0:0.00000000
# Time:341.09
#
# Epoch: 9000, loss:70335.92
# Loss_observations:48490.41601562
# Loss_ASDM:21845.50329590 sigma_a:0:0.22967462, sigma_s:0:0.09883963, rho_a:0:2.55405760, rho_s:0:0.10153984, mu_a:0:2.75528765, kappa_a:0:0.00000000
# Time:343.22
#
# Epoch: 9500, loss:66823.67
# Loss_observations:44618.54248047
# Loss_ASDM:22205.12817383 sigma_a:0:0.24668315, sigma_s:0:0.09889995, rho_a:0:2.59539175, rho_s:0:0.10154852, mu_a:0:2.81288385, kappa_a:0:0.00000000
# Time:342.60
#
# Epoch: 10000, loss:65702.12
# Loss_observations:43141.68750000
# Loss_ASDM:22560.44091797 sigma_a:0:0.26033211, sigma_s:0:0.09826513, rho_a:0:2.63184762, rho_s:0:0.10203946, mu_a:0:2.86341000, kappa_a:0:0.00000000
# Time:342.86
#
# Epoch: 10500, loss:61576.80
# Loss_observations:38883.19140625
# Loss_ASDM:22693.60156250 sigma_a:0:0.27235878, sigma_s:0:0.09884614, rho_a:0:2.66500258, rho_s:0:0.10161159, mu_a:0:2.90813923, kappa_a:0:0.00000000
# Time:346.86
#
# Epoch: 11000, loss:61329.67
# Loss_observations:38165.55273438
# Loss_ASDM:23164.11987305 sigma_a:0:0.28370449, sigma_s:0:0.09983629, rho_a:0:2.70227003, rho_s:0:0.10174826, mu_a:0:2.95773292, kappa_a:0:0.00000000
# Time:353.10
#
# Epoch: 11500, loss:57703.25
# Loss_observations:34308.51782227
# Loss_ASDM:23394.73486328 sigma_a:0:0.29499710, sigma_s:0:0.10017444, rho_a:0:2.74466562, rho_s:0:0.10252124, mu_a:0:3.01490998, kappa_a:0:0.00019139
# Time:353.91
#
# Epoch: 12000, loss:58720.45
# Loss_observations:35184.09082031
# Loss_ASDM:23536.35644531 sigma_a:0:0.30853650, sigma_s:0:0.10072911, rho_a:0:2.79804111, rho_s:0:0.10224814, mu_a:0:3.07611609, kappa_a:0:0.00010391
# Time:357.17
#
# Epoch: 12500, loss:55582.26
# Loss_observations:31648.34252930
# Loss_ASDM:23933.91577148 sigma_a:0:0.32020721, sigma_s:0:0.10130785, rho_a:0:2.86200595, rho_s:0:0.10276061, mu_a:0:3.14482212, kappa_a:0:0.00117035
# Time:358.93
#
# Epoch: 13000, loss:56075.06
# Loss_observations:31932.52026367
# Loss_ASDM:24142.53833008 sigma_a:0:0.33148700, sigma_s:0:0.10167836, rho_a:0:2.93248606, rho_s:0:0.10433254, mu_a:0:3.21696925, kappa_a:0:0.00151059
# Time:362.03
#
# Epoch: 13500, loss:134082.72
# Loss_observations:107166.47753906
# Loss_ASDM:26916.25024414 sigma_a:0:0.32660097, sigma_s:0:0.10199266, rho_a:0:2.91670895, rho_s:0:0.10305228, mu_a:0:3.19930482, kappa_a:0:0.00182493
# Time:363.67
#
# Epoch: 14000, loss:136226.94
# Loss_observations:108523.92187500
# Loss_ASDM:27703.00878906 sigma_a:0:0.30604979, sigma_s:0:0.10282032, rho_a:0:2.85923982, rho_s:0:0.10266939, mu_a:0:3.12976694, kappa_a:0:0.00202576
# Time:364.08
#
# Epoch: 14500, loss:131342.69
# Loss_observations:103224.73046875
# Loss_ASDM:28117.94799805 sigma_a:0:0.29035097, sigma_s:0:0.10372480, rho_a:0:2.81814241, rho_s:0:0.10240842, mu_a:0:3.07799220, kappa_a:0:0.00218399
# Time:364.88
#
# Epoch: 15000, loss:125445.42
# Loss_observations:96619.06250000
# Loss_ASDM:28826.35180664 sigma_a:0:0.28061950, sigma_s:0:0.10365331, rho_a:0:2.79394770, rho_s:0:0.10298426, mu_a:0:3.04799891, kappa_a:0:0.00208202
# Time:364.96
#
# Epoch: 15500, loss:127699.28
# Loss_observations:98974.14941406
# Loss_ASDM:28725.12817383 sigma_a:0:0.27469838, sigma_s:0:0.10415940, rho_a:0:2.78183556, rho_s:0:0.10221080, mu_a:0:3.03170943, kappa_a:0:0.00197464
# Time:367.51
#
# Epoch: 16000, loss:120368.30
# Loss_observations:90815.63769531
# Loss_ASDM:29552.66357422 sigma_a:0:0.27013069, sigma_s:0:0.10392981, rho_a:0:2.77757835, rho_s:0:0.10303509, mu_a:0:3.02287292, kappa_a:0:0.00158569
# Time:368.65
#
# Epoch: 16500, loss:133215.67
# Loss_observations:103564.55957031
# Loss_ASDM:29651.11303711 sigma_a:0:0.26646298, sigma_s:0:0.10429725, rho_a:0:2.77694631, rho_s:0:0.10354366, mu_a:0:3.02158761, kappa_a:0:0.00231606
# Time:368.69
#
# Epoch: 17000, loss:116148.60
# Loss_observations:86292.69140625
# Loss_ASDM:29855.90893555 sigma_a:0:0.26528698, sigma_s:0:0.10505241, rho_a:0:2.78034067, rho_s:0:0.10382131, mu_a:0:3.02284074, kappa_a:0:0.00134105
# Time:371.92
#
# Epoch: 17500, loss:109594.91
# Loss_observations:79216.07617188
# Loss_ASDM:30378.83374023 sigma_a:0:0.26269004, sigma_s:0:0.10644616, rho_a:0:2.78319240, rho_s:0:0.10347340, mu_a:0:3.02594852, kappa_a:0:0.00148763
# Time:371.30
#
# Epoch: 18000, loss:117252.77
# Loss_observations:86711.04101562
# Loss_ASDM:30541.72656250 sigma_a:0:0.26272300, sigma_s:0:0.10583474, rho_a:0:2.78767920, rho_s:0:0.10365067, mu_a:0:3.02857256, kappa_a:0:0.00190705
# Time:371.05
# Epoch: 18500, loss:116900.77
# Loss_observations:86581.50195312
# Loss_ASDM:30319.26513672 sigma_a:0:0.26082754, sigma_s:0:0.10643080, rho_a:0:2.79319572, rho_s:0:0.10456289, mu_a:0:3.03402495, kappa_a:0:0.00162263
# Time:369.71
#
# Epoch: 19000, loss:114485.39
# Loss_observations:83175.90429688
# Loss_ASDM:31309.48144531 sigma_a:0:0.26192966, sigma_s:0:0.10627183, rho_a:0:2.80120373, rho_s:0:0.10414926, mu_a:0:3.04040337, kappa_a:0:0.00160477
# Time:372.43
#
# Epoch: 19500, loss:107438.29
# Loss_observations:76570.23632812
# Loss_ASDM:30868.05688477 sigma_a:0:0.26117596, sigma_s:0:0.10704040, rho_a:0:2.80902100, rho_s:0:0.10528892, mu_a:0:3.04829836, kappa_a:0:0.00225054
# Time:373.47
#
# Epoch: 20000, loss:114886.52
# Loss_observations:83890.69921875
# Loss_ASDM:30995.82446289 sigma_a:0:0.26139268, sigma_s:0:0.10752778, rho_a:0:2.81695628, rho_s:0:0.10477836, mu_a:0:3.05518341, kappa_a:0:0.00182810
# Time:376.21

# %%
param_names = [v.name for v in loss_stack_2[1].trainable_vars()]
params_len = len(param_names)
W_n = len(layers)-1

start = 0

_ = plt.figure(figsize=(16,5))
#plt.subplot(2,1,1)
for j in range(params_len):
    plt.plot(samples_params_2[start:,j], label=f"{param_names[j]}")

#plt.ylim([0,.28])
plt.grid()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

#plt.subplot(2,1,2)
fig = plt.figure(figsize=(16,5))
fig.patch.set_facecolor('white')
plt.plot(arr_losses_2[start:,0], label="Obs Loss")
plt.plot(arr_losses_2[start:,1], label="PDE Loss")
plt.grid()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
#plt.ylim([0,8000])

plt.show()

# %%
print_model(model_1)
# Out:
# sigma_s: 0.01800923, actual: 0.020, difference: 0.00199077, relative: %9.95382518
# rho_s: 0.01819850, actual: 0.020, difference: 0.00180150, relative: %9.00751948
#
# sigma_a: 0.00007586, actual: 0.000, difference: 0.00007586
# rho_a: 0.00926400, actual: 0.010, difference: 0.00073600, relative: %7.36001730
# mu_a: 0.00929719, actual: 0.010, difference: 0.00070281, relative: %7.02807903
# kappa_a: 0.25277999, actual: 0.250, difference: 0.00277999, relative: %1.11199617

# %% [markdown]
# # Dataset 3

# %%
data_path = os.path.abspath("turing_sigma_s_0_03_kappa_0.npy")
with open(data_path, 'rb') as f:
    data3 = np.load(f)
    
data_path = os.path.abspath("turing_t_sigma_s_0_03_kappa_0.npy")
with open(data_path, 'rb') as f:
    t_star3 = np.load(f) 
    
T3 = t_star3.shape[0]    
    
L3 = 50
x_size3 = data3.shape[1]
y_size3 = data3.shape[2]
N3 = x_size3*y_size3

# %%
model_params_3 = {'training_data_size': T3*32,
                'pde_data_size': (T3*N3)//(32),
                'boundary_data_size':((x_size3 + y_size3)*T3)//(8)}

dataset3 = create_dataset(data3, T3, L3, **model_params_3)
lb3 = dataset3['lb']
ub3 = dataset3['ub']
obs_X3 = dataset3['obs_input']
obs_Y3 = dataset3['obs_output']
pde_X3 = dataset3['pde']

# %%
pinn3 = tu.NN(layers, lb3, ub3)
loss_stack_3 = [tu_loss.Observations(pinn3, obs_X3, obs_Y3),
                tu_loss.ASDM(pinn3, pde_X3)
               ]
model_3 = tu.TINN(pinn3, loss_stack_3, optimizer=keras.optimizers.Adam())

# %%
arr_losses_3, samples_params_3 = \
         model_3.train_experimental(20000,
                       batch_size=dataset3['obs_input'].shape[0]//8, 
                       print_iter=500,
                       sample_stats = True,
                       sample_params = True,
                       init_warmup = 100,
                       observation_index = 0,
                       pde_index = 1,
                       observation_error_threshold = 1e-4,
                       gradient_ratio = 10,
                       loss_update_ratio=1.2)
# Out:
# Epoch: 1, loss:77145.56
# Loss_observations:47521.32275391
# Loss_ASDM:29624.23559570 sigma_a:0:0.99206787, sigma_s:0:0.99200183, rho_a:0:0.99581969, rho_s:0:1.00661254, mu_a:0:1.00228822, kappa_a:0:0.99536961
# Time:1.84
#
# Epoch: 500, loss:178346.66
# Loss_observations:178314.30078125
# Loss_ASDM:32.37002897 sigma_a:0:0.92431277, sigma_s:0:0.77340961, rho_a:0:0.92004704, rho_s:0:1.30862761, mu_a:0:0.97828400, kappa_a:0:0.65095460
# Time:329.62
#
# Epoch: 1000, loss:177892.58
# Loss_observations:177866.32617188
# Loss_ASDM:26.25199676 sigma_a:0:0.69432163, sigma_s:0:0.73108333, rho_a:0:0.82463652, rho_s:0:1.24089432, mu_a:0:0.78813237, kappa_a:0:0.65311772
# Time:331.43
#
# Epoch: 1500, loss:177924.58
# Loss_observations:177906.19335938
# Loss_ASDM:18.39201379 sigma_a:0:0.42241254, sigma_s:0:0.66842049, rho_a:0:0.71291101, rho_s:0:1.16353118, mu_a:0:0.55637187, kappa_a:0:0.68270731
# Time:335.23
#
# Epoch: 2000, loss:177601.58
# Loss_observations:177593.63281250
# Loss_ASDM:7.94196719 sigma_a:0:0.17056914, sigma_s:0:0.58671868, rho_a:0:0.59087110, rho_s:0:1.09128463, mu_a:0:0.32570666, kappa_a:0:0.76056868
# Time:338.49
#
# Epoch: 2500, loss:73944.04
# Loss_observations:69089.03320312
# Loss_ASDM:4855.01080322 sigma_a:0:0.00000000, sigma_s:0:0.13323376, rho_a:0:1.10187876, rho_s:0:0.08507492, mu_a:0:1.08099115, kappa_a:0:0.00000000
# Time:343.11
#
# Epoch: 3000, loss:39245.77
# Loss_observations:32257.39233398
# Loss_ASDM:6988.36999512 sigma_a:0:0.00000000, sigma_s:0:0.15260538, rho_a:0:2.01821518, rho_s:0:0.09797103, mu_a:0:2.03328824, kappa_a:0:0.00000000
# Time:341.34
#
# Epoch: 3500, loss:27976.26
# Loss_observations:15947.16381836
# Loss_ASDM:12029.09814453 sigma_a:0:0.03525760, sigma_s:0:0.13774964, rho_a:0:2.33997560, rho_s:0:0.08816119, mu_a:0:2.40566754, kappa_a:0:0.00000000
# Time:344.45
#
# Epoch: 4000, loss:55094.80
# Loss_observations:46598.46875000
# Loss_ASDM:8496.32458496 sigma_a:0:0.18547641, sigma_s:0:0.15888779, rho_a:0:2.49650145, rho_s:0:0.10251024, mu_a:0:2.63588500, kappa_a:0:0.00000000
# Time:345.94
#
# Epoch: 4500, loss:38678.03
# Loss_observations:31861.12768555
# Loss_ASDM:6816.90893555 sigma_a:0:0.31878757, sigma_s:0:0.15677689, rho_a:0:2.65288758, rho_s:0:0.10151727, mu_a:0:2.87556767, kappa_a:0:0.00000000
# Time:344.13
#
# Epoch: 5000, loss:29299.49
# Loss_observations:22604.99926758
# Loss_ASDM:6694.49041748 sigma_a:0:0.41689458, sigma_s:0:0.15523218, rho_a:0:2.80103374, rho_s:0:0.10096721, mu_a:0:3.08486700, kappa_a:0:0.00006973
# Time:344.83
#
# Epoch: 5500, loss:27325.26
# Loss_observations:20260.59423828
# Loss_ASDM:7064.66955566 sigma_a:0:0.49041417, sigma_s:0:0.15533401, rho_a:0:2.93589902, rho_s:0:0.10128838, mu_a:0:3.26376820, kappa_a:0:0.00004608
# Time:347.18
#
# Epoch: 6000, loss:24148.10
# Loss_observations:16396.89294434
# Loss_ASDM:7751.21252441 sigma_a:0:0.57031244, sigma_s:0:0.15344782, rho_a:0:3.08794618, rho_s:0:0.10101745, mu_a:0:3.46578717, kappa_a:0:0.00004382
# Time:344.80
#
# Epoch: 6500, loss:22460.08
# Loss_observations:13898.74536133
# Loss_ASDM:8561.33001709 sigma_a:0:0.66595447, sigma_s:0:0.15288785, rho_a:0:3.25050187, rho_s:0:0.09978145, mu_a:0:3.69111133, kappa_a:0:0.00030228
# Time:345.21
#
# Epoch: 7000, loss:23654.40
# Loss_observations:13317.08654785
# Loss_ASDM:10337.31622314 sigma_a:0:0.77409154, sigma_s:0:0.14987563, rho_a:0:3.46064186, rho_s:0:0.09789233, mu_a:0:3.96748805, kappa_a:0:0.00063571
# Time:345.40
#
# Epoch: 7500, loss:99277.90
# Loss_observations:89653.69531250
# Loss_ASDM:9624.19555664 sigma_a:0:0.86340880, sigma_s:0:0.15490921, rho_a:0:3.50955653, rho_s:0:0.10261669, mu_a:0:4.08820391, kappa_a:0:0.00000000
# Time:348.32
#
# Epoch: 8000, loss:94393.74
# Loss_observations:85366.80175781
# Loss_ASDM:9026.93505859 sigma_a:0:0.86603314, sigma_s:0:0.15505856, rho_a:0:3.50523329, rho_s:0:0.10253660, mu_a:0:4.08701992, kappa_a:0:0.00000000
# Time:348.98
#
# Epoch: 8500, loss:86365.33
# Loss_observations:77337.12109375
# Loss_ASDM:9028.21514893 sigma_a:0:0.85379934, sigma_s:0:0.15466373, rho_a:0:3.48138523, rho_s:0:0.10249063, mu_a:0:4.05405807, kappa_a:0:0.00000000
# Time:347.96
#
# Epoch: 9000, loss:81632.03
# Loss_observations:72708.18261719
# Loss_ASDM:8923.85089111 sigma_a:0:0.83984017, sigma_s:0:0.15417635, rho_a:0:3.45278144, rho_s:0:0.10247833, mu_a:0:4.01358414, kappa_a:0:0.00000000
# Time:349.05
#
# Epoch: 9500, loss:71108.74
# Loss_observations:62333.58056641
# Loss_ASDM:8775.16833496 sigma_a:0:0.82380569, sigma_s:0:0.15419117, rho_a:0:3.42540097, rho_s:0:0.10303935, mu_a:0:3.97503281, kappa_a:0:0.00000000
# Time:350.78
#
# Epoch: 10000, loss:71989.85
# Loss_observations:63141.11962891
# Loss_ASDM:8848.73315430 sigma_a:0:0.80910641, sigma_s:0:0.15423448, rho_a:0:3.40013433, rho_s:0:0.10305283, mu_a:0:3.93859839, kappa_a:0:0.00000000
# Time:350.48
#
# Epoch: 10500, loss:67877.64
# Loss_observations:59026.63867188
# Loss_ASDM:8851.00177002 sigma_a:0:0.79499751, sigma_s:0:0.15393321, rho_a:0:3.37690520, rho_s:0:0.10356056, mu_a:0:3.90737510, kappa_a:0:0.00000000
# Time:351.46
#
# Epoch: 11000, loss:62346.68
# Loss_observations:53585.86132812
# Loss_ASDM:8760.81933594 sigma_a:0:0.78270650, sigma_s:0:0.15431300, rho_a:0:3.35663629, rho_s:0:0.10377157, mu_a:0:3.87746406, kappa_a:0:0.00000000
# Time:352.02
#
# Epoch: 11500, loss:60272.56
# Loss_observations:51506.07421875
# Loss_ASDM:8766.48547363 sigma_a:0:0.77084345, sigma_s:0:0.15538819, rho_a:0:3.33761573, rho_s:0:0.10269222, mu_a:0:3.85079169, kappa_a:0:0.00000000
# Time:353.71
#
# Epoch: 12000, loss:56609.59
# Loss_observations:47969.65039062
# Loss_ASDM:8639.94110107 sigma_a:0:0.75954276, sigma_s:0:0.15522398, rho_a:0:3.32159162, rho_s:0:0.10362233, mu_a:0:3.82674003, kappa_a:0:0.00000000
# Time:357.36
#
# Epoch: 12500, loss:57879.92
# Loss_observations:49332.01123047
# Loss_ASDM:8547.90356445 sigma_a:0:0.74926984, sigma_s:0:0.15578875, rho_a:0:3.30715871, rho_s:0:0.10382927, mu_a:0:3.80614781, kappa_a:0:0.00000000
# Time:359.27
#
# Epoch: 13000, loss:53935.24
# Loss_observations:45349.14453125
# Loss_ASDM:8586.10015869 sigma_a:0:0.74079007, sigma_s:0:0.15616573, rho_a:0:3.29591966, rho_s:0:0.10376853, mu_a:0:3.78913760, kappa_a:0:0.00000000
# Time:360.76
#
# Epoch: 13500, loss:52233.69
# Loss_observations:43785.40917969
# Loss_ASDM:8448.28308105 sigma_a:0:0.73531353, sigma_s:0:0.15527418, rho_a:0:3.28760791, rho_s:0:0.10467219, mu_a:0:3.77513885, kappa_a:0:0.00000000
# Time:368.58
#
# Epoch: 14000, loss:53688.00
# Loss_observations:45119.86718750
# Loss_ASDM:8568.14093018 sigma_a:0:0.72952849, sigma_s:0:0.15617578, rho_a:0:3.28103447, rho_s:0:0.10410958, mu_a:0:3.76637316, kappa_a:0:0.00000000
# Time:367.97
#
# Epoch: 14500, loss:51220.10
# Loss_observations:42694.16357422
# Loss_ASDM:8525.93945312 sigma_a:0:0.72653335, sigma_s:0:0.15699425, rho_a:0:3.27750492, rho_s:0:0.10369656, mu_a:0:3.76047873, kappa_a:0:0.00000000
# Time:368.83
#
# Epoch: 15000, loss:50271.50
# Loss_observations:41742.83349609
# Loss_ASDM:8528.66766357 sigma_a:0:0.72566283, sigma_s:0:0.15617467, rho_a:0:3.27726579, rho_s:0:0.10441307, mu_a:0:3.75955868, kappa_a:0:0.00000000
# Time:368.81
#
# Epoch: 15500, loss:59683.66
# Loss_observations:51126.78955078
# Loss_ASDM:8556.86767578 sigma_a:0:0.72508025, sigma_s:0:0.15687704, rho_a:0:3.27805519, rho_s:0:0.10399508, mu_a:0:3.76208091, kappa_a:0:0.00000000
# Time:369.13
#
# Epoch: 16000, loss:45096.93
# Loss_observations:36462.72607422
# Loss_ASDM:8634.20208740 sigma_a:0:0.72750670, sigma_s:0:0.15731119, rho_a:0:3.28268433, rho_s:0:0.10390995, mu_a:0:3.76748276, kappa_a:0:0.00000000
# Time:371.18
#
# Epoch: 16500, loss:43880.33
# Loss_observations:35244.97167969
# Loss_ASDM:8635.36163330 sigma_a:0:0.72990400, sigma_s:0:0.15744995, rho_a:0:3.28827953, rho_s:0:0.10421931, mu_a:0:3.77716136, kappa_a:0:0.00000000
# Time:375.01
#
# Epoch: 17000, loss:43453.14
# Loss_observations:34768.11059570
# Loss_ASDM:8685.03204346 sigma_a:0:0.73509413, sigma_s:0:0.15802874, rho_a:0:3.29721594, rho_s:0:0.10386429, mu_a:0:3.78823495, kappa_a:0:0.00000000
# Time:379.29
#
# Epoch: 17500, loss:45007.95
# Loss_observations:36230.36816406
# Loss_ASDM:8777.58087158 sigma_a:0:0.74094349, sigma_s:0:0.15699960, rho_a:0:3.30726671, rho_s:0:0.10437912, mu_a:0:3.80296206, kappa_a:0:0.00000000
# Time:378.61
#
# Epoch: 18000, loss:46083.97
# Loss_observations:37088.68750000
# Loss_ASDM:8995.28637695 sigma_a:0:0.74902749, sigma_s:0:0.15690991, rho_a:0:3.31939912, rho_s:0:0.10476597, mu_a:0:3.81992292, kappa_a:0:0.00000000
# Time:377.15
# Epoch: 18500, loss:42172.84
# Loss_observations:33149.61791992
# Loss_ASDM:9023.22009277 sigma_a:0:0.75690782, sigma_s:0:0.15719661, rho_a:0:3.33309221, rho_s:0:0.10466963, mu_a:0:3.83897448, kappa_a:0:0.00000000
# Time:367.89
#
# Epoch: 19000, loss:43744.19
# Loss_observations:34652.36401367
# Loss_ASDM:9091.82104492 sigma_a:0:0.76562184, sigma_s:0:0.15739851, rho_a:0:3.34762621, rho_s:0:0.10457817, mu_a:0:3.86078405, kappa_a:0:0.00000000
# Time:368.00

# %%
param_names = [v.name for v in loss_stack_3[1].trainable_vars()]
params_len = len(param_names)
W_n = len(layers)-1

start = 0

_ = plt.figure(figsize=(16,5))
#plt.subplot(2,1,1)
for j in range(params_len):
    plt.plot(samples_params_3[start:,j], label=f"{param_names[j]}")

#plt.ylim([0,.28])
plt.grid()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

#plt.subplot(2,1,2)
fig = plt.figure(figsize=(16,5))
fig.patch.set_facecolor('white')
plt.plot(arr_losses_3[start:,0], label="Obs Loss")
plt.plot(arr_losses_3[start:,1], label="PDE Loss")
plt.grid()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
#plt.ylim([0,8000])

plt.show()

# %%
print_model(model_3)

# %% [markdown]
# # Dataset 4

# %%
data_path = os.path.abspath("turing_model_2.npy")
with open(data_path, 'rb') as f:
    data4 = np.load(f)
    
data_path = os.path.abspath("turing_t_model_2.npy")
with open(data_path, 'rb') as f:
    t_star4 = np.load(f) 
    
T4 = t_star4.shape[0]    
    
L4 = 50
x_size4 = data4.shape[1]
y_size4 = data4.shape[2]
N4 = x_size4*y_size4

# %%
model_params_4 = {'training_data_size': T4*32,
                'pde_data_size': (T4*N4)//(32),
                'boundary_data_size':((x_size4 + y_size4)*T4)//(8)}

dataset4 = create_dataset(data4, T4, L4, **model_params_4)
lb4 = dataset4['lb']
ub4 = dataset4['ub']
obs_X4 = dataset4['obs_input']
obs_Y4 = dataset4['obs_output']
pde_X4 = dataset4['pde']

# %%
class schnakenberg(tu_loss.Truing_PDE):
    def __init__(self, 
                 pinn, 
                 inputs_pde, 
                 init_loss_weight = 1.0,
                 D_u = 10.0,
                 D_v = 10.0,
                 c_0 = 10.0,
                 c_1 = 10.0,
                 c_2 = 10.0                 
                ):
        super().__init__(pinn, inputs_pde, name="Loss_Schnakenberg", init_loss_weight= init_loss_weight)
        
        self.D_u = tf.Variable([D_u], dtype=tf.float32,
                                   name="D_u",
                                   constraint= lambda z: tf.clip_by_value(z, 0, 1e10))
        self.D_v = tf.Variable([D_v], dtype=tf.float32,
                                   name="D_v",
                                   constraint= lambda z: tf.clip_by_value(z, 0, 1e10))
        self.c_0 = tf.Variable([c_0], dtype=tf.float32,
                                   name="c_0",
                                   constraint= lambda z: tf.clip_by_value(z, 0, 1e10))
        self.c_1 = tf.Variable([c_1], dtype=tf.float32, 
                                   name="c_1",
                                   constraint= lambda z: tf.clip_by_value(z, 0, 1e10))
        self.c_2 = tf.Variable([c_2], dtype=tf.float32, 
                                name="c_2",
                                constraint= lambda z: tf.clip_by_value(z, 0, 1e10))
        
        
        
    def trainable_vars(self):
        return [self.D_u,
                self.D_v,
                self.c_0,
                self.c_1,                
                self.c_2]
        
    def pde(self, outputs, partials_1, partials_2):
        u = outputs[:, 0]
        v = outputs[:, 1]
        
        u_x = partials_1[0][:, 0]
        u_y = partials_1[0][:, 1]
        u_t = partials_1[0][:, 2]
        
        u_xx = partials_2[0][:, 0]
        u_yy = partials_2[0][:, 1]
        
        
        v_x = partials_1[1][:, 0]
        v_y = partials_1[1][:, 1]
        v_t = partials_1[1][:, 2]
        
        v_xx = partials_2[1][:, 0]
        v_yy = partials_2[1][:, 1]
        
        D_u = self.D_u
        D_v = self.D_v
        c_0 = self.c_0
        c_1 = self.c_1
        c_2 = self.c_2
               
        
        u2v = u*u*v
        f_u = u_t - D_u*(u_xx + u_yy) - c_1 + c_0*u -  u2v
        f_v = v_t - D_v*(v_xx + v_yy) - c_2 + u2v
        
        return tf.concat([tf.expand_dims(f_u, axis=1), 
                          tf.expand_dims(f_v, axis=1)], axis = 1)

# %%
pinn4 = tu.NN(layers, lb4, ub4)
loss_stack_4 = [tu_loss.Observations(pinn4, obs_X4, obs_Y4),
                schnakenberg(pinn4, pde_X4)
               ]
model_4 = tu.TINN(pinn4, loss_stack_4, optimizer=keras.optimizers.Adam())

# %%
arr_losses_4, samples_params_4 = \
         model_4.train_experimental(2000,
                       batch_size=dataset4['obs_input'].shape[0]//8, 
                       print_iter=100,
                       sample_stats = True,
                       sample_params = True,
                       init_warmup = 200,
                       observation_index = 0,
                       pde_index = 1,
                       observation_error_threshold = 1e-3,
                       gradient_ratio = 10,
                       loss_update_ratio=1.2)
# Out:
# Epoch: 1, loss:2980418.50
# Loss_observations:38347.56298828
# Loss_Schnakenberg:2942071.00000000 D_u:0:10.00289440, D_v:0:10.00511265, c_0:0:10.00401974, c_1:0:9.99207211, c_2:0:9.99199772
# Time:1.91
#
# Epoch: 100, loss:82730.62
# Loss_observations:81084.99316406
# Loss_Schnakenberg:1645.62626648 D_u:0:9.77659225, D_v:0:10.11851311, c_0:0:9.61560917, c_1:0:10.13084507, c_2:0:9.91655350
# Time:63.26
#
# Epoch: 200, loss:74798.59
# Loss_observations:73941.26269531
# Loss_Schnakenberg:857.33354950 D_u:0:9.58750153, D_v:0:10.20990372, c_0:0:9.14711761, c_1:0:10.33719254, c_2:0:9.82049274
# Time:63.06
#
# Epoch: 300, loss:670048.56
# Loss_observations:597738.22656250
# Loss_Schnakenberg:72310.27734375 D_u:0:9.15761662, D_v:0:11.12366199, c_0:0:8.35144043, c_1:0:10.88141918, c_2:0:8.64056301
# Time:68.14
#
# Epoch: 400, loss:605803.00
# Loss_observations:530032.01562500
# Loss_Schnakenberg:75770.97656250 D_u:0:9.09408379, D_v:0:11.92003918, c_0:0:8.25636578, c_1:0:10.95598316, c_2:0:7.72180462
# Time:63.99
#
# Epoch: 500, loss:546146.31
# Loss_observations:470594.54296875
# Loss_Schnakenberg:75551.79296875 D_u:0:9.08737946, D_v:0:12.70627403, c_0:0:8.25576305, c_1:0:10.95543098, c_2:0:6.87472725
# Time:64.17
#
# Epoch: 600, loss:488803.94
# Loss_observations:415160.25390625
# Loss_Schnakenberg:73643.69726562 D_u:0:9.11355782, D_v:0:13.55550480, c_0:0:8.29710579, c_1:0:10.91624165, c_2:0:6.05718184
# Time:65.00
#
# Epoch: 700, loss:433634.88
# Loss_observations:362576.94921875
# Loss_Schnakenberg:71057.92089844 D_u:0:9.19314671, D_v:0:14.42078209, c_0:0:8.38573742, c_1:0:10.82637215, c_2:0:5.25762510
# Time:65.19
#
# Epoch: 800, loss:381304.41
# Loss_observations:317060.78125000
# Loss_Schnakenberg:64243.60644531 D_u:0:9.34258175, D_v:0:15.25749016, c_0:0:8.52873135, c_1:0:10.67185307, c_2:0:4.47647190
# Time:66.32
#
# Epoch: 900, loss:333767.19
# Loss_observations:279946.68359375
# Loss_Schnakenberg:53820.49609375 D_u:0:9.54039478, D_v:0:16.01557541, c_0:0:8.72482872, c_1:0:10.44908237, c_2:0:3.72207093
# Time:68.25
#
# Epoch: 1000, loss:293882.38
# Loss_observations:253596.39257812
# Loss_Schnakenberg:40285.98681641 D_u:0:9.74645138, D_v:0:16.62365341, c_0:0:8.96144581, c_1:0:10.17719173, c_2:0:3.00900126
# Time:68.08
#
# Epoch: 1100, loss:263237.94
# Loss_observations:238596.98242188
# Loss_Schnakenberg:24640.94506836 D_u:0:9.94428253, D_v:0:17.13376999, c_0:0:9.21058273, c_1:0:9.89004612, c_2:0:2.35488415
# Time:66.10
#
# Epoch: 1200, loss:242949.27
# Loss_observations:230671.18164062
# Loss_Schnakenberg:12278.07824707 D_u:0:10.09313488, D_v:0:17.49477577, c_0:0:9.44116020, c_1:0:9.62220860, c_2:0:1.77809501
# Time:66.00
#
# Epoch: 1300, loss:231794.22
# Loss_observations:227074.74414062
# Loss_Schnakenberg:4719.47967529 D_u:0:10.19082069, D_v:0:17.74172974, c_0:0:9.63256550, c_1:0:9.40192413, c_2:0:1.30038834
# Time:67.02
#
# Epoch: 1400, loss:227005.08
# Loss_observations:225864.30859375
# Loss_Schnakenberg:1140.76480103 D_u:0:10.21705818, D_v:0:17.88193321, c_0:0:9.77410889, c_1:0:9.23825932, c_2:0:0.94601858
# Time:66.24
#
# Epoch: 1500, loss:225725.25
# Loss_observations:225508.91406250
# Loss_Schnakenberg:216.33849907 D_u:0:10.15483189, D_v:0:17.95846176, c_0:0:9.86234760, c_1:0:9.13514042, c_2:0:0.73199213
# Time:66.28
#
# Epoch: 1600, loss:225606.78
# Loss_observations:225503.44140625
# Loss_Schnakenberg:103.32593203 D_u:0:9.99855995, D_v:0:17.98510551, c_0:0:9.89895153, c_1:0:9.08709717, c_2:0:0.64180511
# Time:65.57
#
# Epoch: 1700, loss:225583.47
# Loss_observations:225527.86523438
# Loss_Schnakenberg:55.60358953 D_u:0:9.76604939, D_v:0:17.99147606, c_0:0:9.90598106, c_1:0:9.07046700, c_2:0:0.62014049
# Time:65.56
#
# Epoch: 1800, loss:225533.78
# Loss_observations:225483.62890625
# Loss_Schnakenberg:50.15952539 D_u:0:9.42785549, D_v:0:17.99045563, c_0:0:9.90209007, c_1:0:9.06550026, c_2:0:0.61779684
# Time:65.96
#
# Epoch: 1900, loss:225519.67
# Loss_observations:225452.82226562
# Loss_Schnakenberg:66.85089064 D_u:0:9.02601624, D_v:0:17.98642349, c_0:0:9.89635754, c_1:0:9.05962658, c_2:0:0.61776626
# Time:66.12
#
# Epoch: 2000, loss:225556.08
# Loss_observations:225441.34570312
# Loss_Schnakenberg:114.73798180 D_u:0:8.58778858, D_v:0:17.97714996, c_0:0:9.89210987, c_1:0:9.05360126, c_2:0:0.61774904
# Time:65.81

# %% [markdown]
# - $c_0 = 1$
# - $c_1 = 0.1$
# - $c_2 = 0.9/40 = 0.0225$
# - $c_3 = 1$
# - $c_4 = 1/40 = 0.025$

# %%
param_names = [v.name for v in loss_stack_4[1].trainable_vars()]
params_len = len(param_names)
W_n = len(layers)-1

start = 0

_ = plt.figure(figsize=(16,5))
#plt.subplot(2,1,1)
for j in range(params_len):
    plt.plot(samples_params_4[start:,j], label=f"{param_names[j]}")

#plt.ylim([0,4])
plt.grid()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

#plt.subplot(2,1,2)
fig = plt.figure(figsize=(16,5))
fig.patch.set_facecolor('white')
plt.plot(arr_losses_4[start:,0], label="Obs Loss")
plt.plot(arr_losses_4[start:,1], label="PDE Loss")
plt.grid()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
#plt.ylim([0,100000])

plt.show()

# %%
pinn5 = tu.NN(layers, lb4, ub4)
loss_stack_5 = [tu_loss.Observations(pinn5, obs_X4, obs_Y4),
                schnakenberg(pinn5, pde_X4)
               ]
model_5 = tu.TINN(pinn5, loss_stack_5, optimizer=keras.optimizers.Adam())

# %%
arr_losses_5, samples_params_5, _ = \
         model_5.train(2000,
                       batch_size=dataset4['obs_input'].shape[0]//8, 
                       print_iter=100,
                       stop_threshold=0,
                       regularised=False,
                       regularisation_freq=10,
                       sample_stats=True,
                       sample_params=True,
                       sample_gradiants=False)
# Out:
# Epoch: 1, loss:3036612.00
# Loss_observations:39002.06689453
# Loss_Schnakenberg:2997610.00000000 D_u:0:10.00332832, D_v:0:9.99283981, c_0:0:10.00487518, c_1:0:9.99205494, c_2:0:9.99199677
# Time:1.82
#
# Epoch: 100, loss:84091.55
# Loss_observations:82186.60156250
# Loss_Schnakenberg:1904.94584656 D_u:0:9.81897163, D_v:0:10.12058258, c_0:0:9.68456554, c_1:0:10.12393475, c_2:0:9.91856289
# Time:64.06
#
# Epoch: 200, loss:75827.93
# Loss_observations:74861.47558594
# Loss_Schnakenberg:966.45234680 D_u:0:9.65082550, D_v:0:10.26024437, c_0:0:9.24962425, c_1:0:10.33696270, c_2:0:9.81050682
# Time:64.17
#
# Epoch: 300, loss:70891.70
# Loss_observations:70307.47558594
# Loss_Schnakenberg:584.22786331 D_u:0:9.54437160, D_v:0:10.41462898, c_0:0:8.87620544, c_1:0:10.53074265, c_2:0:9.61463261
# Time:64.42
#
# Epoch: 400, loss:67844.12
# Loss_observations:67252.84863281
# Loss_Schnakenberg:591.27564621 D_u:0:9.49072170, D_v:0:10.57300472, c_0:0:8.61319160, c_1:0:10.67058086, c_2:0:9.29824352
# Time:65.54
#
# Epoch: 500, loss:64904.11
# Loss_observations:64308.36230469
# Loss_Schnakenberg:595.75384521 D_u:0:9.46942425, D_v:0:10.72862625, c_0:0:8.45852852, c_1:0:10.75406361, c_2:0:8.84215450
# Time:64.81
#
# Epoch: 600, loss:61417.30
# Loss_observations:60854.13330078
# Loss_Schnakenberg:563.17260361 D_u:0:9.46148014, D_v:0:10.88661098, c_0:0:8.37064648, c_1:0:10.80271626, c_2:0:8.25913239
# Time:65.70
#
# Epoch: 700, loss:57408.36
# Loss_observations:56811.16113281
# Loss_Schnakenberg:597.20272446 D_u:0:9.45766258, D_v:0:11.05784702, c_0:0:8.30790138, c_1:0:10.83876705, c_2:0:7.58245277
# Time:66.95
#
# Epoch: 800, loss:52967.66
# Loss_observations:52412.12597656
# Loss_Schnakenberg:555.53516388 D_u:0:9.45542336, D_v:0:11.25778389, c_0:0:8.25810146, c_1:0:10.86872387, c_2:0:6.84717751
# Time:67.23
#
# Epoch: 900, loss:48362.17
# Loss_observations:47776.50488281
# Loss_Schnakenberg:585.67232513 D_u:0:9.45418739, D_v:0:11.49737167, c_0:0:8.22553825, c_1:0:10.88938904, c_2:0:6.08018541
# Time:67.17
#
# Epoch: 1000, loss:43638.27
# Loss_observations:43057.41455078
# Loss_Schnakenberg:580.85288239 D_u:0:9.45381260, D_v:0:11.78750420, c_0:0:8.21648026, c_1:0:10.89518166, c_2:0:5.29809046
# Time:65.68
#
# Epoch: 1100, loss:38854.39
# Loss_observations:38280.76416016
# Loss_Schnakenberg:573.62210846 D_u:0:9.45421410, D_v:0:12.14655781, c_0:0:8.23931313, c_1:0:10.87608147, c_2:0:4.51049423
# Time:66.07
#
# Epoch: 1200, loss:34128.43
# Loss_observations:33542.51660156
# Loss_Schnakenberg:585.90977478 D_u:0:9.45660591, D_v:0:12.57656860, c_0:0:8.30188560, c_1:0:10.81727600, c_2:0:3.72507787
# Time:66.07
#
# Epoch: 1300, loss:29548.54
# Loss_observations:29026.89379883
# Loss_Schnakenberg:521.64457703 D_u:0:9.46830750, D_v:0:13.03907871, c_0:0:8.41857815, c_1:0:10.69782639, c_2:0:2.94946051
# Time:66.09
#
# Epoch: 1400, loss:25379.58
# Loss_observations:24941.98754883
# Loss_Schnakenberg:437.58944321 D_u:0:9.50699997, D_v:0:13.48184013, c_0:0:8.60694408, c_1:0:10.49635410, c_2:0:2.20165920
# Time:66.20
#
# Epoch: 1500, loss:22056.91
# Loss_observations:21812.40454102
# Loss_Schnakenberg:244.50323296 D_u:0:9.59188461, D_v:0:13.83952141, c_0:0:8.89334106, c_1:0:10.18032169, c_2:0:1.52472281
# Time:66.24
#
# Epoch: 1600, loss:20229.94
# Loss_observations:20151.20898438
# Loss_Schnakenberg:78.72685003 D_u:0:9.71735573, D_v:0:14.05200481, c_0:0:9.23764515, c_1:0:9.79373169, c_2:0:1.01603711
# Time:68.68
#
# Epoch: 1700, loss:19672.38
# Loss_observations:19662.34716797
# Loss_Schnakenberg:10.03306973 D_u:0:9.83622265, D_v:0:14.14077282, c_0:0:9.53501129, c_1:0:9.45893764, c_2:0:0.76276100
# Time:66.81
#
# Epoch: 1800, loss:19553.54
# Loss_observations:19550.32788086
# Loss_Schnakenberg:3.21145469 D_u:0:9.90888882, D_v:0:14.17790508, c_0:0:9.72457027, c_1:0:9.24595642, c_2:0:0.67412704
# Time:66.38
#
# Epoch: 1900, loss:19531.54
# Loss_observations:19525.62524414
# Loss_Schnakenberg:5.91838145 D_u:0:9.93878841, D_v:0:14.19892502, c_0:0:9.82215786, c_1:0:9.13675117, c_2:0:0.63967699
# Time:67.03
#
# Epoch: 2000, loss:19530.21
# Loss_observations:19522.44360352
# Loss_Schnakenberg:7.77126002 D_u:0:9.93685055, D_v:0:14.21204567, c_0:0:9.86674023, c_1:0:9.08748436, c_2:0:0.62573749
# Time:67.18

# %% [markdown]
# - $c_0 = 1$
# - $c_1 = 0.1$
# - $c_2 = 0.9/40 = 0.0225$
# - $c_3 = 1$
# - $c_4 = 1/40 = 0.025$

# %%
param_names = [v.name for v in loss_stack_5[1].trainable_vars()]
params_len = len(param_names)
W_n = len(layers)-1

start = 10

_ = plt.figure(figsize=(16,5))
#plt.subplot(2,1,1)
for j in range(params_len):
    plt.plot(samples_params_5[start:,j], label=f"{param_names[j]}")

#plt.ylim([0,4])
plt.grid()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

#plt.subplot(2,1,2)
fig = plt.figure(figsize=(16,5))
fig.patch.set_facecolor('white')
plt.plot(arr_losses_5[start:,0], label="Obs Loss")
plt.plot(arr_losses_5[start:,1], label="PDE Loss")
plt.grid()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
#plt.ylim([0,5000])

plt.show()

# %%
pinn6 = tu.NN(layers, lb4, ub4)
loss_stack_6 = [tu_loss.Observations(pinn6, obs_X4, obs_Y4, init_loss_weight=10.0),
                schnakenberg(pinn5, pde_X4)
               ]
model_6 = tu.TINN(pinn6, loss_stack_6, optimizer=keras.optimizers.Adam())

# %%
arr_losses_6, samples_params_6, _ = \
         model_6.train(1000,
                       batch_size=dataset4['obs_input'].shape[0]//8, 
                       print_iter=100,
                       stop_threshold=0,
                       regularised=False,
                       regularisation_freq=10,
                       sample_stats=True,
                       sample_params=True,
                       sample_gradiants=False)
# Out:
# Epoch: 1, loss:1834169.75
# Loss_observations:383477.78125000
# Loss_Schnakenberg:1450692.14062500 D_u:0:10.00799847, D_v:0:10.00799274, c_0:0:10.00799561, c_1:0:9.99200439, c_2:0:9.99199677
# Time:1.48
#
# Epoch: 100, loss:1406560.25
# Loss_observations:195156.85937500
# Loss_Schnakenberg:1211403.54687500 D_u:0:10.40133381, D_v:0:10.78403854, c_0:0:10.39423370, c_1:0:9.60572910, c_2:0:9.21507168
# Time:63.88
#
# Epoch: 200, loss:1202316.50
# Loss_observations:195049.31250000
# Loss_Schnakenberg:1007267.12500000 D_u:0:10.43755531, D_v:0:11.54094887, c_0:0:10.40644455, c_1:0:9.59340763, c_2:0:8.45734882
# Time:64.32
#
# Epoch: 300, loss:1021878.00
# Loss_observations:194870.98046875
# Loss_Schnakenberg:827006.99218750 D_u:0:10.47763443, D_v:0:12.27615833, c_0:0:10.40640068, c_1:0:9.59334755, c_2:0:7.72130394
# Time:64.24
#
# Epoch: 400, loss:848475.12
# Loss_observations:180240.11132812
# Loss_Schnakenberg:668234.94531250 D_u:0:10.53981304, D_v:0:12.99354744, c_0:0:10.40626812, c_1:0:9.59322071, c_2:0:7.00309229
# Time:64.41
#
# Epoch: 500, loss:647245.06
# Loss_observations:117964.18945312
# Loss_Schnakenberg:529280.82031250 D_u:0:10.63387394, D_v:0:13.69526291, c_0:0:10.40605450, c_1:0:9.59300041, c_2:0:6.30052471
# Time:64.52
#
# Epoch: 600, loss:487811.91
# Loss_observations:78853.66406250
# Loss_Schnakenberg:408958.26953125 D_u:0:10.77399349, D_v:0:14.38202953, c_0:0:10.40572739, c_1:0:9.59268379, c_2:0:5.61296368
# Time:65.09
#
# Epoch: 700, loss:325805.47
# Loss_observations:19446.28149414
# Loss_Schnakenberg:306359.19921875 D_u:0:10.97972298, D_v:0:15.05297375, c_0:0:10.40524769, c_1:0:9.59220505, c_2:0:4.94116974
# Time:64.20
#
# Epoch: 800, loss:224388.98
# Loss_observations:3693.32324219
# Loss_Schnakenberg:220695.64257812 D_u:0:11.27486515, D_v:0:15.70604897, c_0:0:10.40451431, c_1:0:9.59148407, c_2:0:4.28725386
# Time:64.63
#
# Epoch: 900, loss:153535.47
# Loss_observations:2361.50100708
# Loss_Schnakenberg:151173.97656250 D_u:0:11.68180656, D_v:0:16.33767509, c_0:0:10.40342712, c_1:0:9.59043503, c_2:0:3.65479064
# Time:66.35
#
# Epoch: 1000, loss:98797.85
# Loss_observations:1907.58432007
# Loss_Schnakenberg:96890.26855469 D_u:0:12.20940208, D_v:0:16.94239235, c_0:0:10.40178871, c_1:0:9.58886909, c_2:0:3.04917789
# Time:67.33

# %% [markdown]
# - $D_u = 1.0$
# - $D_v = 40$
# - $c_0 = 1.0$
# - $c_1 = 0.1$
# - $c_2 = 0.9$
# - $c_3 = 1.0$

# %%
param_names = [v.name for v in loss_stack_6[1].trainable_vars()]
params_len = len(param_names)
W_n = len(layers)-1

start = 10

_ = plt.figure(figsize=(16,5))
#plt.subplot(2,1,1)
for j in range(params_len):
    plt.plot(samples_params_6[start:,j], label=f"{param_names[j]}")

#plt.ylim([0,4])
plt.grid()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

#plt.subplot(2,1,2)
fig = plt.figure(figsize=(16,5))
fig.patch.set_facecolor('white')
plt.plot(arr_losses_6[start:,0], label="Obs Loss")
plt.plot(arr_losses_6[start:,1], label="PDE Loss")
plt.grid()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
#plt.ylim([0,1000])

plt.show()

# %%
arr_losses_7, samples_params_7, _ = \
         model_6.train(2000,
                       batch_size=dataset4['obs_input'].shape[0]//8, 
                       print_iter=100,
                       stop_threshold=0,
                       regularised=False,
                       regularisation_freq=10,
                       sample_stats=True,
                       sample_params=True,
                       sample_gradiants=False)
# Out:
# Epoch: 1, loss:98324.34
# Loss_observations:1903.50634766
# Loss_Schnakenberg:96420.83203125 D_u:0:12.21526814, D_v:0:16.94830322, c_0:0:10.40175343, c_1:0:9.58886623, c_2:0:3.04328132
# Time:0.60
#
# Epoch: 100, loss:58389.43
# Loss_observations:1663.97488403
# Loss_Schnakenberg:56725.45703125 D_u:0:12.84357548, D_v:0:17.51239014, c_0:0:10.39940357, c_1:0:9.58649445, c_2:0:2.47828388
# Time:70.66
#
# Epoch: 200, loss:30754.79
# Loss_observations:1526.61576843
# Loss_Schnakenberg:29228.17407227 D_u:0:13.55318165, D_v:0:18.03615570, c_0:0:10.39581203, c_1:0:9.58297253, c_2:0:1.95348871
# Time:69.76
#
# Epoch: 300, loss:13893.88
# Loss_observations:1412.54395294
# Loss_Schnakenberg:12481.33813477 D_u:0:14.30701351, D_v:0:18.49744034, c_0:0:10.39060593, c_1:0:9.57764244, c_2:0:1.49100912
# Time:69.97
#
# Epoch: 400, loss:5357.81
# Loss_observations:1360.47483826
# Loss_Schnakenberg:3997.33764648 D_u:0:15.08359051, D_v:0:18.87432861, c_0:0:10.38265514, c_1:0:9.57014561, c_2:0:1.11256123
# Time:70.17
#
# Epoch: 500, loss:2096.65
# Loss_observations:1282.95301056
# Loss_Schnakenberg:813.69212341 D_u:0:15.87073803, D_v:0:19.14276314, c_0:0:10.37147999, c_1:0:9.55929756, c_2:0:0.84179866
# Time:69.89
#
# Epoch: 600, loss:1368.79
# Loss_observations:1285.31859589
# Loss_Schnakenberg:83.46699905 D_u:0:16.66246986, D_v:0:19.29128838, c_0:0:10.35658646, c_1:0:9.54448986, c_2:0:0.68964827
# Time:69.96
#
# Epoch: 700, loss:1256.73
# Loss_observations:1249.85412598
# Loss_Schnakenberg:6.87232435 D_u:0:17.45566559, D_v:0:19.34235573, c_0:0:10.33826160, c_1:0:9.52642441, c_2:0:0.63284153
# Time:70.01
#
# Epoch: 800, loss:1321.47
# Loss_observations:1317.05535126
# Loss_Schnakenberg:4.41263568 D_u:0:18.24922180, D_v:0:19.34482765, c_0:0:10.31812000, c_1:0:9.50630093, c_2:0:0.62162459
# Time:72.41
#
# Epoch: 900, loss:1235.88
# Loss_observations:1231.50853729
# Loss_Schnakenberg:4.37508148 D_u:0:19.04286003, D_v:0:19.33259583, c_0:0:10.29659081, c_1:0:9.48552895, c_2:0:0.62076247
# Time:72.23
#
# Epoch: 1000, loss:1204.37
# Loss_observations:1200.01120758
# Loss_Schnakenberg:4.36007249 D_u:0:19.83650398, D_v:0:19.31307793, c_0:0:10.27415180, c_1:0:9.46418381, c_2:0:0.62074649
# Time:75.01
#
# Epoch: 1100, loss:1221.04
# Loss_observations:1216.71067810
# Loss_Schnakenberg:4.33281434 D_u:0:20.62999916, D_v:0:19.28389740, c_0:0:10.25376511, c_1:0:9.44245434, c_2:0:0.62074620
# Time:75.26
#
# Epoch: 1200, loss:1251.00
# Loss_observations:1246.68587494
# Loss_Schnakenberg:4.31454876 D_u:0:21.42321396, D_v:0:19.24048042, c_0:0:10.23308849, c_1:0:9.42251682, c_2:0:0.62074655
# Time:75.30
#
# Epoch: 1300, loss:1249.42
# Loss_observations:1245.12609863
# Loss_Schnakenberg:4.29381090 D_u:0:22.21658707, D_v:0:19.17576790, c_0:0:10.21126080, c_1:0:9.40235519, c_2:0:0.62074602
# Time:75.22
#
# Epoch: 1400, loss:1166.17
# Loss_observations:1161.90815735
# Loss_Schnakenberg:4.26654673 D_u:0:23.00992775, D_v:0:19.07967377, c_0:0:10.19041538, c_1:0:9.38173676, c_2:0:0.62074339
# Time:75.37
#
# Epoch: 1500, loss:1159.78
# Loss_observations:1155.53535461
# Loss_Schnakenberg:4.24654883 D_u:0:23.80329514, D_v:0:18.93768501, c_0:0:10.16931248, c_1:0:9.36064911, c_2:0:0.62074512
# Time:75.53
#
# Epoch: 1600, loss:1115.42
# Loss_observations:1111.19210815
# Loss_Schnakenberg:4.22367677 D_u:0:24.59660339, D_v:0:18.73011017, c_0:0:10.14836502, c_1:0:9.34000206, c_2:0:0.62074506
# Time:75.53
#
# Epoch: 1700, loss:1110.70
# Loss_observations:1106.49811554
# Loss_Schnakenberg:4.20160097 D_u:0:25.39000320, D_v:0:18.43319511, c_0:0:10.12722492, c_1:0:9.31904125, c_2:0:0.62075120
# Time:73.31
#
# Epoch: 1800, loss:1106.12
# Loss_observations:1101.93470001
# Loss_Schnakenberg:4.18383497 D_u:0:26.18333054, D_v:0:18.02493668, c_0:0:10.10610771, c_1:0:9.29823589, c_2:0:0.62074375
# Time:75.96
#
# Epoch: 1900, loss:1128.06
# Loss_observations:1123.89283752
# Loss_Schnakenberg:4.16964704 D_u:0:26.97651291, D_v:0:17.49699593, c_0:0:10.08512688, c_1:0:9.27852249, c_2:0:0.62073827
# Time:75.36
#
# Epoch: 2000, loss:1118.16
# Loss_observations:1114.01825714
# Loss_Schnakenberg:4.14034903 D_u:0:27.76989555, D_v:0:16.86396790, c_0:0:10.06451893, c_1:0:9.25756741, c_2:0:0.62074745
# Time:77.09

# %%
param_names = [v.name for v in loss_stack_6[1].trainable_vars()]
params_len = len(param_names)
W_n = len(layers)-1

start = 10

_ = plt.figure(figsize=(16,5))
#plt.subplot(2,1,1)
for j in range(params_len):
    plt.plot(samples_params_7[start:,j], label=f"{param_names[j]}")

#plt.ylim([0,4])
plt.grid()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

#plt.subplot(2,1,2)
fig = plt.figure(figsize=(16,5))
fig.patch.set_facecolor('white')
plt.plot(arr_losses_7[start:,0], label="Obs Loss")
plt.plot(arr_losses_7[start:,1], label="PDE Loss")
plt.grid()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
#plt.ylim([0,1000])

plt.show()

# %%
x_2 = L*np.linspace(0,1,x_size4)
y_2 = L*np.linspace(0,1,y_size4)

X_2,Y_2 = np.meshgrid(x_2, y_2, sparse=False, indexing='ij')
XX_2 = X_2.flatten()# N 
YY_2 = Y_2.flatten()# N 

index = -1#-1
t_test = 50000#t_star[index]#0#5000000


TT_2 = np.array([t_test]*N4) # N

x_2 = XX_2[:, np.newaxis] # N x 1
y_2 = YY_2[:, np.newaxis] # N x 1
t_2 = TT_2[:, np.newaxis] # N x 1

# %%
uv_2 = pinn6(np.hstack([x_2, y_2, t_2]), False)
u_2 = uv_2[:, 0].numpy()
v_2 = uv_2[:, 1].numpy()
u_2 = u_2.reshape((x_size4,y_size4))
v_2 = v_2.reshape((x_size4,y_size4))

# %%
plt.subplot(131)
plt.imshow(u_2)
plt.subplot(132)
plt.imshow(v_2)
plt.show()

# %%
UU = np.einsum('ijk->kij', data4[0, :, :, -t_test:]) # T x x_size x y_size
VV = np.einsum('ijk->kij', data4[1, :, :, -t_test:]) # T x x_size x y_size

# %%
L_obs = 0
for i,T in enumerate(t_star4):
    TT_2 = np.array([T]*N4) # N
    t_2 = TT_2[:, np.newaxis] # N x 1
    uv_2 = pinn6(np.hstack([x_2, y_2, t_2]), False)
    u_2 = uv_2[:, 0].numpy()
    v_2 = uv_2[:, 1].numpy()
    u_2 = u_2.reshape((x_size4,y_size4))
    v_2 = v_2.reshape((x_size4,y_size4))
    L_obs += np.sum(np.square(u_2 - UU[i,:, :])) + np.sum(np.square(v_2 - VV[i,:, :]))

# %%
np.sqrt(L_obs/10)/(512*32*32)
# Out:
# 4.30541163844145e-05

# %%
arr_losses_8, samples_params_8, _ = \
         model_6.train(1000,
                       batch_size=dataset4['obs_input'].shape[0]//8, 
                       print_iter=100,
                       stop_threshold=0,
                       regularised=False,
                       regularisation_freq=10,
                       sample_stats=True,
                       sample_params=True,
                       sample_gradiants=False)
# Out:
# Epoch: 1, loss:1096.62
# Loss_observations:1092.47930908
# Loss_Schnakenberg:4.14113355 D_u:0:27.77779007, D_v:0:16.85721016, c_0:0:10.06413364, c_1:0:9.25753975, c_2:0:0.62071997
# Time:0.55
#
# Epoch: 100, loss:1145.67
# Loss_observations:1141.54853058
# Loss_Schnakenberg:4.11662418 D_u:0:28.56313896, D_v:0:16.15670967, c_0:0:10.04290199, c_1:0:9.23713875, c_2:0:0.62071574
# Time:76.39
#
# Epoch: 200, loss:1130.48
# Loss_observations:1126.38321686
# Loss_Schnakenberg:4.09717026 D_u:0:29.35651398, D_v:0:15.40578270, c_0:0:10.02190971, c_1:0:9.21556759, c_2:0:0.62077141
# Time:71.77
#
# Epoch: 300, loss:1057.02
# Loss_observations:1052.93722534
# Loss_Schnakenberg:4.07948098 D_u:0:30.14978600, D_v:0:14.63234806, c_0:0:9.99983692, c_1:0:9.19500637, c_2:0:0.62074912
# Time:67.71
#
# Epoch: 400, loss:1104.89
# Loss_observations:1100.83106995
# Loss_Schnakenberg:4.05575168 D_u:0:30.94311714, D_v:0:13.84807396, c_0:0:9.97876835, c_1:0:9.17377186, c_2:0:0.62065291
# Time:68.03
#
# Epoch: 500, loss:1091.51
# Loss_observations:1087.47024155
# Loss_Schnakenberg:4.04003742 D_u:0:31.73628998, D_v:0:13.05890465, c_0:0:9.95722961, c_1:0:9.15351963, c_2:0:0.62099499
# Time:69.85
#
# Epoch: 600, loss:1107.03
# Loss_observations:1103.01221466
# Loss_Schnakenberg:4.01448780 D_u:0:32.52959061, D_v:0:12.26766777, c_0:0:9.93673706, c_1:0:9.13273430, c_2:0:0.62083840
# Time:69.83
#
# Epoch: 700, loss:1094.00
# Loss_observations:1089.99975586
# Loss_Schnakenberg:3.99759811 D_u:0:33.32286835, D_v:0:11.47543049, c_0:0:9.91531658, c_1:0:9.11212635, c_2:0:0.62084061
# Time:68.27
#
# Epoch: 800, loss:1096.32
# Loss_observations:1092.33896637
# Loss_Schnakenberg:3.97817853 D_u:0:34.11613846, D_v:0:10.68298244, c_0:0:9.89500618, c_1:0:9.09141159, c_2:0:0.62059885
# Time:68.94
#
# Epoch: 900, loss:1132.90
# Loss_observations:1128.94284058
# Loss_Schnakenberg:3.95751938 D_u:0:34.90953827, D_v:0:9.89037991, c_0:0:9.87348652, c_1:0:9.07080173, c_2:0:0.62041897
# Time:67.95
#
# Epoch: 1000, loss:1065.93
# Loss_observations:1062.00662231
# Loss_Schnakenberg:3.92764798 D_u:0:35.70283127, D_v:0:9.09769821, c_0:0:9.85239792, c_1:0:9.04927826, c_2:0:0.62068284
# Time:68.90

# %%
param_names = [v.name for v in loss_stack_4[1].trainable_vars()]
params_len = len(param_names)
W_n = len(layers)-1

start = 0

_ = plt.figure(figsize=(16,5))
#plt.subplot(2,1,1)
for j in range(params_len):
    plt.plot(samples_params_8[start:,j], label=f"{param_names[j]}")

#plt.ylim([0,4])
plt.grid()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

#plt.subplot(2,1,2)
fig = plt.figure(figsize=(16,5))
fig.patch.set_facecolor('white')
plt.plot(arr_losses_8[start:,0], label="Obs Loss")
plt.plot(arr_losses_8[start:,1], label="PDE Loss")
plt.grid()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
#plt.ylim([0,10])

plt.show()

# %%
class schnakenberg2(tu_loss.Truing_PDE):
    def __init__(self, 
                 pinn, 
                 inputs_pde, 
                 init_loss_weight = 1.0,
                 #D_u = 10.0,
                 #D_v = 10.0,
                 c_0 = 10.0#,
                 #c_1 = 10.0,
                 #c_2 = 10.0                 
                ):
        super().__init__(pinn, inputs_pde, name="Loss_Schnakenberg", init_loss_weight= init_loss_weight)
        
        #self.D_u = tf.Variable([D_u], dtype=tf.float32,
        #                           name="D_u",
        #                           constraint= lambda z: tf.clip_by_value(z, 0, 1e10))
        #self.D_v = tf.Variable([D_v], dtype=tf.float32,
        #                           name="D_v",
        #                           constraint= lambda z: tf.clip_by_value(z, 0, 1e10))
        self.c_0 = tf.Variable([c_0], dtype=tf.float32,
                                   name="c_0",
                                   constraint= lambda z: tf.clip_by_value(z, 0, 1e10))
#         self.c_1 = tf.Variable([c_1], dtype=tf.float32, 
#                                    name="c_1",
#                                    constraint= lambda z: tf.clip_by_value(z, 0, 1e10))
#         self.c_2 = tf.Variable([c_2], dtype=tf.float32, 
#                                 name="c_2",
#                                 constraint= lambda z: tf.clip_by_value(z, 0, 1e10))
        
        
        
    def trainable_vars(self):
        return [#self.D_u,
                #self.D_v,
                self.c_0,
                #self.c_1,                
                #self.c_2
               ]
        
    def pde(self, outputs, partials_1, partials_2):
        u = outputs[:, 0]
        v = outputs[:, 1]
        
        u_x = partials_1[0][:, 0]
        u_y = partials_1[0][:, 1]
        u_t = partials_1[0][:, 2]
        
        u_xx = partials_2[0][:, 0]
        u_yy = partials_2[0][:, 1]
        
        
        v_x = partials_1[1][:, 0]
        v_y = partials_1[1][:, 1]
        v_t = partials_1[1][:, 2]
        
        v_xx = partials_2[1][:, 0]
        v_yy = partials_2[1][:, 1]
        
        #D_u = self.D_u
        #D_v = self.D_v
        c_0 = self.c_0
        #c_1 = self.c_1
        #c_2 = self.c_2
               
        
        u2v = u*u*v
        f_u = u_t - 1.0*(u_xx + u_yy) - 0.1 + c_0*u -  u2v
        f_v = v_t - 40.0*(v_xx + v_yy) - 0.9 + u2v
        
        return tf.concat([tf.expand_dims(f_u, axis=1), 
                          tf.expand_dims(f_v, axis=1)], axis = 1)

# %%
pinn9 = tu.NN(layers, lb4, ub4)
loss_stack_9 = [tu_loss.Observations(pinn9, obs_X4, obs_Y4),
                schnakenberg2(pinn9, pde_X4)
               ]
model_9 = tu.TINN(pinn9, loss_stack_9, optimizer=keras.optimizers.Adam())

# %%
arr_losses_9, samples_params_9, _ = \
         model_9.train(2000,
                       batch_size=dataset4['obs_input'].shape[0]//8, 
                       print_iter=100,
                       stop_threshold=0,
                       regularised=False,
                       regularisation_freq=10,
                       sample_stats=True,
                       sample_params=True,
                       sample_gradiants=False)
# Out:
# Epoch: 1, loss:68371.06
# Loss_observations:40733.97802734
# Loss_Schnakenberg:27637.08886719 c_0:0:9.99433422
# Time:1.83
#
# Epoch: 100, loss:47887.27
# Loss_observations:34539.33789062
# Loss_Schnakenberg:13347.93286133 c_0:0:9.89167404
# Time:69.87
#
# Epoch: 200, loss:47893.39
# Loss_observations:34519.97753906
# Loss_Schnakenberg:13373.41333008 c_0:0:9.67602634
# Time:65.48
#
# Epoch: 300, loss:47888.84
# Loss_observations:34482.13793945
# Loss_Schnakenberg:13406.70068359 c_0:0:9.31594372
# Time:69.45
#
# Epoch: 400, loss:47854.46
# Loss_observations:34414.33959961
# Loss_Schnakenberg:13440.12280273 c_0:0:8.77051640
# Time:68.19
#
# Epoch: 500, loss:47794.18
# Loss_observations:34302.85156250
# Loss_Schnakenberg:13491.32714844 c_0:0:8.02111816
# Time:67.69
#
# Epoch: 600, loss:47674.78
# Loss_observations:34110.53320312
# Loss_Schnakenberg:13564.24719238 c_0:0:7.09402847
# Time:70.27
#
# Epoch: 700, loss:47475.95
# Loss_observations:33804.84814453
# Loss_Schnakenberg:13671.10095215 c_0:0:6.03375769
# Time:68.74
#
# Epoch: 800, loss:47105.49
# Loss_observations:33215.24047852
# Loss_Schnakenberg:13890.24645996 c_0:0:4.85678911
# Time:69.56
#
# Epoch: 900, loss:46156.66
# Loss_observations:31746.18212891
# Loss_Schnakenberg:14410.47607422 c_0:0:3.50983214
# Time:68.85
#
# Epoch: 1000, loss:25067.91
# Loss_observations:21609.13549805
# Loss_Schnakenberg:3458.77145386 c_0:0:1.54237115
# Time:68.20
#
# Epoch: 1100, loss:19927.30
# Loss_observations:19845.53588867
# Loss_Schnakenberg:81.76504564 c_0:0:0.95361507
# Time:68.91
#
# Epoch: 1200, loss:19833.39
# Loss_observations:19760.39282227
# Loss_Schnakenberg:73.00262356 c_0:0:0.87251067
# Time:69.46
#
# Epoch: 1300, loss:19828.59
# Loss_observations:19745.53833008
# Loss_Schnakenberg:83.05035400 c_0:0:0.86843693
# Time:68.41
#
# Epoch: 1400, loss:19825.25
# Loss_observations:19748.20727539
# Loss_Schnakenberg:77.04668522 c_0:0:0.86828601
# Time:65.20
#
# Epoch: 1500, loss:19824.41
# Loss_observations:19750.49511719
# Loss_Schnakenberg:73.91811514 c_0:0:0.86843175
# Time:65.01
#
# Epoch: 1600, loss:19825.49
# Loss_observations:19750.97998047
# Loss_Schnakenberg:74.50828886 c_0:0:0.86845744
# Time:68.78
#
# Epoch: 1700, loss:19827.97
# Loss_observations:19743.44921875
# Loss_Schnakenberg:84.52527332 c_0:0:0.86851048
# Time:71.35
#
# Epoch: 1800, loss:19825.68
# Loss_observations:19745.30932617
# Loss_Schnakenberg:80.37431908 c_0:0:0.86867857
# Time:70.15
#
# Epoch: 1900, loss:19823.88
# Loss_observations:19736.50317383
# Loss_Schnakenberg:87.37836981 c_0:0:0.86830801
# Time:69.69
#
# Epoch: 2000, loss:19814.16
# Loss_observations:19721.28979492
# Loss_Schnakenberg:92.87397385 c_0:0:0.86881250
# Time:70.85

# %%
param_names = [v.name for v in loss_stack_9[1].trainable_vars()]
params_len = len(param_names)
W_n = len(layers)-1

start = 0

_ = plt.figure(figsize=(16,5))
#plt.subplot(2,1,1)
for j in range(params_len):
    plt.plot(samples_params_9[start:,j], label=f"{param_names[j]}")

plt.ylim([0,4])
plt.grid()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

#plt.subplot(2,1,2)
fig = plt.figure(figsize=(16,5))
fig.patch.set_facecolor('white')
plt.plot(arr_losses_9[start:,0], label="Obs Loss")
plt.plot(arr_losses_9[start:,1], label="PDE Loss")
plt.grid()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
#plt.ylim([0,10])

plt.show()

# %%
pinn10 = tu.NN(layers, lb4, ub4)
loss_stack_10 = [tu_loss.Observations(pinn10, obs_X4, obs_Y4, init_loss_weight=10.0),
                schnakenberg2(pinn10, pde_X4)
               ]
model_10 = tu.TINN(pinn10, loss_stack_10, optimizer=keras.optimizers.Adam())

# %%
arr_losses_10, samples_params_10, _ = \
         model_10.train(2000,
                       batch_size=dataset4['obs_input'].shape[0]//8, 
                       print_iter=100,
                       stop_threshold=0,
                       regularised=False,
                       regularisation_freq=10,
                       sample_stats=True,
                       sample_params=True,
                       sample_gradiants=False)
# Out:
# Epoch: 1, loss:410413.69
# Loss_observations:390579.56640625
# Loss_Schnakenberg:19834.12243652 c_0:0:9.99253845
# Time:1.68
#
# Epoch: 100, loss:344772.34
# Loss_observations:316257.48046875
# Loss_Schnakenberg:28514.88867188 c_0:0:9.16224575
# Time:70.35
#
# Epoch: 200, loss:340836.50
# Loss_observations:309632.32031250
# Loss_Schnakenberg:31204.20336914 c_0:0:8.24470997
# Time:68.90
#
# Epoch: 300, loss:335103.97
# Loss_observations:299439.51171875
# Loss_Schnakenberg:35664.47802734 c_0:0:7.25441551
# Time:72.01
#
# Epoch: 400, loss:326328.97
# Loss_observations:285859.06640625
# Loss_Schnakenberg:40469.89160156 c_0:0:6.19888401
# Time:73.28
#
# Epoch: 500, loss:312229.25
# Loss_observations:265152.43164062
# Loss_Schnakenberg:47076.83837891 c_0:0:5.08141804
# Time:72.45
#
# Epoch: 600, loss:287755.78
# Loss_observations:234488.66406250
# Loss_Schnakenberg:53267.11621094 c_0:0:3.90257335
# Time:71.00
#
# Epoch: 700, loss:244426.84
# Loss_observations:201392.86914062
# Loss_Schnakenberg:43033.96777344 c_0:0:2.71219945
# Time:72.21
#
# Epoch: 800, loss:103556.47
# Loss_observations:73656.99316406
# Loss_Schnakenberg:29899.47705078 c_0:0:1.78291500
# Time:70.66
#
# Epoch: 900, loss:42183.78
# Loss_observations:16372.64929199
# Loss_Schnakenberg:25811.13037109 c_0:0:1.19794953
# Time:70.27
#
# Epoch: 1000, loss:26568.78
# Loss_observations:7139.77947998
# Loss_Schnakenberg:19429.00097656 c_0:0:0.92730778
# Time:69.06
#
# Epoch: 1100, loss:24999.16
# Loss_observations:4887.92248535
# Loss_Schnakenberg:20111.23486328 c_0:0:0.85080981
# Time:69.88
#
# Epoch: 1200, loss:24203.66
# Loss_observations:4263.09634399
# Loss_Schnakenberg:19940.56616211 c_0:0:0.84755504
# Time:71.15
#
# Epoch: 1300, loss:24020.19
# Loss_observations:3927.49780273
# Loss_Schnakenberg:20092.68701172 c_0:0:0.85725135
# Time:73.12
#
# Epoch: 1400, loss:24279.18
# Loss_observations:3860.24298096
# Loss_Schnakenberg:20418.93334961 c_0:0:0.86517990
# Time:69.15
#
# Epoch: 1500, loss:24485.44
# Loss_observations:3559.18875122
# Loss_Schnakenberg:20926.25048828 c_0:0:0.86933661
# Time:72.97
#
# Epoch: 1600, loss:25813.85
# Loss_observations:3597.83694458
# Loss_Schnakenberg:22216.00952148 c_0:0:0.87083632
# Time:69.30
#
# Epoch: 1700, loss:27501.93
# Loss_observations:3714.27957153
# Loss_Schnakenberg:23787.64819336 c_0:0:0.87001097
# Time:70.86
#
# Epoch: 1800, loss:26794.26
# Loss_observations:3446.23678589
# Loss_Schnakenberg:23348.02612305 c_0:0:0.86693710
# Time:64.96
#
# Epoch: 1900, loss:26157.97
# Loss_observations:3211.72021484
# Loss_Schnakenberg:22946.24804688 c_0:0:0.86605817
# Time:64.60
#
# Epoch: 2000, loss:24602.30
# Loss_observations:3164.31924438
# Loss_Schnakenberg:21437.98583984 c_0:0:0.86466277
# Time:65.21

# %%
param_names = [v.name for v in loss_stack_9[1].trainable_vars()]
params_len = len(param_names)
W_n = len(layers)-1

start = 0

_ = plt.figure(figsize=(16,5))
#plt.subplot(2,1,1)
for j in range(params_len):
    plt.plot(samples_params_10[start:,j], label=f"{param_names[j]}")

#plt.ylim([0,4])
plt.grid()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

#plt.subplot(2,1,2)
fig = plt.figure(figsize=(16,5))
fig.patch.set_facecolor('white')
plt.plot(arr_losses_10[start:,0], label="Obs Loss")
plt.plot(arr_losses_10[start:,1], label="PDE Loss")
plt.grid()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
#plt.ylim([0,10])

plt.show()

# %%
arr_losses_11, samples_params_11, _ = \
         model_10.train(4000,
                       batch_size=dataset4['obs_input'].shape[0]//8, 
                       print_iter=100,
                       stop_threshold=0,
                       regularised=False,
                       regularisation_freq=10,
                       sample_stats=True,
                       sample_params=True,
                       sample_gradiants=False)
# Out:
# Epoch: 1, loss:24553.21
# Loss_observations:3182.86276245
# Loss_Schnakenberg:21370.34375000 c_0:0:0.86458355
# Time:0.50
#
# Epoch: 100, loss:23637.12
# Loss_observations:2902.48217773
# Loss_Schnakenberg:20734.63159180 c_0:0:0.86411518
# Time:65.13
#
# Epoch: 200, loss:22430.19
# Loss_observations:2751.45385742
# Loss_Schnakenberg:19678.73779297 c_0:0:0.86492729
# Time:72.83
#
# Epoch: 300, loss:22026.64
# Loss_observations:2715.28829956
# Loss_Schnakenberg:19311.35424805 c_0:0:0.86538470
# Time:69.82
#
# Epoch: 400, loss:21719.25
# Loss_observations:2699.82803345
# Loss_Schnakenberg:19019.42382812 c_0:0:0.86771995
# Time:69.77
#
# Epoch: 500, loss:21182.63
# Loss_observations:2493.09716797
# Loss_Schnakenberg:18689.53100586 c_0:0:0.86706799
# Time:69.94
#
# Epoch: 600, loss:20893.41
# Loss_observations:2462.35919189
# Loss_Schnakenberg:18431.05102539 c_0:0:0.86798739
# Time:70.69
#
# Epoch: 700, loss:20640.29
# Loss_observations:2448.16674805
# Loss_Schnakenberg:18192.11791992 c_0:0:0.86890161
# Time:70.21
#
# Epoch: 800, loss:20329.29
# Loss_observations:2472.69456482
# Loss_Schnakenberg:17856.60229492 c_0:0:0.87025744
# Time:69.48
#
# Epoch: 900, loss:20047.34
# Loss_observations:2348.24882507
# Loss_Schnakenberg:17699.09497070 c_0:0:0.87099415
# Time:70.11
#
# Epoch: 1000, loss:20012.98
# Loss_observations:2336.15629578
# Loss_Schnakenberg:17676.81872559 c_0:0:0.87267369
# Time:70.18
#
# Epoch: 1100, loss:20378.82
# Loss_observations:2317.53018188
# Loss_Schnakenberg:18061.29345703 c_0:0:0.87504244
# Time:69.42
#
# Epoch: 1200, loss:21016.00
# Loss_observations:2265.93014526
# Loss_Schnakenberg:18750.06982422 c_0:0:0.87691045
# Time:69.20
#
# Epoch: 1300, loss:21485.87
# Loss_observations:2198.00787354
# Loss_Schnakenberg:19287.86401367 c_0:0:0.87801343
# Time:69.75
#
# Epoch: 1400, loss:21879.56
# Loss_observations:2188.73971558
# Loss_Schnakenberg:19690.81933594 c_0:0:0.87818134
# Time:71.30
#
# Epoch: 1500, loss:21315.09
# Loss_observations:2140.80563354
# Loss_Schnakenberg:19174.28100586 c_0:0:0.87706542
# Time:71.75
#
# Epoch: 1600, loss:20630.88
# Loss_observations:2081.87654114
# Loss_Schnakenberg:18549.00024414 c_0:0:0.87535369
# Time:69.73
#
# Epoch: 1700, loss:20843.65
# Loss_observations:2122.94204712
# Loss_Schnakenberg:18720.70410156 c_0:0:0.87423319
# Time:68.78
#
# Epoch: 1800, loss:21264.21
# Loss_observations:2134.42835999
# Loss_Schnakenberg:19129.77587891 c_0:0:0.87323403
# Time:70.51
#
# Epoch: 1900, loss:21423.13
# Loss_observations:2113.26339722
# Loss_Schnakenberg:19309.87011719 c_0:0:0.87381417
# Time:66.60
#
# Epoch: 2000, loss:21757.00
# Loss_observations:2148.01344299
# Loss_Schnakenberg:19608.98706055 c_0:0:0.87288851
# Time:70.44
#
# Epoch: 2100, loss:22143.93
# Loss_observations:2044.09759521
# Loss_Schnakenberg:20099.82983398 c_0:0:0.87384903
# Time:72.72
#
# Epoch: 2200, loss:22828.50
# Loss_observations:2087.23080444
# Loss_Schnakenberg:20741.27441406 c_0:0:0.87611771
# Time:68.31
#
# Epoch: 2300, loss:23681.07
# Loss_observations:2141.17651367
# Loss_Schnakenberg:21539.89794922 c_0:0:0.87945712
# Time:69.56
#
# Epoch: 2400, loss:25269.93
# Loss_observations:2272.86561584
# Loss_Schnakenberg:22997.06640625 c_0:0:0.88197851
# Time:70.96
#
# Epoch: 2500, loss:25368.57
# Loss_observations:2270.44528198
# Loss_Schnakenberg:23098.12280273 c_0:0:0.88323259
# Time:72.07
#
# Epoch: 2600, loss:25045.74
# Loss_observations:2122.26858521
# Loss_Schnakenberg:22923.47167969 c_0:0:0.88116425
# Time:69.19
#
# Epoch: 2700, loss:24754.99
# Loss_observations:2119.25067139
# Loss_Schnakenberg:22635.74121094 c_0:0:0.88401145
# Time:68.28
#
# Epoch: 2800, loss:24868.00
# Loss_observations:2137.57534790
# Loss_Schnakenberg:22730.42919922 c_0:0:0.88455224
# Time:67.63
#
# Epoch: 2900, loss:24846.93
# Loss_observations:2148.67684937
# Loss_Schnakenberg:22698.24853516 c_0:0:0.88524622
# Time:70.66
#
# Epoch: 3000, loss:25196.27
# Loss_observations:2141.72843933
# Loss_Schnakenberg:23054.54101562 c_0:0:0.88384730
# Time:71.13
#
# Epoch: 3100, loss:26214.92
# Loss_observations:2139.51898193
# Loss_Schnakenberg:24075.39550781 c_0:0:0.88525331
# Time:68.60
#
# Epoch: 3200, loss:28942.02
# Loss_observations:2199.21011353
# Loss_Schnakenberg:26742.80639648 c_0:0:0.88736129
# Time:71.30
#
# Epoch: 3300, loss:31494.47
# Loss_observations:2274.50068665
# Loss_Schnakenberg:29219.96899414 c_0:0:0.89043552
# Time:68.11
#
# Epoch: 3400, loss:34153.59
# Loss_observations:2312.14430237
# Loss_Schnakenberg:31841.44555664 c_0:0:0.88963938
# Time:71.50
#
# Epoch: 3500, loss:35746.01
# Loss_observations:2761.35458374
# Loss_Schnakenberg:32984.65454102 c_0:0:0.88057047
# Time:70.71
#
# Epoch: 3600, loss:30862.80
# Loss_observations:2342.33668518
# Loss_Schnakenberg:28520.46264648 c_0:0:0.88899767
# Time:71.39
#
# Epoch: 3700, loss:31577.35
# Loss_observations:2339.76762390
# Loss_Schnakenberg:29237.57958984 c_0:0:0.88820171
# Time:70.39
#
# Epoch: 3800, loss:29929.42
# Loss_observations:2258.69252014
# Loss_Schnakenberg:27670.72460938 c_0:0:0.89223242
# Time:70.56
#
# Epoch: 3900, loss:31022.39
# Loss_observations:2240.70433044
# Loss_Schnakenberg:28781.69213867 c_0:0:0.89914042
# Time:72.84
#
# Epoch: 4000, loss:24678.13
# Loss_observations:1944.59651184
# Loss_Schnakenberg:22733.53637695 c_0:0:0.90008658
# Time:71.61

# %%
param_names = [v.name for v in loss_stack_9[1].trainable_vars()]
params_len = len(param_names)
W_n = len(layers)-1

start = 0

_ = plt.figure(figsize=(16,5))
#plt.subplot(2,1,1)
for j in range(params_len):
    plt.plot(samples_params_11[start:,j], label=f"{param_names[j]}")

#plt.ylim([0,4])
plt.grid()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

#plt.subplot(2,1,2)
fig = plt.figure(figsize=(16,5))
fig.patch.set_facecolor('white')
plt.plot(arr_losses_11[start:,0], label="Obs Loss")
plt.plot(arr_losses_11[start:,1], label="PDE Loss")
plt.grid()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
#plt.ylim([0,10])

plt.show()

# %%
arr_losses = np.vstack([arr_losses_10,arr_losses_11])
samples_params = np.vstack([samples_params_10,samples_params_11])

# %%
param_names = [v.name for v in loss_stack_9[1].trainable_vars()]
params_len = len(param_names)
W_n = len(layers)-1

start = 10

_ = plt.figure(figsize=(16,5))
#plt.subplot(2,1,1)
for j in range(params_len):
    plt.plot(samples_params[start:,j], label=f"{param_names[j]}")

plt.ylim([0.5,1.5])
plt.grid()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

#plt.subplot(2,1,2)
fig = plt.figure(figsize=(16,5))
fig.patch.set_facecolor('white')
plt.plot(arr_losses[start:,0], label="Obs Loss")
plt.plot(arr_losses[start:,1], label="PDE Loss")
plt.grid()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
#plt.ylim([0,10])

plt.show()

# %%
arr_losses_12, samples_params_12, _ = \
         model_10.train(4000,
                       batch_size=dataset4['obs_input'].shape[0]//8, 
                       print_iter=100,
                       stop_threshold=0,
                       regularised=False,
                       regularisation_freq=10,
                       sample_stats=True,
                       sample_params=True,
                       sample_gradiants=False)
# Out:
# Epoch: 1, loss:24809.12
# Loss_observations:1969.77235413
# Loss_Schnakenberg:22839.35375977 c_0:0:0.90015972
# Time:0.55
#
# Epoch: 100, loss:26914.96
# Loss_observations:2079.35937500
# Loss_Schnakenberg:24835.59741211 c_0:0:0.90357983
# Time:73.21
#
# Epoch: 200, loss:25105.18
# Loss_observations:2040.23524475
# Loss_Schnakenberg:23064.94799805 c_0:0:0.90148234
# Time:74.84
#
# Epoch: 300, loss:24518.51
# Loss_observations:2005.92790222
# Loss_Schnakenberg:22512.58349609 c_0:0:0.90882045
# Time:70.68
#
# Epoch: 400, loss:25162.68
# Loss_observations:1950.64663696
# Loss_Schnakenberg:23212.03295898 c_0:0:0.90910751
# Time:72.90
#
# Epoch: 500, loss:25019.66
# Loss_observations:1917.36355591
# Loss_Schnakenberg:23102.29882812 c_0:0:0.90963465
# Time:73.92
#
# Epoch: 600, loss:24661.92
# Loss_observations:1968.19029236
# Loss_Schnakenberg:22693.72827148 c_0:0:0.90740293
# Time:75.12
#
# Epoch: 700, loss:25545.82
# Loss_observations:1945.41134644
# Loss_Schnakenberg:23600.40942383 c_0:0:0.90992391
# Time:75.95
#
# Epoch: 800, loss:25048.41
# Loss_observations:1963.96069336
# Loss_Schnakenberg:23084.45166016 c_0:0:0.90631467
# Time:70.07
#
# Epoch: 900, loss:27079.31
# Loss_observations:1990.97370911
# Loss_Schnakenberg:25088.33203125 c_0:0:0.91081411
# Time:75.65
#
# Epoch: 1000, loss:25652.42
# Loss_observations:1961.83106995
# Loss_Schnakenberg:23690.58886719 c_0:0:0.90579331
# Time:76.38
#
# Epoch: 1100, loss:26045.82
# Loss_observations:1956.32949829
# Loss_Schnakenberg:24089.49340820 c_0:0:0.90837908
# Time:74.86
#
# Epoch: 1200, loss:25712.34
# Loss_observations:1970.08605957
# Loss_Schnakenberg:23742.25878906 c_0:0:0.90793800
# Time:73.01
#
# Epoch: 1300, loss:26273.68
# Loss_observations:2075.23373413
# Loss_Schnakenberg:24198.44140625 c_0:0:0.90937167
# Time:72.78
#
# Epoch: 1400, loss:33847.44
# Loss_observations:2188.07904053
# Loss_Schnakenberg:31659.35644531 c_0:0:0.92034888
# Time:75.18
#
# Epoch: 1500, loss:34346.02
# Loss_observations:2384.86730957
# Loss_Schnakenberg:31961.15722656 c_0:0:0.91525382
# Time:76.30
#
# Epoch: 1600, loss:45831.45
# Loss_observations:3045.47622681
# Loss_Schnakenberg:42785.96679688 c_0:0:0.92705804
# Time:71.23
#
# Epoch: 1700, loss:49828.01
# Loss_observations:2991.95651245
# Loss_Schnakenberg:46836.05566406 c_0:0:0.91212988
# Time:71.13
#
# Epoch: 1800, loss:46259.95
# Loss_observations:3312.19418335
# Loss_Schnakenberg:42947.75683594 c_0:0:0.90421402
# Time:72.21
#
# Epoch: 1900, loss:34695.32
# Loss_observations:2701.77325439
# Loss_Schnakenberg:31993.55175781 c_0:0:0.90423912
# Time:74.28
#
# Epoch: 2000, loss:32219.32
# Loss_observations:2475.37600708
# Loss_Schnakenberg:29743.94140625 c_0:0:0.90173727
# Time:76.98
#
# Epoch: 2100, loss:30273.19
# Loss_observations:2400.88983154
# Loss_Schnakenberg:27872.30126953 c_0:0:0.89545959
# Time:76.16
#
# Epoch: 2200, loss:30717.15
# Loss_observations:2499.86880493
# Loss_Schnakenberg:28217.28198242 c_0:0:0.89779061
# Time:70.10
#
# Epoch: 2300, loss:28786.45
# Loss_observations:2478.07800293
# Loss_Schnakenberg:26308.37597656 c_0:0:0.88523567
# Time:71.30
#
# Epoch: 2400, loss:27384.45
# Loss_observations:2226.92280579
# Loss_Schnakenberg:25157.52880859 c_0:0:0.88998920
# Time:71.76
#
# Epoch: 2500, loss:27134.85
# Loss_observations:2193.29594421
# Loss_Schnakenberg:24941.55493164 c_0:0:0.89694715
# Time:72.76
#
# Epoch: 2600, loss:26198.83
# Loss_observations:2119.18565369
# Loss_Schnakenberg:24079.64257812 c_0:0:0.89964569
# Time:71.27
#
# Epoch: 2700, loss:26765.65
# Loss_observations:2205.85971069
# Loss_Schnakenberg:24559.78735352 c_0:0:0.90050983
# Time:74.37
#
# Epoch: 2800, loss:27723.33
# Loss_observations:2079.58714294
# Loss_Schnakenberg:25643.74707031 c_0:0:0.89389068
# Time:72.61
#
# Epoch: 2900, loss:27427.67
# Loss_observations:2043.10112000
# Loss_Schnakenberg:25384.56860352 c_0:0:0.89466387
# Time:71.93
#
# Epoch: 3000, loss:27327.27
# Loss_observations:2010.71632385
# Loss_Schnakenberg:25316.55688477 c_0:0:0.89643800
# Time:73.36
#
# Epoch: 3100, loss:30011.59
# Loss_observations:2382.49168396
# Loss_Schnakenberg:27629.09497070 c_0:0:0.89769387
# Time:80.94
#
# Epoch: 3200, loss:30216.67
# Loss_observations:2148.87080383
# Loss_Schnakenberg:28067.80029297 c_0:0:0.89325982
# Time:74.18
#
# Epoch: 3300, loss:29980.18
# Loss_observations:2112.69332886
# Loss_Schnakenberg:27867.48315430 c_0:0:0.89294988
# Time:77.58
#
# Epoch: 3400, loss:29906.31
# Loss_observations:2091.79650879
# Loss_Schnakenberg:27814.51025391 c_0:0:0.89415485
# Time:80.96
#
# Epoch: 3500, loss:30537.27
# Loss_observations:2411.75009155
# Loss_Schnakenberg:28125.52587891 c_0:0:0.89305234
# Time:76.05
#
# Epoch: 3600, loss:29228.98
# Loss_observations:2177.79211426
# Loss_Schnakenberg:27051.18603516 c_0:0:0.88867408
# Time:75.49
#
# Epoch: 3700, loss:29096.82
# Loss_observations:2176.17889404
# Loss_Schnakenberg:26920.63745117 c_0:0:0.89447170
# Time:76.12
#
# Epoch: 3800, loss:28944.81
# Loss_observations:2092.16209412
# Loss_Schnakenberg:26852.64331055 c_0:0:0.90158355
# Time:77.67
#
# Epoch: 3900, loss:29133.38
# Loss_observations:2083.46121216
# Loss_Schnakenberg:27049.91601562 c_0:0:0.90346068
# Time:78.05
#
# Epoch: 4000, loss:29249.91
# Loss_observations:2034.18389893
# Loss_Schnakenberg:27215.72729492 c_0:0:0.90109998
# Time:77.74

# %%
param_names = [v.name for v in loss_stack_9[1].trainable_vars()]
params_len = len(param_names)
W_n = len(layers)-1

start = 10

_ = plt.figure(figsize=(16,5))
#plt.subplot(2,1,1)
for j in range(params_len):
    plt.plot(samples_params_12[start:,j], label=f"{param_names[j]}")

plt.ylim([0.5,1.5])
plt.grid()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

#plt.subplot(2,1,2)
fig = plt.figure(figsize=(16,5))
fig.patch.set_facecolor('white')
plt.plot(arr_losses_12[start:,0], label="Obs Loss")
plt.plot(arr_losses_12[start:,1], label="PDE Loss")
plt.grid()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.yscale('log')
#plt.ylim([0,10])

plt.show()

# %%
layers2 = [3, 128, 128, 128, 128, 2]

# %%
pinn_2 = tu.NN(layers2, lb4, ub4)
loss_stack_2_1 = [tu_loss.Observations(pinn_2, obs_X4, obs_Y4, init_loss_weight=10.0),
                schnakenberg2(pinn_2, pde_X4)
               ]
model_2_1 = tu.TINN(pinn_2, loss_stack_2_1, optimizer=keras.optimizers.Adam())

# %%
arr_losses_2_1, samples_params_2_1, _ = \
         model_2_1.train(10000,
                       batch_size=dataset4['obs_input'].shape[0]//8, 
                       print_iter=100,
                       stop_threshold=0,
                       regularised=False,
                       regularisation_freq=10,
                       sample_stats=True,
                       sample_params=True,
                       sample_gradiants=False)
# Out:
# Epoch: 1, loss:413068.94
# Loss_observations:377618.40234375
# Loss_Schnakenberg:35450.52441406 c_0:0:9.99210167
# Time:1.87
#
# Epoch: 100, loss:344905.59
# Loss_observations:316845.89062500
# Loss_Schnakenberg:28059.71484375 c_0:0:9.19025326
# Time:86.48
#
# Epoch: 200, loss:341062.56
# Loss_observations:309920.75781250
# Loss_Schnakenberg:31141.79492188 c_0:0:8.27806187
# Time:86.12
#
# Epoch: 300, loss:335371.03
# Loss_observations:300628.76953125
# Loss_Schnakenberg:34742.26806641 c_0:0:7.29076719
# Time:85.02
#
# Epoch: 400, loss:326832.38
# Loss_observations:286938.70312500
# Loss_Schnakenberg:39893.67822266 c_0:0:6.23720264
# Time:85.79
#
# Epoch: 500, loss:312966.88
# Loss_observations:264763.40234375
# Loss_Schnakenberg:48203.47705078 c_0:0:5.12117195
# Time:88.01
#
# Epoch: 600, loss:288868.94
# Loss_observations:235838.07421875
# Loss_Schnakenberg:53030.85937500 c_0:0:3.94368958
# Time:82.95
#
# Epoch: 700, loss:247890.70
# Loss_observations:203270.22070312
# Loss_Schnakenberg:44620.48095703 c_0:0:2.75031424
# Time:86.44
#
# Epoch: 800, loss:158130.70
# Loss_observations:137893.27734375
# Loss_Schnakenberg:20237.42382812 c_0:0:1.81885600
# Time:87.91
#
# Epoch: 900, loss:124116.47
# Loss_observations:115026.13671875
# Loss_Schnakenberg:9090.32507324 c_0:0:1.23916340
# Time:89.14
#
# Epoch: 1000, loss:109734.19
# Loss_observations:102078.67285156
# Loss_Schnakenberg:7655.51660156 c_0:0:0.92387784
# Time:89.94
#
# Epoch: 1100, loss:48332.35
# Loss_observations:26740.52294922
# Loss_Schnakenberg:21591.82348633 c_0:0:0.84284395
# Time:88.99
#
# Epoch: 1200, loss:22427.05
# Loss_observations:4738.90850830
# Loss_Schnakenberg:17688.14123535 c_0:0:0.84597075
# Time:89.82
#
# Epoch: 1300, loss:21108.51
# Loss_observations:3683.96569824
# Loss_Schnakenberg:17424.54467773 c_0:0:0.84462148
# Time:86.27
#
# Epoch: 1400, loss:20921.23
# Loss_observations:3189.43621826
# Loss_Schnakenberg:17731.79565430 c_0:0:0.84529203
# Time:89.97
#
# Epoch: 1500, loss:20665.48
# Loss_observations:2863.84902954
# Loss_Schnakenberg:17801.63476562 c_0:0:0.85214424
# Time:90.76
#
# Epoch: 1600, loss:20984.18
# Loss_observations:2928.45288086
# Loss_Schnakenberg:18055.72607422 c_0:0:0.85976809
# Time:90.16
#
# Epoch: 1700, loss:21533.40
# Loss_observations:2737.27539062
# Loss_Schnakenberg:18796.12670898 c_0:0:0.86797458
# Time:91.18
#
# Epoch: 1800, loss:22888.00
# Loss_observations:2609.62207031
# Loss_Schnakenberg:20278.37744141 c_0:0:0.87521106
# Time:89.14
#
# Epoch: 1900, loss:24225.81
# Loss_observations:2627.87393188
# Loss_Schnakenberg:21597.93408203 c_0:0:0.87790519
# Time:88.99
#
# Epoch: 2000, loss:25797.44
# Loss_observations:2769.46087646
# Loss_Schnakenberg:23027.97900391 c_0:0:0.87860394
# Time:90.14
#
# Epoch: 2100, loss:27076.06
# Loss_observations:2799.84674072
# Loss_Schnakenberg:24276.20922852 c_0:0:0.87999475
# Time:88.65
#
# Epoch: 2200, loss:28832.12
# Loss_observations:2675.28256226
# Loss_Schnakenberg:26156.83178711 c_0:0:0.86727035
# Time:89.77
#
# Epoch: 2300, loss:28301.17
# Loss_observations:2658.40458679
# Loss_Schnakenberg:25642.76220703 c_0:0:0.86127180
# Time:90.04
#
# Epoch: 2400, loss:24952.18
# Loss_observations:2439.60140991
# Loss_Schnakenberg:22512.58325195 c_0:0:0.87199330
# Time:89.15
#
# Epoch: 2500, loss:23279.62
# Loss_observations:2420.97750854
# Loss_Schnakenberg:20858.63964844 c_0:0:0.87173337
# Time:90.34
#
# Epoch: 2600, loss:22944.66
# Loss_observations:2264.58421326
# Loss_Schnakenberg:20680.07177734 c_0:0:0.86982852
# Time:89.04
#
# Epoch: 2700, loss:21547.52
# Loss_observations:2254.23794556
# Loss_Schnakenberg:19293.27978516 c_0:0:0.87011039
# Time:89.87
#
# Epoch: 2800, loss:21311.31
# Loss_observations:2085.05885315
# Loss_Schnakenberg:19226.24829102 c_0:0:0.87265539
# Time:92.29
#
# Epoch: 2900, loss:21530.43
# Loss_observations:2070.19081116
# Loss_Schnakenberg:19460.24145508 c_0:0:0.87293941
# Time:92.88
#
# Epoch: 3000, loss:21252.51
# Loss_observations:2097.52583313
# Loss_Schnakenberg:19154.98828125 c_0:0:0.87111366
# Time:90.28
#
# Epoch: 3100, loss:21318.16
# Loss_observations:1950.71502686
# Loss_Schnakenberg:19367.44604492 c_0:0:0.87097722
# Time:92.56
#
# Epoch: 3200, loss:21243.89
# Loss_observations:1955.31655884
# Loss_Schnakenberg:19288.57421875 c_0:0:0.87226111
# Time:94.47
#
# Epoch: 3300, loss:21315.79
# Loss_observations:1890.06140137
# Loss_Schnakenberg:19425.73461914 c_0:0:0.87322891
# Time:92.09
#
# Epoch: 3400, loss:21176.07
# Loss_observations:1930.38298035
# Loss_Schnakenberg:19245.68725586 c_0:0:0.87157494
# Time:91.70
#
# Epoch: 3500, loss:21381.04
# Loss_observations:1904.10112000
# Loss_Schnakenberg:19476.93310547 c_0:0:0.87195176
# Time:92.10
#
# Epoch: 3600, loss:21835.22
# Loss_observations:1882.32351685
# Loss_Schnakenberg:19952.89404297 c_0:0:0.87359118
# Time:91.64
#
# Epoch: 3700, loss:22136.73
# Loss_observations:1858.70468140
# Loss_Schnakenberg:20278.02392578 c_0:0:0.87486488
# Time:92.60
#
# Epoch: 3800, loss:22330.27
# Loss_observations:1845.23442078
# Loss_Schnakenberg:20485.03247070 c_0:0:0.87504244
# Time:91.17
#
# Epoch: 3900, loss:24342.52
# Loss_observations:1973.61796570
# Loss_Schnakenberg:22368.89575195 c_0:0:0.87614423
# Time:91.19
#
# Epoch: 4000, loss:23803.25
# Loss_observations:1909.82099915
# Loss_Schnakenberg:21893.42529297 c_0:0:0.87575543
# Time:92.19
#
# Epoch: 4100, loss:23721.06
# Loss_observations:1836.88835144
# Loss_Schnakenberg:21884.17651367 c_0:0:0.88365448
# Time:93.81
#
# Epoch: 4200, loss:22595.73
# Loss_observations:1807.72193909
# Loss_Schnakenberg:20788.00268555 c_0:0:0.88164848
# Time:89.32
#
# Epoch: 4300, loss:23369.01
# Loss_observations:1858.67433167
# Loss_Schnakenberg:21510.33740234 c_0:0:0.88146693
# Time:92.69
#
# Epoch: 4400, loss:23962.56
# Loss_observations:1832.15454102
# Loss_Schnakenberg:22130.41137695 c_0:0:0.88312775
# Time:94.18
#
# Epoch: 4500, loss:24860.37
# Loss_observations:1916.16633606
# Loss_Schnakenberg:22944.20117188 c_0:0:0.88334459
# Time:89.93
#
# Epoch: 4600, loss:25999.32
# Loss_observations:1932.13201904
# Loss_Schnakenberg:24067.18847656 c_0:0:0.88031644
# Time:86.18
#
# Epoch: 4700, loss:31563.40
# Loss_observations:2317.20138550
# Loss_Schnakenberg:29246.20092773 c_0:0:0.87976867
# Time:92.60
#
# Epoch: 4800, loss:27710.91
# Loss_observations:2102.27087402
# Loss_Schnakenberg:25608.64379883 c_0:0:0.89011502
# Time:95.47
#
# Epoch: 4900, loss:27631.05
# Loss_observations:1968.11029053
# Loss_Schnakenberg:25662.94213867 c_0:0:0.88816595
# Time:91.35
#
# Epoch: 5000, loss:29208.91
# Loss_observations:2124.79673767
# Loss_Schnakenberg:27084.11743164 c_0:0:0.88710767
# Time:88.65
#
# Epoch: 5100, loss:29656.92
# Loss_observations:1872.20709229
# Loss_Schnakenberg:27784.71533203 c_0:0:0.89193124
# Time:89.97
#
# Epoch: 5200, loss:29056.35
# Loss_observations:1840.18714905
# Loss_Schnakenberg:27216.16528320 c_0:0:0.88514096
# Time:87.39
#
# Epoch: 5300, loss:31291.54
# Loss_observations:1847.36361694
# Loss_Schnakenberg:29444.17163086 c_0:0:0.88232976
# Time:86.18
#
# Epoch: 5400, loss:36890.71
# Loss_observations:2111.76689148
# Loss_Schnakenberg:34778.94677734 c_0:0:0.88020486
# Time:87.05
#
# Epoch: 5500, loss:35296.06
# Loss_observations:1928.38647461
# Loss_Schnakenberg:33367.67211914 c_0:0:0.88630980
# Time:87.90
#
# Epoch: 5600, loss:41124.07
# Loss_observations:2256.26800537
# Loss_Schnakenberg:38867.80517578 c_0:0:0.88388741
# Time:87.22
#
# Epoch: 5700, loss:39879.76
# Loss_observations:2124.38310242
# Loss_Schnakenberg:37755.37353516 c_0:0:0.88904011
# Time:86.97
#
# Epoch: 5800, loss:39983.84
# Loss_observations:2152.15348816
# Loss_Schnakenberg:37831.68896484 c_0:0:0.88249916
# Time:87.83
#
# Epoch: 5900, loss:43130.46
# Loss_observations:2066.24359131
# Loss_Schnakenberg:41064.21728516 c_0:0:0.87604713
# Time:91.09
#
# Epoch: 6000, loss:46481.57
# Loss_observations:2658.68515015
# Loss_Schnakenberg:43822.88378906 c_0:0:0.86676836
# Time:90.35
#
# Epoch: 6100, loss:45330.99
# Loss_observations:2318.63143921
# Loss_Schnakenberg:43012.35986328 c_0:0:0.88150817
# Time:93.56
#
# Epoch: 6200, loss:51080.05
# Loss_observations:2560.86437988
# Loss_Schnakenberg:48519.19042969 c_0:0:0.88278258
# Time:95.46
#
# Epoch: 6300, loss:58144.51
# Loss_observations:2889.42596436
# Loss_Schnakenberg:55255.08203125 c_0:0:0.89349073
# Time:89.41
#
# Epoch: 6400, loss:57171.93
# Loss_observations:2681.68960571
# Loss_Schnakenberg:54490.23535156 c_0:0:0.91007996
# Time:91.92
#
# Epoch: 6500, loss:53581.38
# Loss_observations:2802.66250610
# Loss_Schnakenberg:50778.71435547 c_0:0:0.89971417
# Time:90.14
#
# Epoch: 6600, loss:63859.33
# Loss_observations:3101.79397583
# Loss_Schnakenberg:60757.53710938 c_0:0:0.90314192
# Time:86.09
# Epoch: 6700, loss:51581.98
# Loss_observations:2799.68878174
# Loss_Schnakenberg:48782.28662109 c_0:0:0.89793247
# Time:87.34
#
# Epoch: 6800, loss:52558.37
# Loss_observations:2624.50054932
# Loss_Schnakenberg:49933.87060547 c_0:0:0.86341786
# Time:89.14
#
# Epoch: 6900, loss:52128.32
# Loss_observations:2793.00964355
# Loss_Schnakenberg:49335.31396484 c_0:0:0.89914817
# Time:89.48
#
# Epoch: 7000, loss:54895.57
# Loss_observations:3035.97500610
# Loss_Schnakenberg:51859.60058594 c_0:0:0.90049839
# Time:93.50
#
# Epoch: 7100, loss:57231.25
# Loss_observations:2756.16848755
# Loss_Schnakenberg:54475.08154297 c_0:0:0.90332174
# Time:92.36
#
# Epoch: 7200, loss:61487.68
# Loss_observations:3603.54638672
# Loss_Schnakenberg:57884.13916016 c_0:0:0.89403725
# Time:89.27
#
# Epoch: 7300, loss:61932.07
# Loss_observations:3463.73623657
# Loss_Schnakenberg:58468.33154297 c_0:0:0.88940656
# Time:90.73
#
# Epoch: 7400, loss:64564.82
# Loss_observations:3548.81768799
# Loss_Schnakenberg:61016.00488281 c_0:0:0.88992095
# Time:89.93
#
# Epoch: 7500, loss:62070.84
# Loss_observations:3622.85452271
# Loss_Schnakenberg:58447.97998047 c_0:0:0.89057630
# Time:88.63
#
# Epoch: 7600, loss:73610.76
# Loss_observations:4750.53137207
# Loss_Schnakenberg:68860.22949219 c_0:0:0.88518268
# Time:90.16
#
# Epoch: 7700, loss:98185.66
# Loss_observations:6060.22723389
# Loss_Schnakenberg:92125.42675781 c_0:0:0.84435993
# Time:94.24
#
# Epoch: 7800, loss:90835.96
# Loss_observations:6008.69335938
# Loss_Schnakenberg:84827.26464844 c_0:0:0.87588465
# Time:91.74
#
# Epoch: 7900, loss:125695.59
# Loss_observations:9881.14965820
# Loss_Schnakenberg:115814.43164062 c_0:0:0.87061429
# Time:91.12
#
# Epoch: 8000, loss:135313.78
# Loss_observations:9156.63769531
# Loss_Schnakenberg:126157.14746094 c_0:0:0.86993009
# Time:90.32
#
# Epoch: 8100, loss:204089.89
# Loss_observations:9117.46789551
# Loss_Schnakenberg:194972.41601562 c_0:0:0.90870732
# Time:90.58
#
# Epoch: 8200, loss:179450.97
# Loss_observations:7373.88372803
# Loss_Schnakenberg:172077.08203125 c_0:0:0.85335422
# Time:88.69
#
# Epoch: 8300, loss:136102.20
# Loss_observations:8301.01666260
# Loss_Schnakenberg:127801.17773438 c_0:0:0.89224726
# Time:89.26
#
# Epoch: 8400, loss:318307.62
# Loss_observations:20676.42675781
# Loss_Schnakenberg:297631.22851562 c_0:0:0.88104123
# Time:90.99
#
# Epoch: 8500, loss:300273.19
# Loss_observations:10586.73400879
# Loss_Schnakenberg:289686.44531250 c_0:0:0.86977220
# Time:92.36
#
# Epoch: 8600, loss:502557.66
# Loss_observations:29567.90161133
# Loss_Schnakenberg:472989.75000000 c_0:0:0.90478122
# Time:92.83
#
# Epoch: 8700, loss:708458.12
# Loss_observations:25585.48120117
# Loss_Schnakenberg:682872.66406250 c_0:0:0.88134754
# Time:93.77
#
# Epoch: 8800, loss:857893.88
# Loss_observations:24460.22509766
# Loss_Schnakenberg:833433.60156250 c_0:0:0.85814267
# Time:91.21
#
# Epoch: 8900, loss:1163545.75
# Loss_observations:38479.70068359
# Loss_Schnakenberg:1125066.02343750 c_0:0:0.92182648
# Time:89.87
#
# Epoch: 9000, loss:2041972.88
# Loss_observations:37244.05419922
# Loss_Schnakenberg:2004728.85937500 c_0:0:0.93486184
# Time:93.96
#
# Epoch: 9100, loss:1959504.38
# Loss_observations:67921.49169922
# Loss_Schnakenberg:1891582.95312500 c_0:0:0.82197076
# Time:92.03
#
# Epoch: 9200, loss:28654582.00
# Loss_observations:98265.13378906
# Loss_Schnakenberg:28556317.50000000 c_0:0:0.45850378
# Time:94.96
#
# Epoch: 9300, loss:6192690.00
# Loss_observations:65601.50585938
# Loss_Schnakenberg:6127088.59375000 c_0:0:0.60366988
# Time:93.83
#
# Epoch: 9400, loss:11040792.00
# Loss_observations:54201.90039062
# Loss_Schnakenberg:10986589.62500000 c_0:0:0.68306744
# Time:89.45
#
# Epoch: 9500, loss:91953264.00
# Loss_observations:174681.98437500
# Loss_Schnakenberg:91778584.00000000 c_0:0:0.05160062
# Time:92.09
#
# Epoch: 9600, loss:176275728.00
# Loss_observations:153057.55273438
# Loss_Schnakenberg:176122662.50000000 c_0:0:0.00000000
# Time:97.01
#
# Epoch: 9700, loss:1824046976.00
# Loss_observations:258280.00781250
# Loss_Schnakenberg:1823788560.00000000 c_0:0:0.00000000
# Time:92.30
#
# Epoch: 9800, loss:4225177088.00
# Loss_observations:595999.88281250
# Loss_Schnakenberg:4224580848.00000000 c_0:0:0.00160509
# Time:93.47
#
# Epoch: 9900, loss:3136973312.00
# Loss_observations:777920.52343750
# Loss_Schnakenberg:3136195456.00000000 c_0:0:0.01073361
# Time:93.44
#
# Epoch: 10000, loss:4106912256.00
# Loss_observations:564232.75000000
# Loss_Schnakenberg:4106348032.00000000 c_0:0:0.00000000
# Time:92.21

# %%
param_names = [v.name for v in loss_stack_2_1[1].trainable_vars()]
params_len = len(param_names)
W_n = len(layers)-1

start = 10

_ = plt.figure(figsize=(16,5))
#plt.subplot(2,1,1)
for j in range(params_len):
    plt.plot(samples_params_2_1[start:,j], label=f"{param_names[j]}")

plt.ylim([0.5,1.5])
plt.grid()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

#plt.subplot(2,1,2)
fig = plt.figure(figsize=(16,5))
fig.patch.set_facecolor('white')
plt.plot(arr_losses_2_1[start:,0], label="Obs Loss")
plt.plot(arr_losses_2_1[start:,1], label="PDE Loss")
plt.grid()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.yscale('log')
#plt.ylim([0,10])

plt.show()

# %%
uv_2 = pinn_2(np.hstack([x_2, y_2, t_2]), False)
u_2 = uv_2[:, 0].numpy()
v_2 = uv_2[:, 1].numpy()
u_2 = u_2.reshape((x_size4,y_size4))
v_2 = v_2.reshape((x_size4,y_size4))

# %%
plt.subplot(131)
plt.imshow(u_2)
plt.subplot(132)
plt.imshow(v_2)
plt.show()

# %%
pinn_2_2 = tu.NN(layers, lb4, ub4)
loss_stack_2_2 = [tu_loss.Observations(pinn_2_2, obs_X4, obs_Y4)
               ]
model_2_2 = tu.TINN(pinn_2_2, loss_stack_2_2, optimizer=keras.optimizers.Adam())

# %%
arr_losses_2_2, samples_params_2_2, _ = \
         model_2_2.train(1000,
                       batch_size=dataset4['obs_input'].shape[0]//8, 
                       print_iter=100,
                       stop_threshold=0,
                       regularised=False,
                       regularisation_freq=10,
                       sample_stats=True,
                       sample_params=True,
                       sample_gradiants=False)
# Out:
# Epoch: 1, loss:38557.87
# Loss_observations:38557.86962891
# Time:0.54
#
# Epoch: 100, loss:19519.05
# Loss_observations:19519.05541992
# Time:35.31
#
# Epoch: 200, loss:19503.88
# Loss_observations:19503.88427734
# Time:39.39
#
# Epoch: 300, loss:19500.93
# Loss_observations:19500.92602539
# Time:42.14
#
# Epoch: 400, loss:19446.42
# Loss_observations:19446.42504883
# Time:39.94
#
# Epoch: 500, loss:19372.89
# Loss_observations:19372.88940430
# Time:39.56
#
# Epoch: 600, loss:11445.70
# Loss_observations:11445.69909668
# Time:38.48
#
# Epoch: 700, loss:2610.63
# Loss_observations:2610.62844849
# Time:41.32
#
# Epoch: 800, loss:853.31
# Loss_observations:853.30948639
# Time:40.86
#
# Epoch: 900, loss:391.67
# Loss_observations:391.66945648
# Time:43.61
#
# Epoch: 1000, loss:305.99
# Loss_observations:305.98926353
# Time:43.42

# %%
uv_2 = pinn_2_2(np.hstack([x_2, y_2, t_2]), False)
u_2 = uv_2[:, 0].numpy()
v_2 = uv_2[:, 1].numpy()
u_2 = u_2.reshape((x_size4,y_size4))
v_2 = v_2.reshape((x_size4,y_size4))

# %%
plt.subplot(131)
plt.imshow(u_2)
plt.subplot(132)
plt.imshow(v_2)
plt.show()
