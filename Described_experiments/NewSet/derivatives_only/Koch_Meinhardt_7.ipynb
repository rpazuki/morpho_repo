# %%
# %config Completer.use_jedi = False
import sys
import warnings
warnings.filterwarnings('ignore')

import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

MEMORY = 8*1024

gpus = tf.config.list_physical_devices('GPU')
try:
    tf.config.set_logical_device_configuration(gpus[0],
                                              [tf.config.LogicalDeviceConfiguration(memory_limit=MEMORY)])
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
except RuntimeError as e:        
    # Memory growth must be set before GPUs have been initialized
    print(e) 
    
import pathlib
import pickle
from pathlib import Path
sys.path.append(f"{Path.home()}/morpho_repo")
sys.path.append(f"{Path.home()}/morpho_repo/turing_codebase")
from turing.utils import *
from turing.tf_utils import *
import turing.pinns as tu
from turing.loss_functions import *
# Out:
# 2023-02-14 16:06:36.932018: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-14 16:06:37.148919: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-02-14 16:06:37.872332: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /end/home/rh2310/lib:/end/soft/Linux_2.6_64/lib::/end/home/rh2310/.conda/envs/tensorflow.2.10/lib
# 2023-02-14 16:06:37.872417: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /end/home/rh2310/lib:/end/soft/Linux_2.6_64/lib::/end/home/rh2310/.conda/envs/tensorflow.2.10/lib
# 2023-02-14 16:06:37.872425: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2023-02-14 16:06:39.660150: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-14 16:06:40.596564: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 8192 MB memory:  -> device: 0, name: NVIDIA A40, pci bus id: 0000:65:00.0, compute capability: 8.6
# 1 Physical GPUs, 1 Logical GPUs

# %%
from local_utils import *

# %% [markdown]
# # Note to remember
# # In this form of reshaping the datasets, u, u_xx, u_yy, u_t, v, v_xx and v_yy, v_t must be transposed to correctly show x and y coordinates
#
# # This note book use only one snapshot (the last), does not estimate the time derivatives and use the exact u and v to reduce the loss residual. FInaly, the parameters are constant.

# %%
sim_name = "Koch_Meinhardt_7"
x_slice=slice(0,100,1)#slice(30,65,1)#slice(0,100,1)#slice(30,65,1)#slice(50,65,1)#
y_slice=slice(0,100,1)#slice(50,85,1)#slice(0,100,1)#slice(50,85,1)#slice(70,85,1)#
pattern = load(sim_name, x_slice, y_slice,
               data_time_start=-3,
               data_time_len=2,
               data_time_step=1)

x_range = np.linspace(0, 1, pattern.simulation.n[0])*pattern.simulation.L[0]
y_range = np.linspace(0, 1, pattern.simulation.n[0])*pattern.simulation.L[1]
x_range = x_range[x_slice]
y_range = y_range[y_slice]

# %%
plt.figure(figsize=(12, 5))
plt.subplot(121)
plt.imshow(pattern.params["D_u"]*(pattern.c_xx[0,:, : , -1] + pattern.c_yy[0,:, : , -1]) - pattern.c_t[0,:, : , -1])
plt.colorbar()
plt.subplot(122)
plt.imshow(pattern.params["D_v"]*(pattern.c_xx[1,:, : , -1] + pattern.c_yy[1,:, : , -1]) - pattern.c_t[1,:, : , -1])
plt.colorbar()

# %%
x = tf.constant(x_range, dtype=tf.float32)
y = tf.constant(y_range, dtype=tf.float32)
# The order of the Y and X must be reversed,
# since the chnages the value finds the derivatives
#Y, X = tf.meshgrid(x, y)
X, Y = tf.meshgrid(x, y)
ts = tf.constant(pattern.t_star[-1:], dtype=tf.float32)
T = ts[tf.newaxis, tf.newaxis, :] * tf.ones(X.shape)[:, :, tf.newaxis]
H = tf.concat(
            [
                tf.concat(
                    [
                        X[tf.newaxis, :, :, tf.newaxis],
                        Y[tf.newaxis, :, :, tf.newaxis],
                        T[:, :, i : i + 1][tf.newaxis, :, :, :],
                    ],
                    axis=3,
                )
                for i in range(T.shape[-1])
            ],
            axis=0,
        )

# %%
H.shape
# Out:
# TensorShape([1, 100, 100, 3])

# %%
def grads(pinn, inputs):
    
    with tf.GradientTape(persistent=True) as tape:        
        tape.watch(inputs)      
        
        with tf.GradientTape(persistent=True) as tape2:             
            tape2.watch(inputs)            
            outputs = pinn.net(inputs)            
        
            u = tf.squeeze(outputs[:, 0])
            v = tf.squeeze(outputs[:, 1])
            
            grad_u = tape2.gradient(u, inputs)
            u_x = grad_u[:, 0]
            u_y = grad_u[:, 1]
            u_t = grad_u[:, 2]
            
            grad_v = tape2.gradient(v, inputs)
            v_x = grad_v[:, 0]
            v_y = grad_v[:, 1]
            v_t = grad_v[:, 2]
                    
        grad_u_x = tape.gradient(u_x, inputs)
        u_xx = grad_u_x[:, 0]
        #u_yx = grad_u_x[:, :, :, 1]
        #u_tx = grad_u_x[:, :, :, 2]
        grad_u_y = tape.gradient(u_y, inputs)
        #u_xy = grad_u_y[:, :, :, 0]
        u_yy = grad_u_y[:, 1]
        #u_ty = grad_u_y[:, :, :, 2]
        grad_v_x = tape.gradient(v_x, inputs)
        v_xx = grad_v_x[:, 0]
        #v_yx = grad_v_x[:, :, :, 1]
        #v_tx = grad_v_x[:, :, :, 2]
        grad_v_y = tape.gradient(v_y, inputs)
        #v_xy = grad_v_y[:, :, :, 0]
        v_yy = grad_v_y[:, 1]
        #v_ty = grad_v_y[:, :, :, 2]
                                     
    return (tf.squeeze(u),
            tf.squeeze(u_xx), tf.squeeze(u_yy), tf.squeeze(u_t),
            tf.squeeze(v),
            tf.squeeze(v_xx), tf.squeeze(v_yy), tf.squeeze(v_t))

# %%
class NN2(tu.NN):
    def build(self):
        """Create the state of the layers (weights)"""
        self.weights = []
        self.scales = []
        self.biases = []
        for i in range(0, self.num_layers - 1):
            W = self.xavier_init(size=[self.layers[i], self.layers[i + 1]])
            a = tf.Variable(tf.ones([1, self.layers[i + 1]], dtype=self.dtype), dtype=self.dtype)
            b = tf.Variable(tf.zeros([1, self.layers[i + 1]], dtype=self.dtype), dtype=self.dtype)
            self.weights.append(W)
            self.scales.append(a)
            self.biases.append(b)
        
        
    @tf.function
    def net(self, inputs):
        # Map the inputs to the range [-1, 1]
        H = 2.0 * (inputs - self.lb) / (self.ub - self.lb) - 1.0
        for W, a ,b in zip(self.weights[:-1], self.scales[:-1], self.biases[:-1]):
            outputs = tf.matmul(H, W)
            H = tf.tanh(a*outputs + b)

        W = self.weights[-1]
        a = self.scales[-1]
        b = self.biases[-1]
        outputs = tf.matmul(H, W)
        outputs = a*outputs + b*b/2.0
        return outputs

# %%
lb = tf.constant([x_range[0], y_range[0], pattern.t_star[0]], dtype=tf.float32)
ub =  tf.constant([x_range[-1], y_range[-1], pattern.t_star[-1]], dtype=tf.float32)
pinn = NN2([3, 128, 128, 2], lb, ub, tf.float32)

# %%
optimizer=keras.optimizers.Adam(learning_rate=1e-2)

D_u = tf.constant(pattern.params["D_u"], pinn.dtype, name="D_u")
D_v = tf.constant(pattern.params["D_v"], pinn.dtype, name="D_v")
def clip_by_value_zero_lb(z):
    return tf.clip_by_value(z, 1e-4, 1e10,)

init_per = 1.0
sigma_u = tf.Variable(pattern.params["sigma_u"]*init_per,
                      pinn.dtype,
                      name="sigma_u",
                      constraint=clip_by_value_zero_lb)


sigma_v = tf.Variable(pattern.params["sigma_v"]*init_per,
                      pinn.dtype,
                      name="sigma_v",
                      constraint=clip_by_value_zero_lb)

mu_u = tf.Variable(pattern.params["mu_u"]*init_per,
                   pinn.dtype,
                   name="mu_u",
                   constraint=clip_by_value_zero_lb)

rho_u = tf.Variable(pattern.params["rho_u"]*init_per,
                    pinn.dtype,
                    name="rho_u",
                    constraint=clip_by_value_zero_lb)

rho_v = tf.Variable(pattern.params["rho_v"]*init_per,
                    pinn.dtype,
                    name="rho_v",
                    constraint=clip_by_value_zero_lb)

kappa_u = tf.Variable(pattern.params["kappa_u"]*init_per,
                      pinn.dtype,
                      name="kappa_u",
                      constraint=clip_by_value_zero_lb)


params_tf = (sigma_u, sigma_v, mu_u, rho_u, rho_v, kappa_u,)


@tf.function
def train_step_inverse(elements):
    with tf.GradientTape(persistent=True) as tape: 
        H = elements[0]
        tape.watch(H)
        trainables = pinn.trainable_variables

        
        with tf.GradientTape(persistent=True) as tape2:             
            tape2.watch(H)
            
            outputs = pinn.net(H)
            ug = tf.squeeze(outputs[:, 0])
            vg = tf.squeeze(outputs[:, 1])
            
            grad_u = tape2.gradient(ug, H)
            u_x = grad_u[:, 0]
            u_y = grad_u[:, 1]
            #u_t = grad_u[:, 2]
            
            grad_v = tape2.gradient(vg, H)
            v_x = grad_v[:, 0]
            v_y = grad_v[:, 1]
            #v_t = grad_v[:, 2]
                    
        grad_u_x = tape.gradient(u_x, H)
        u_xx = grad_u_x[:, 0]
        #u_yx = grad_u_x[:, :, :, 1]
        #u_tx = grad_u_x[:, :, :, 2]
        grad_u_y = tape.gradient(u_y, H)
        #u_xy = grad_u_y[:, :, :, 0]
        u_yy = grad_u_y[:, 1]
        #u_ty = grad_u_y[:, :, :, 2]
        grad_v_x = tape.gradient(v_x, H)
        v_xx = grad_v_x[:, 0]
        #v_yx = grad_v_x[:, :, :, 1]
        #v_tx = grad_v_x[:, :, :, 2]
        grad_v_y = tape.gradient(v_y, H)
        #v_xy = grad_v_y[:, :, :, 0]
        v_yy = grad_v_y[:, 1]
        #v_ty = grad_v_y[:, :, :, 2]
                             
        u = tf.squeeze(elements[1][:, 0])
        v = tf.squeeze(elements[1][:, 1])
        #print(u)
        #print(u_xx)
        f = u * u * v / (1.0 + kappa_u * u * u)
        #print(u_xx.shape)
        #print(f.shape)
        f_u = D_u * (u_xx + u_yy) + rho_u * f - mu_u * u + sigma_u# - u_t
        f_v = D_v * (v_xx + v_yy) - rho_v * f + sigma_v# - v_t
        l2_res_u = tf.reduce_sum(f_u**2)
        l2_res_v = tf.reduce_sum(f_v**2)
        
#         u_diff = u - elements[1][:, 0, :, :]
#         v_diff = v - elements[1][:, 1, :, :]
#         l2_u_obs = tf.reduce_sum(u_diff**2)
#         l2_v_obs = tf.reduce_sum(v_diff**2)

                
        #l2 = l2_u_obs + l2_v_obs + l2_res_u + l2_res_v
        l2 = l2_res_u + l2_res_v
        
    #print(trainables)  
    grads = tape.gradient(l2, trainables)

#     print("=================================")
#     print(list(grads))
#     print()
    optimizer.apply_gradients(zip(grads, trainables))
    #return (l2_u_obs, l2_v_obs, l2_res_u, l2_res_v)
    return (l2_res_u, l2_res_v)

# %%
# Data is a three column matrix as (x,y,t), where
# first x changes, then y, and finally t (like Boolean tables)
data = tf.reshape(H, (H.shape[0]*H.shape[1]*H.shape[2],3))

# %%
#Select the last time step
# and reorder the x and y to match it
# with H
c_copy = np.einsum("cxy -> cyx", pattern.c[..., -1].copy())
#reshape c to flatten the data for each species
c = c_copy.reshape((2, pattern.c.shape[1]*pattern.c.shape[2]))
# and finnaly use its transposed, to have the each speacices in on column 
c = c.T
def gen_series():    
    
    for i in range(data.shape[0]):
        h = data[i,:]
        yield h, c[i,:]    
        
ds = tf.data.Dataset.from_generator(gen_series,
                                    output_types=(tf.float32, tf.float32), 
                                    output_shapes=((3,),(2,)))

# %%
batch_size = 5000
def print_callback(printer, losses, epoch):
    printer(f"at epoch {epoch:d}\n"
            f" total loss: {np.sum(losses)}"
            f"  u: {losses[0]},  v: {losses[1]},\n"
           # f" Res u: {losses[1]}, Res v: {losses[2]},\n"
           )
    
losses = tu.train(epochs=20000+1,
                  batch_size=batch_size,
                  dataset = ds ,
                  train_step = train_step_inverse,
                  train_step_returns_num = 2,
                  print_interval=100,
                  loss_sample_interval = 1,
                  stop_threshold=1e-5,
                  print_callback = print_callback,
                  epoch_callback=None)
# Out:
# Start of epoch 0
# WARNING:tensorflow:Calling GradientTape.gradient on a persistent tape inside its context is significantly less efficient than calling it outside the context (it causes the gradient ops to be recorded on the tape, leading to increased CPU and memory usage). Only call GradientTape.gradient inside the context if you actually want to trace the gradient in order to compute higher order derivatives.
# 2023-02-14 16:07:25.933597: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:630] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-02-14 16:07:25.957630: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x7f72c4003e90 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-02-14 16:07:25.957708: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): NVIDIA A40, Compute Capability 8.6
# 2023-02-14 16:07:25.965943: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-02-14 16:07:26.487865: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# at epoch 0
#  total loss: 3607.280957572162  u: 0.17121636122465134,  v: 3607.1097412109375,
#
# Time taken: 25.48s
#
# Start of epoch 100
# at epoch 100
#  total loss: 9.376111834135372  u: 0.0011113572982139885,  v: 9.375000476837158,
#
# Time taken: 5.76s
#
# Start of epoch 200
# at epoch 200
#  total loss: 8.178715167887276  u: 0.0006679877114947885,  v: 8.178047180175781,
#
# Time taken: 5.65s
#
# Start of epoch 300
# at epoch 300
#  total loss: 12.514974231511587  u: 0.0008975217642728239,  v: 12.514076709747314,
#
# Time taken: 5.59s
#
# Start of epoch 400
# at epoch 400
#  total loss: 23.37226054741768  u: 0.0014738805475644767,  v: 23.370786666870117,
#
# Time taken: 5.55s
#
# Start of epoch 500
# at epoch 500
#  total loss: 17.48027472337708  u: 0.0010915263555943966,  v: 17.479183197021484,
#
# Time taken: 5.64s
#
# Start of epoch 600
# at epoch 600
#  total loss: 3.7950018786941655  u: 0.0002862357650883496,  v: 3.794715642929077,
#
# Time taken: 5.58s
#
# Start of epoch 700
# at epoch 700
#  total loss: 2.7021387106651673  u: 0.00025086467212531716,  v: 2.701887845993042,
#
# Time taken: 5.57s
#
# Start of epoch 800
# at epoch 800
#  total loss: 16.510877551947488  u: 0.0010446929081808776,  v: 16.509832859039307,
#
# Time taken: 5.60s
#
# Start of epoch 900
# at epoch 900
#  total loss: 21.476096799888182  u: 0.001142194785643369,  v: 21.47495460510254,
#
# Time taken: 5.46s
#
# Start of epoch 1000
# at epoch 1000
#  total loss: 5.724763235339196  u: 0.00036819864180870354,  v: 5.724395036697388,
#
# Time taken: 5.44s
#
# Start of epoch 1100
# at epoch 1100
#  total loss: 9.401210397365503  u: 0.0006102024344727397,  v: 9.40060019493103,
#
# Time taken: 5.52s
#
# Start of epoch 1200
# at epoch 1200
#  total loss: 3.978719453421945  u: 0.00028107604157412425,  v: 3.978438377380371,
#
# Time taken: 5.54s
#
# Start of epoch 1300
# at epoch 1300
#  total loss: 2.2761347395862686  u: 0.00017179078713525087,  v: 2.2759629487991333,
#
# Time taken: 5.34s
#
# Start of epoch 1400
# at epoch 1400
#  total loss: 4.987751621978532  u: 0.00031795002723811194,  v: 4.987433671951294,
#
# Time taken: 5.44s
#
# Start of epoch 1500
# at epoch 1500
#  total loss: 2.411907373381837  u: 0.00017082543490687385,  v: 2.41173654794693,
#
# Time taken: 5.53s
#
# Start of epoch 1600
# at epoch 1600
#  total loss: 12.390422577940626  u: 0.0007736636034678668,  v: 12.389648914337158,
#
# Time taken: 5.58s
#
# Start of epoch 1700
# at epoch 1700
#  total loss: 7.949417263356736  u: 0.0004486144462134689,  v: 7.9489686489105225,
#
# Time taken: 5.50s
#
# Start of epoch 1800
# at epoch 1800
#  total loss: 6.041445114373346  u: 0.00037989830889273435,  v: 6.041065216064453,
#
# Time taken: 5.79s
#
# Start of epoch 1900
# at epoch 1900
#  total loss: 2.868549519778753  u: 0.00021463036682689562,  v: 2.8683348894119263,
#
# Time taken: 5.52s
#
# Start of epoch 2000
# at epoch 2000
#  total loss: 6.91348649864085  u: 0.00043990020640194416,  v: 6.913046598434448,
#
# Time taken: 5.51s
#
# Start of epoch 2100
# at epoch 2100
#  total loss: 11.357321346731624  u: 0.0006543049530591816,  v: 11.356667041778564,
#
# Time taken: 5.50s
#
# Start of epoch 2200
# at epoch 2200
#  total loss: 11.178158279130002  u: 0.0007233578653540462,  v: 11.177434921264648,
#
# Time taken: 5.49s
#
# Start of epoch 2300
# at epoch 2300
#  total loss: 6.189849434565986  u: 0.00038271970697678626,  v: 6.189466714859009,
#
# Time taken: 5.66s
#
# Start of epoch 2400
# at epoch 2400
#  total loss: 1.1881811841049057  u: 0.00010152893446502276,  v: 1.1880796551704407,
#
# Time taken: 5.39s
#
# Start of epoch 2500
# at epoch 2500
#  total loss: 2.1025662873689726  u: 0.0001488779489591252,  v: 2.1024174094200134,
#
# Time taken: 5.52s
#
# Start of epoch 2600
# at epoch 2600
#  total loss: 6.857780233651283  u: 0.0004301226435927674,  v: 6.85735011100769,
#
# Time taken: 5.44s
#
# Start of epoch 2700
# at epoch 2700
#  total loss: 2.2535179692931706  u: 0.00014077012019697577,  v: 2.2533771991729736,
#
# Time taken: 5.34s
#
# Start of epoch 2800
# at epoch 2800
#  total loss: 5.923988459537213  u: 0.0003883819081238471,  v: 5.923600077629089,
#
# Time taken: 5.56s
#
# Start of epoch 2900
# at epoch 2900
#  total loss: 11.26961513106653  u: 0.0006801659328630194,  v: 11.268934965133667,
#
# Time taken: 5.45s
#
# Start of epoch 3000
# at epoch 3000
#  total loss: 2.3391866800011485  u: 0.00016851393593242392,  v: 2.339018166065216,
#
# Time taken: 5.45s
#
# Start of epoch 3100
# at epoch 3100
#  total loss: 3.2542600248998497  u: 0.0002135847753379494,  v: 3.2540464401245117,
#
# Time taken: 5.69s
#
# Start of epoch 3200
# at epoch 3200
#  total loss: 2.794304496681434  u: 0.00020009938452858478,  v: 2.7941043972969055,
#
# Time taken: 5.55s
#
# Start of epoch 3300
# at epoch 3300
#  total loss: 2.7492675186731503  u: 0.00018513217946747318,  v: 2.749082386493683,
#
# Time taken: 5.41s
#
# Start of epoch 3400
# at epoch 3400
#  total loss: 3.643630548926012  u: 0.00024644991935929283,  v: 3.643384099006653,
#
# Time taken: 5.58s
#
# Start of epoch 3500
# at epoch 3500
#  total loss: 3.271611961266899  u: 0.00023058309307089075,  v: 3.271381378173828,
#
# Time taken: 5.47s
#
# Start of epoch 3600
# at epoch 3600
#  total loss: 0.9681002811266808  u: 8.468485611956567e-05,  v: 0.9680155962705612,
#
# Time taken: 5.45s
#
# Start of epoch 3700
# at epoch 3700
#  total loss: 2.7349187071431516  u: 0.00018841875680664089,  v: 2.734730288386345,
#
# Time taken: 5.58s
#
# Start of epoch 3800
# at epoch 3800
#  total loss: 7.974322325826506  u: 0.0005421706446213648,  v: 7.973780155181885,
#
# Time taken: 5.68s
#
# Start of epoch 3900
# at epoch 3900
#  total loss: 3.3414730786171276  u: 0.00022933472064323723,  v: 3.3412437438964844,
#
# Time taken: 5.42s
#
# Start of epoch 4000
# at epoch 4000
#  total loss: 6.144536608087947  u: 0.00038539730303455144,  v: 6.144151210784912,
#
# Time taken: 5.62s
#
# Start of epoch 4100
# at epoch 4100
#  total loss: 3.8555073295283364  u: 0.0002702031779335812,  v: 3.855237126350403,
#
# Time taken: 5.40s
#
# Start of epoch 4200
# at epoch 4200
#  total loss: 3.618433375711902  u: 0.00024356400535907596,  v: 3.618189811706543,
#
# Time taken: 5.42s
#
# Start of epoch 4300
# at epoch 4300
#  total loss: 8.400574085913831  u: 0.0004950739967171103,  v: 8.400079011917114,
#
# Time taken: 5.47s
#
# Start of epoch 4400
# at epoch 4400
#  total loss: 4.354686888123979  u: 0.00028518047474790365,  v: 4.354401707649231,
#
# Time taken: 5.46s
#
# Start of epoch 4500
# at epoch 4500
#  total loss: 3.3915028039045865  u: 0.0002489749022061005,  v: 3.3912538290023804,
#
# Time taken: 5.47s
#
# Start of epoch 4600
# at epoch 4600
#  total loss: 3.164303381847276  u: 0.00022085468663135543,  v: 3.1640825271606445,
#
# Time taken: 5.38s
#
# Start of epoch 4700
# at epoch 4700
#  total loss: 3.748083947910345  u: 0.0002519476547604427,  v: 3.7478320002555847,
#
# Time taken: 5.62s
#
# Start of epoch 4800
# at epoch 4800
#  total loss: 3.020087357144803  u: 0.00020265160128474236,  v: 3.019884705543518,
#
# Time taken: 5.46s
#
# Start of epoch 4900
# at epoch 4900
#  total loss: 3.969640098483069  u: 0.0002600773877929896,  v: 3.969380021095276,
#
# Time taken: 5.49s
#
# Start of epoch 5000
# at epoch 5000
#  total loss: 5.523640231956961  u: 0.0003622339863795787,  v: 5.523277997970581,
#
# Time taken: 5.52s
#
# Start of epoch 5100
# at epoch 5100
#  total loss: 5.75407699326388  u: 0.00040242651812150143,  v: 5.753674566745758,
#
# Time taken: 5.57s
#
# Start of epoch 5200
# at epoch 5200
#  total loss: 2.4302729698320036  u: 0.00018331729370402172,  v: 2.4300896525382996,
#
# Time taken: 5.40s
#
# Start of epoch 5300
# at epoch 5300
#  total loss: 0.7072723682631477  u: 7.145364179450553e-05,  v: 0.7072009146213531,
#
# Time taken: 5.48s
#
# Start of epoch 5400
# at epoch 5400
#  total loss: 0.2747047056618612  u: 4.788089427165687e-05,  v: 0.27465682476758957,
#
# Time taken: 5.47s
#
# Start of epoch 5500
# at epoch 5500
#  total loss: 0.04875103545418824  u: 3.821005157078616e-05,  v: 0.048712825402617455,
#
# Time taken: 5.58s
#
# Start of epoch 5600
# at epoch 5600
#  total loss: 0.7633212879991333  u: 9.457028863835149e-05,  v: 0.763226717710495,
#
# Time taken: 5.30s
#
# Start of epoch 5700
# at epoch 5700
#  total loss: 0.6314237657097692  u: 7.629013634868897e-05,  v: 0.6313474755734205,
#
# Time taken: 5.52s
#
# Start of epoch 5800
# at epoch 5800
#  total loss: 2.945462622476043  u: 0.0003047369245905429,  v: 2.9451578855514526,
#
# Time taken: 5.52s
#
# Start of epoch 5900
# at epoch 5900
#  total loss: 2.2370989737464697  u: 0.00019780969159910455,  v: 2.2369011640548706,
#
# Time taken: 5.49s
#
# Start of epoch 6000
# at epoch 6000
#  total loss: 4.288571346900426  u: 0.0003491531824693084,  v: 4.2882221937179565,
#
# Time taken: 5.57s
# Start of epoch 6100
# at epoch 6100
#  total loss: 7.965154058882035  u: 0.0005525421584025025,  v: 7.964601516723633,
#
# Time taken: 5.40s
#
# Start of epoch 6200
# at epoch 6200
#  total loss: 1.4914363141833746  u: 0.0001173730670416262,  v: 1.491318941116333,
#
# Time taken: 5.32s
#
# Start of epoch 6300
# at epoch 6300
#  total loss: 0.15514211529625754  u: 5.286359919409733e-05,  v: 0.15508925169706345,
#
# Time taken: 5.50s
#
# Start of epoch 6400
# at epoch 6400
#  total loss: 0.5679606790290563  u: 6.620535714318976e-05,  v: 0.5678944736719131,
#
# Time taken: 5.47s
#
# Start of epoch 6500
# at epoch 6500
#  total loss: 2.4989455471149995  u: 0.00018186665693065152,  v: 2.498763680458069,
#
# Time taken: 5.41s
#
# Start of epoch 6600
# at epoch 6600
#  total loss: 0.907591159997537  u: 0.00010358875806559809,  v: 0.9074875712394714,
#
# Time taken: 5.47s
#
# Start of epoch 6700
# at epoch 6700
#  total loss: 3.0885929701653367  u: 0.00019300857456983067,  v: 3.088399961590767,
#
# Time taken: 5.69s
#
# Start of epoch 6800
# at epoch 6800
#  total loss: 0.3740403915726347  u: 5.1122435252182186e-05,  v: 0.3739892691373825,
#
# Time taken: 5.51s
#
# Start of epoch 6900
# at epoch 6900
#  total loss: 2.0624180849117693  u: 0.0001532848400529474,  v: 2.0622648000717163,
#
# Time taken: 5.44s
#
# Start of epoch 7000
# at epoch 7000
#  total loss: 1.8155041601858102  u: 0.0001597669324837625,  v: 1.8153443932533264,
#
# Time taken: 5.59s
#
# Start of epoch 7100
# at epoch 7100
#  total loss: 0.6583435494103469  u: 7.210258627310395e-05,  v: 0.6582714468240738,
#
# Time taken: 5.40s
#
# Start of epoch 7200
# at epoch 7200
#  total loss: 5.38171463071194  u: 0.00039963780727703124,  v: 5.381314992904663,
#
# Time taken: 5.44s
#
# Start of epoch 7300
# at epoch 7300
#  total loss: 0.0705562170696794  u: 4.692488437285647e-05,  v: 0.07050929218530655,
#
# Time taken: 5.57s
#
# Start of epoch 7400
# at epoch 7400
#  total loss: 5.124047707402497  u: 0.0003811825154116377,  v: 5.123666524887085,
#
# Time taken: 5.52s
#
# Start of epoch 7500
# at epoch 7500
#  total loss: 5.746920104116725  u: 0.00034808644704753533,  v: 5.746572017669678,
#
# Time taken: 5.52s
#
# Start of epoch 7600
# at epoch 7600
#  total loss: 1.6062757083454926  u: 0.00011840548904729076,  v: 1.6061573028564453,
#
# Time taken: 5.51s
#
# Start of epoch 7700
# at epoch 7700
#  total loss: 4.000243689966737  u: 0.0002565645700087771,  v: 3.9999871253967285,
#
# Time taken: 5.63s
#
# Start of epoch 7800
# at epoch 7800
#  total loss: 3.261046769715904  u: 0.0002563024536357261,  v: 3.260790467262268,
#
# Time taken: 5.48s
#
# Start of epoch 7900
# at epoch 7900
#  total loss: 0.15570378383199568  u: 5.0120852392865345e-05,  v: 0.1556536629796028,
#
# Time taken: 5.34s
#
# Start of epoch 8000
# at epoch 8000
#  total loss: 0.03564889065819443  u: 4.024326699436642e-05,  v: 0.035608647391200066,
#
# Time taken: 5.34s
#
# Start of epoch 8100
# at epoch 8100
#  total loss: 0.044940378121282265  u: 3.6201044167682994e-05,  v: 0.04490417707711458,
#
# Time taken: 5.52s
#
# Start of epoch 8200
# at epoch 8200
#  total loss: 0.20092555226983677  u: 4.9338659664499573e-05,  v: 0.20087621361017227,
#
# Time taken: 5.50s
#
# Start of epoch 8300
# at epoch 8300
#  total loss: 9.636054901668103  u: 0.0006033464160282165,  v: 9.635451555252075,
#
# Time taken: 5.52s
#
# Start of epoch 8400
# at epoch 8400
#  total loss: 0.2212120560943731  u: 5.276184674585238e-05,  v: 0.22115929424762726,
#
# Time taken: 5.63s
#
# Start of epoch 8500
# at epoch 8500
#  total loss: 0.033979352314418065  u: 3.730667049239855e-05,  v: 0.03394204564392567,
#
# Time taken: 5.61s
#
# Start of epoch 8600
# at epoch 8600
#  total loss: 0.07273700838231889  u: 3.659916364995297e-05,  v: 0.07270040921866894,
#
# Time taken: 5.57s
#
# Start of epoch 8700
# at epoch 8700
#  total loss: 0.05303465920042072  u: 3.7273117413860746e-05,  v: 0.05299738608300686,
#
# Time taken: 5.49s
#
# Start of epoch 8800
# at epoch 8800
#  total loss: 0.28372488573040755  u: 4.8455147407366894e-05,  v: 0.2836764305830002,
#
# Time taken: 5.53s
#
# Start of epoch 8900
# at epoch 8900
#  total loss: 0.08551506596086256  u: 3.929706690541934e-05,  v: 0.08547576889395714,
#
# Time taken: 5.59s
#
# Start of epoch 9000
# at epoch 9000
#  total loss: 4.581889010849409  u: 0.001618124428205192,  v: 4.580270886421204,
#
# Time taken: 5.52s
#
# Start of epoch 9100
# at epoch 9100
#  total loss: 0.4048608616285492  u: 0.0006493851833511144,  v: 0.40421147644519806,
#
# Time taken: 5.46s
#
# Start of epoch 9200
# at epoch 9200
#  total loss: 0.5386459960864158  u: 0.00026880048972088844,  v: 0.538377195596695,
#
# Time taken: 5.39s
#
# Start of epoch 9300
# at epoch 9300
#  total loss: 0.6032602099512587  u: 0.00020856240735156462,  v: 0.6030516475439072,
#
# Time taken: 5.38s
#
# Start of epoch 9400
# at epoch 9400
#  total loss: 0.9716291325967177  u: 0.0001875060479505919,  v: 0.9714416265487671,
#
# Time taken: 5.46s
#
# Start of epoch 9500
# at epoch 9500
#  total loss: 9.777525146462722  u: 0.0007464484951924533,  v: 9.77677869796753,
#
# Time taken: 5.52s
#
# Start of epoch 9600
# at epoch 9600
#  total loss: 2.659478213863622  u: 0.00022746272588847205,  v: 2.6592507511377335,
#
# Time taken: 5.71s
#
# Start of epoch 9700
# at epoch 9700
#  total loss: 1.3255893029781873  u: 0.00017357250180793926,  v: 1.3254157304763794,
#
# Time taken: 5.54s
#
# Start of epoch 9800
# at epoch 9800
#  total loss: 0.742022815727978  u: 0.00010452010610606521,  v: 0.741918295621872,
#
# Time taken: 5.74s
#
# Start of epoch 9900
# at epoch 9900
#  total loss: 1.1917980453908967  u: 0.0001417464554833714,  v: 1.1916562989354134,
#
# Time taken: 5.52s
#
# Start of epoch 10000
# at epoch 10000
#  total loss: 4.559092473391502  u: 0.000350307826010976,  v: 4.558742165565491,
#
# Time taken: 5.61s
#
# Start of epoch 10100
# at epoch 10100
#  total loss: 9.900188429077389  u: 0.000651581009151414,  v: 9.899536848068237,
#
# Time taken: 5.63s
#
# Start of epoch 10200
# at epoch 10200
#  total loss: 6.877472234249581  u: 0.0004835848812945187,  v: 6.876988649368286,
#
# Time taken: 5.67s
#
# Start of epoch 10300
# at epoch 10300
#  total loss: 8.93742406561796  u: 0.0005847235006513074,  v: 8.93683934211731,
#
# Time taken: 5.38s
#
# Start of epoch 10400
# at epoch 10400
#  total loss: 0.9411126576560491  u: 0.00011517630991875194,  v: 0.9409974813461304,
#
# Time taken: 5.50s
#
# Start of epoch 10500
# at epoch 10500
#  total loss: 0.08514647938682174  u: 6.16461820754921e-05,  v: 0.08508483320474625,
#
# Time taken: 5.39s
#
# Start of epoch 10600
# at epoch 10600
#  total loss: 0.12053340927013778  u: 5.842253813170828e-05,  v: 0.12047498673200607,
#
# Time taken: 5.46s
#
# Start of epoch 10700
# at epoch 10700
#  total loss: 0.1283221835255972  u: 6.325859430944547e-05,  v: 0.12825892493128777,
#
# Time taken: 5.48s
#
# Start of epoch 10800
# at epoch 10800
#  total loss: 0.07413532445025339  u: 5.4048838137532584e-05,  v: 0.07408127561211586,
#
# Time taken: 5.52s
#
# Start of epoch 10900
# at epoch 10900
#  total loss: 0.4146967426095216  u: 7.03752193658147e-05,  v: 0.4146263673901558,
#
# Time taken: 5.43s
#
# Start of epoch 11000
# at epoch 11000
#  total loss: 0.6685198989252967  u: 8.888510274118744e-05,  v: 0.6684310138225555,
#
# Time taken: 5.53s
#
# Start of epoch 11100
# at epoch 11100
#  total loss: 4.7004067663656315  u: 0.00030062241421546787,  v: 4.700106143951416,
#
# Time taken: 5.54s
#
# Start of epoch 11200
# at epoch 11200
#  total loss: 0.4750710364533006  u: 7.093065505614504e-05,  v: 0.4750001057982445,
#
# Time taken: 5.42s
#
# Start of epoch 11300
# at epoch 11300
#  total loss: 0.11898035356716719  u: 5.345592217054218e-05,  v: 0.11892689764499664,
#
# Time taken: 5.43s
#
# Start of epoch 11400
# at epoch 11400
#  total loss: 1.07947673408853  u: 9.815900193643756e-05,  v: 1.0793785750865936,
#
# Time taken: 5.56s
#
# Start of epoch 11500
# at epoch 11500
#  total loss: 3.0136222525470657  u: 0.0002112074726028368,  v: 3.013411045074463,
#
# Time taken: 5.47s
#
# Start of epoch 11600
# at epoch 11600
#  total loss: 1.4539725054928567  u: 0.00013880626647733152,  v: 1.4538336992263794,
#
# Time taken: 5.49s
#
# Start of epoch 11700
# at epoch 11700
#  total loss: 0.04422249646995624  u: 4.3630619984469377e-05,  v: 0.04417886584997177,
#
# Time taken: 5.60s
#
# Start of epoch 11800
# at epoch 11800
#  total loss: 0.06810998036235105  u: 4.897690087091178e-05,  v: 0.06806100346148014,
#
# Time taken: 5.60s
#
# Start of epoch 11900
# at epoch 11900
#  total loss: 0.37792630621152057  u: 8.184590296878014e-05,  v: 0.3778444603085518,
#
# Time taken: 5.45s
#
# Start of epoch 12000
# at epoch 12000
#  total loss: 4.348645685680822  u: 0.00031152225346886553,  v: 4.348334163427353,
#
# Time taken: 5.50s
# Start of epoch 12100
# at epoch 12100
#  total loss: 0.0371926995121612  u: 5.870593122381251e-05,  v: 0.037133993580937386,
#
# Time taken: 5.47s
#
# Start of epoch 12200
# at epoch 12200
#  total loss: 0.16426714568478928  u: 5.766063077317085e-05,  v: 0.1642094850540161,
#
# Time taken: 5.48s
#
# Start of epoch 12300
# at epoch 12300
#  total loss: 7.8574483749507635  u: 0.0005296227573126089,  v: 7.856918752193451,
#
# Time taken: 5.50s
#
# Start of epoch 12400
# at epoch 12400
#  total loss: 0.22435954212778597  u: 5.897134178667329e-05,  v: 0.2243005707859993,
#
# Time taken: 5.62s
#
# Start of epoch 12500
# at epoch 12500
#  total loss: 0.029355035765547655  u: 4.765451558341738e-05,  v: 0.029307381249964237,
#
# Time taken: 5.49s
#
# Start of epoch 12600
# at epoch 12600
#  total loss: 0.24855771167494822  u: 7.948903657961637e-05,  v: 0.2484782226383686,
#
# Time taken: 5.41s
#
# Start of epoch 12700
# at epoch 12700
#  total loss: 0.8820894810924074  u: 0.00010106000991072506,  v: 0.8819884210824966,
#
# Time taken: 5.37s
#
# Start of epoch 12800
# at epoch 12800
#  total loss: 0.029499258864234434  u: 5.400182635639794e-05,  v: 0.029445257037878036,
#
# Time taken: 5.42s
#
# Start of epoch 12900
# at epoch 12900
#  total loss: 0.6314612978567311  u: 9.330897228210233e-05,  v: 0.631367988884449,
#
# Time taken: 5.47s
#
# Start of epoch 13000
# at epoch 13000
#  total loss: 0.8819735721517645  u: 0.00010428585301269777,  v: 0.8818692862987518,
#
# Time taken: 5.54s
#
# Start of epoch 13100
# at epoch 13100
#  total loss: 0.6495652077210252  u: 8.912658813642338e-05,  v: 0.6494760811328888,
#
# Time taken: 5.39s
#
# Start of epoch 13200
# at epoch 13200
#  total loss: 0.9595877829815436  u: 0.00011298096433165483,  v: 0.9594748020172119,
#
# Time taken: 5.43s
#
# Start of epoch 13300
# at epoch 13300
#  total loss: 0.10334603648152552  u: 7.33227607270237e-05,  v: 0.10327271372079849,
#
# Time taken: 5.44s
#
# Start of epoch 13400
# at epoch 13400
#  total loss: 0.03960010941591463  u: 5.339618292055093e-05,  v: 0.03954671323299408,
#
# Time taken: 5.40s
#
# Start of epoch 13500
# at epoch 13500
#  total loss: 0.13514571646192053  u: 6.533050873258617e-05,  v: 0.13508038595318794,
#
# Time taken: 5.49s
#
# Start of epoch 13600
# at epoch 13600
#  total loss: 7.960112802888034  u: 0.0006267951976042241,  v: 7.95948600769043,
#
# Time taken: 5.39s
#
# Start of epoch 13700
# at epoch 13700
#  total loss: 0.17120973309283727  u: 6.050904994481243e-05,  v: 0.17114922404289246,
#
# Time taken: 5.40s
#
# Start of epoch 13800
# at epoch 13800
#  total loss: 0.034500790236052126  u: 5.4198724683374166e-05,  v: 0.03444659151136875,
#
# Time taken: 5.49s
#
# Start of epoch 13900
# at epoch 13900
#  total loss: 0.05058802922394534  u: 5.402301576395985e-05,  v: 0.05053400620818138,
#
# Time taken: 5.50s
#
# Start of epoch 14000
# at epoch 14000
#  total loss: 0.05157243518442556  u: 5.48424413864268e-05,  v: 0.05151759274303913,
#
# Time taken: 5.58s
#
# Start of epoch 14100
# at epoch 14100
#  total loss: 3.080235886242008  u: 0.00027703013620339334,  v: 3.0799588561058044,
#
# Time taken: 5.49s
#
# Start of epoch 14200
# at epoch 14200
#  total loss: 0.46761506018810906  u: 9.705839329399168e-05,  v: 0.46751800179481506,
#
# Time taken: 5.42s
#
# Start of epoch 14300
# at epoch 14300
#  total loss: 6.5666946315323  u: 0.0005170249496586621,  v: 6.566177606582642,
#
# Time taken: 5.45s
#
# Start of epoch 14400
# at epoch 14400
#  total loss: 0.8154901637863077  u: 0.0001035108398355078,  v: 0.8153866529464722,
#
# Time taken: 5.48s
#
# Start of epoch 14500
# at epoch 14500
#  total loss: 0.0929723976933019  u: 0.00013908360233472195,  v: 0.09283331409096718,
#
# Time taken: 5.63s
#
# Start of epoch 14600
# at epoch 14600
#  total loss: 0.026186459906966775  u: 5.4205976994126104e-05,  v: 0.02613225392997265,
#
# Time taken: 5.61s
#
# Start of epoch 14700
# at epoch 14700
#  total loss: 0.034295608285901835  u: 5.179550134926103e-05,  v: 0.034243812784552574,
#
# Time taken: 5.44s
#
# Start of epoch 14800
# at epoch 14800
#  total loss: 0.8593559461151017  u: 0.0002250867401016876,  v: 0.859130859375,
#
# Time taken: 5.42s
#
# Start of epoch 14900
# at epoch 14900
#  total loss: 0.028336094286714797  u: 5.868409243703354e-05,  v: 0.028277410194277763,
#
# Time taken: 5.56s
#
# Start of epoch 15000
# at epoch 15000
#  total loss: 1.0788406050960475  u: 0.0001369185010844376,  v: 1.078703686594963,
#
# Time taken: 5.43s
#
# Start of epoch 15100
# at epoch 15100
#  total loss: 0.7017555851889483  u: 0.00010931682118098252,  v: 0.7016462683677673,
#
# Time taken: 5.47s
#
# Start of epoch 15200
# at epoch 15200
#  total loss: 0.05297835850979027  u: 5.5036785852280445e-05,  v: 0.05292332172393799,
#
# Time taken: 5.51s
#
# Start of epoch 15300
# at epoch 15300
#  total loss: 0.02117105171237199  u: 5.947396311967168e-05,  v: 0.02111157774925232,
#
# Time taken: 5.33s
#
# Start of epoch 15400
# at epoch 15400
#  total loss: 0.029237511605970212  u: 6.340913569147233e-05,  v: 0.02917410247027874,
#
# Time taken: 5.49s
#
# Start of epoch 15500
# at epoch 15500
#  total loss: 0.18582514344961965  u: 7.544129402958788e-05,  v: 0.18574970215559006,
#
# Time taken: 5.30s
#
# Start of epoch 15600
# at epoch 15600
#  total loss: 0.22981168937621987  u: 7.91312450019177e-05,  v: 0.22973255813121796,
#
# Time taken: 5.45s
#
# Start of epoch 15700
# at epoch 15700
#  total loss: 0.19897259190111072  u: 7.677241592318751e-05,  v: 0.19889581948518753,
#
# Time taken: 5.50s
#
# Start of epoch 15800
# at epoch 15800
#  total loss: 0.12826734603731893  u: 0.000686368060996756,  v: 0.12758097797632217,
#
# Time taken: 5.42s
#
# Start of epoch 15900
# at epoch 15900
#  total loss: 0.055017137550748885  u: 0.00023708643857389688,  v: 0.05478005111217499,
#
# Time taken: 5.51s
#
# Start of epoch 16000
# at epoch 16000
#  total loss: 0.763218720399891  u: 0.00023477240756619722,  v: 0.7629839479923248,
#
# Time taken: 5.54s
#
# Start of epoch 16100
# at epoch 16100
#  total loss: 0.38426365416671615  u: 0.00016724031593184918,  v: 0.3840964138507843,
#
# Time taken: 5.40s
#
# Start of epoch 16200
# at epoch 16200
#  total loss: 0.027994511467113625  u: 0.00011757463653339073,  v: 0.027876936830580235,
#
# Time taken: 5.46s
#
# Start of epoch 16300
# at epoch 16300
#  total loss: 0.03131460525401053  u: 0.00012386717207846232,  v: 0.031190738081932068,
#
# Time taken: 5.54s
#
# Start of epoch 16400
# at epoch 16400
#  total loss: 5.495989613060374  u: 0.0006593985599465668,  v: 5.495330214500427,
#
# Time taken: 5.51s
#
# Start of epoch 16500
# at epoch 16500
#  total loss: 0.027204407680983422  u: 0.000118401203508256,  v: 0.027086006477475166,
#
# Time taken: 5.58s
#
# Start of epoch 16600
# at epoch 16600
#  total loss: 0.3092865089456609  u: 0.00013378658695728518,  v: 0.3091527223587036,
#
# Time taken: 5.78s
#
# Start of epoch 16700
# at epoch 16700
#  total loss: 1.8826398543606047  u: 0.00026407759287394583,  v: 1.8823757767677307,
#
# Time taken: 5.76s
#
# Start of epoch 16800
# at epoch 16800
#  total loss: 0.40077449391174014  u: 0.00014348151671583764,  v: 0.4006310123950243,
#
# Time taken: 5.74s
#
# Start of epoch 16900
# at epoch 16900
#  total loss: 0.07969778603001032  u: 0.00012215426249895245,  v: 0.07957563176751137,
#
# Time taken: 5.68s
#
# Start of epoch 17000
# at epoch 17000
#  total loss: 0.06995397810533177  u: 0.00011047725274693221,  v: 0.06984350085258484,
#
# Time taken: 5.61s
#
# Start of epoch 17100
# at epoch 17100
#  total loss: 0.07561549613456009  u: 0.00013540568033931777,  v: 0.07548009045422077,
#
# Time taken: 5.67s
#
# Start of epoch 17200
# at epoch 17200
#  total loss: 3.6760959181265207  u: 0.0005220922903390601,  v: 3.6755738258361816,
#
# Time taken: 5.97s
#
# Start of epoch 17300
# at epoch 17300
#  total loss: 0.657434326094517  u: 0.00020600525749614462,  v: 0.6572283208370209,
#
# Time taken: 5.73s
#
# Start of epoch 17400
# at epoch 17400
#  total loss: 0.16369120712624863  u: 0.00014193292008712888,  v: 0.1635492742061615,
#
# Time taken: 5.87s
#
# Start of epoch 17500
# at epoch 17500
#  total loss: 0.983788442259538  u: 0.0002375360782025382,  v: 0.9835509061813354,
#
# Time taken: 5.79s
#
# Start of epoch 17600
# at epoch 17600
#  total loss: 2.2822813594102627  u: 0.00031032202241476625,  v: 2.281971037387848,
#
# Time taken: 5.74s
#
# Start of epoch 17700
# at epoch 17700
#  total loss: 1.4032628393615596  u: 0.00026859407080337405,  v: 1.4029942452907562,
#
# Time taken: 5.71s
#
# Start of epoch 17800
# at epoch 17800
#  total loss: 0.994439475623949  u: 0.00021422692952910438,  v: 0.9942252486944199,
#
# Time taken: 5.78s
#
# Start of epoch 17900
# at epoch 17900
#  total loss: 1.232585201949405  u: 0.00021357366495067254,  v: 1.2323716282844543,
#
# Time taken: 5.65s
# Start of epoch 18000
# at epoch 18000
#  total loss: 0.23208329824410612  u: 0.00013107059203321114,  v: 0.2319522276520729,
#
# Time taken: 5.81s
#
# Start of epoch 18100
# at epoch 18100
#  total loss: 0.9085627049644245  u: 0.00021903221204411238,  v: 0.9083436727523804,
#
# Time taken: 5.84s
#
# Start of epoch 18200
# at epoch 18200
#  total loss: 1.115164025046397  u: 0.0002763404627330601,  v: 1.114887684583664,
#
# Time taken: 5.61s
#
# Start of epoch 18300
# at epoch 18300
#  total loss: 0.5646628719259752  u: 0.00018834885850083083,  v: 0.5644745230674744,
#
# Time taken: 5.55s
#
# Start of epoch 18400
# at epoch 18400
#  total loss: 0.5688206975974026  u: 0.00018711142911342904,  v: 0.5686335861682892,
#
# Time taken: 5.56s
#
# Start of epoch 18500
# at epoch 18500
#  total loss: 0.3811066320340615  u: 0.00020497498917393386,  v: 0.38090165704488754,
#
# Time taken: 5.51s
#
# Start of epoch 18600
# at epoch 18600
#  total loss: 0.6790259553090436  u: 0.00022215377248357981,  v: 0.6788038015365601,
#
# Time taken: 5.58s
#
# Start of epoch 18700
# at epoch 18700
#  total loss: 1.1940929089105339  u: 0.00024292807938763872,  v: 1.1938499808311462,
#
# Time taken: 5.51s
#
# Start of epoch 18800
# at epoch 18800
#  total loss: 0.36545338355426793  u: 0.00014767669563298114,  v: 0.36530570685863495,
#
# Time taken: 5.62s
#
# Start of epoch 18900
# at epoch 18900
#  total loss: 1.2300758332712576  u: 0.00029861635994166136,  v: 1.229777216911316,
#
# Time taken: 5.54s
#
# Start of epoch 19000
# at epoch 19000
#  total loss: 0.6660544794140151  u: 0.00023018532374408096,  v: 0.665824294090271,
#
# Time taken: 5.47s
#
# Start of epoch 19100
# at epoch 19100
#  total loss: 1.3150111331779044  u: 0.00025861404719762504,  v: 1.3147525191307068,
#
# Time taken: 5.42s
#
# Start of epoch 19200
# at epoch 19200
#  total loss: 1.2598846638647956  u: 0.00033191685361089185,  v: 1.2595527470111847,
#
# Time taken: 5.47s
#
# Start of epoch 19300
# at epoch 19300
#  total loss: 0.2289711119774438  u: 0.00016478394900332205,  v: 0.22880632802844048,
#
# Time taken: 5.46s
#
# Start of epoch 19400
# at epoch 19400
#  total loss: 0.3939826592504687  u: 0.00017736402151058428,  v: 0.39380529522895813,
#
# Time taken: 5.52s
#
# Start of epoch 19500
# at epoch 19500
#  total loss: 0.16876495979886386  u: 0.0001592857406649273,  v: 0.16860567405819893,
#
# Time taken: 5.51s
#
# Start of epoch 19600
# at epoch 19600
#  total loss: 0.02396685672647436  u: 0.00012674690879066475,  v: 0.023840109817683697,
#
# Time taken: 5.59s
#
# Start of epoch 19700
# at epoch 19700
#  total loss: 0.39980361851121415  u: 0.00016721578504075296,  v: 0.3996364027261734,
#
# Time taken: 5.65s
#
# Start of epoch 19800
# at epoch 19800
#  total loss: 1.6366944289475214  u: 0.0002955174713861197,  v: 1.6363989114761353,
#
# Time taken: 5.55s
#
# Start of epoch 19900
# at epoch 19900
#  total loss: 1.0387231062704814  u: 0.00021755207126261666,  v: 1.0385055541992188,
#
# Time taken: 5.59s
#
# Start of epoch 20000
# at epoch 20000
#  total loss: 0.8384139817644609  u: 0.00020277318253647536,  v: 0.8382112085819244,
#
# Time taken: 5.55s

# %%
losses2 = tu.train(epochs=20000+1,
                  batch_size=batch_size,
                  dataset = ds ,
                  train_step = train_step_inverse,
                  train_step_returns_num = 2,
                  print_interval=100,
                  loss_sample_interval = 1,
                  stop_threshold=.015,
                  print_callback = print_callback,
                  epoch_callback=None)
# Out:
# Start of epoch 0
# at epoch 0
#  total loss: 0.9183310768421507  u: 0.00024004791339393705,  v: 0.9180910289287567,
#
# Time taken: 13.82s
#
# Start of epoch 100
# at epoch 100
#  total loss: 0.6146098511308082  u: 0.00015663970407331362,  v: 0.6144532114267349,
#
# Time taken: 5.65s
#
# Start of epoch 200
# at epoch 200
#  total loss: 1.0014009166043252  u: 0.00023570540361106396,  v: 1.0011652112007141,
#
# Time taken: 5.57s
#
# Start of epoch 300
# at epoch 300
#  total loss: 0.30111906336969696  u: 0.000157725386088714,  v: 0.30096133798360825,
#
# Time taken: 5.57s
#
# Start of epoch 400
# at epoch 400
#  total loss: 0.7002430090142298  u: 0.0002044567299890332,  v: 0.7000385522842407,
#
# Time taken: 5.51s
#
# Start of epoch 500
# at epoch 500
#  total loss: 0.7910466501634801  u: 0.00017911290342453867,  v: 0.7908675372600555,
#
# Time taken: 5.52s
#
# Start of epoch 600
# at epoch 600
#  total loss: 0.27535930179146817  u: 0.00016109176067402586,  v: 0.27519821003079414,
#
# Time taken: 5.48s
#
# Start of epoch 700
# at epoch 700
#  total loss: 0.09310791215102654  u: 0.00014882853429298848,  v: 0.09295908361673355,
#
# Time taken: 5.54s
#
# Start of epoch 800
# at epoch 800
#  total loss: 0.2996656326431548  u: 0.00017595569079276174,  v: 0.29948967695236206,
#
# Time taken: 5.51s
#
# Start of epoch 900
# at epoch 900
#  total loss: 0.07291118212742731  u: 0.0001199624384753406,  v: 0.07279121968895197,
#
# Time taken: 5.59s
#
# Start of epoch 1000
# at epoch 1000
#  total loss: 0.160086157364276  u: 0.00013733152809436433,  v: 0.15994882583618164,
#
# Time taken: 5.59s
#
# Start of epoch 1100
# at epoch 1100
#  total loss: 0.6523919074206788  u: 0.0001767842441040557,  v: 0.6522151231765747,
#
# Time taken: 5.60s
#
# Start of epoch 1200
# at epoch 1200
#  total loss: 1.7528097469039494  u: 0.00023005787807051092,  v: 1.752579689025879,
#
# Time taken: 5.54s
#
# Start of epoch 1300
# at epoch 1300
#  total loss: 0.18202705720250378  u: 0.00012728610818157904,  v: 0.1818997710943222,
#
# Time taken: 5.61s
#
# Start of epoch 1400
# at epoch 1400
#  total loss: 0.20020678705259343  u: 0.00013043052240391262,  v: 0.20007635653018951,
#
# Time taken: 5.52s
#
# Start of epoch 1500
# at epoch 1500
#  total loss: 0.46517229181336006  u: 0.0001943419556482695,  v: 0.4649779498577118,
#
# Time taken: 5.57s
#
# Start of epoch 1600
# at epoch 1600
#  total loss: 0.120051205783966  u: 0.00011492583143990487,  v: 0.11993627995252609,
#
# Time taken: 5.66s
#
# Start of epoch 1700
# at epoch 1700
#  total loss: 0.1311164143080532  u: 0.00011691623876686208,  v: 0.13099949806928635,
#
# Time taken: 5.61s
#
# Start of epoch 1800
# at epoch 1800
#  total loss: 0.11826809561171103  u: 0.00011674193956423551,  v: 0.1181513536721468,
#
# Time taken: 5.54s
#
# Start of epoch 1900
# at epoch 1900
#  total loss: 0.07467957613334875  u: 0.00011930455730180256,  v: 0.07456027157604694,
#
# Time taken: 5.70s
#
# Start of epoch 2000
# at epoch 2000
#  total loss: 1.6442017371155089  u: 0.00033597297442611307,  v: 1.6438657641410828,
#
# Time taken: 5.62s
# ############################################
# #       Early stop at 2039
# ############################################

# %%
plt.plot(losses[:,0])
plt.plot(losses[:,1])
plt.yscale('log')

# %%
np.min(np.sum(losses, axis=1))
# Out:
# 0.0124783281062264

# %%
(u, u_xx, u_yy, u_t, v, v_xx, v_yy, v_t) = grads(pinn, data)
# Out:
# WARNING:tensorflow:Calling GradientTape.gradient on a persistent tape inside its context is significantly less efficient than calling it outside the context (it causes the gradient ops to be recorded on the tape, leading to increased CPU and memory usage). Only call GradientTape.gradient inside the context if you actually want to trace the gradient in order to compute higher order derivatives.
# WARNING:tensorflow:Calling GradientTape.gradient on a persistent tape inside its context is significantly less efficient than calling it outside the context (it causes the gradient ops to be recorded on the tape, leading to increased CPU and memory usage). Only call GradientTape.gradient inside the context if you actually want to trace the gradient in order to compute higher order derivatives.
# WARNING:tensorflow:Calling GradientTape.gradient on a persistent tape inside its context is significantly less efficient than calling it outside the context (it causes the gradient ops to be recorded on the tape, leading to increased CPU and memory usage). Only call GradientTape.gradient inside the context if you actually want to trace the gradient in order to compute higher order derivatives.
# WARNING:tensorflow:Calling GradientTape.gradient on a persistent tape inside its context is significantly less efficient than calling it outside the context (it causes the gradient ops to be recorded on the tape, leading to increased CPU and memory usage). Only call GradientTape.gradient inside the context if you actually want to trace the gradient in order to compute higher order derivatives.
# WARNING:tensorflow:Calling GradientTape.gradient on a persistent tape inside its context is significantly less efficient than calling it outside the context (it causes the gradient ops to be recorded on the tape, leading to increased CPU and memory usage). Only call GradientTape.gradient inside the context if you actually want to trace the gradient in order to compute higher order derivatives.
# WARNING:tensorflow:Calling GradientTape.gradient on a persistent tape inside its context is significantly less efficient than calling it outside the context (it causes the gradient ops to be recorded on the tape, leading to increased CPU and memory usage). Only call GradientTape.gradient inside the context if you actually want to trace the gradient in order to compute higher order derivatives.

# %%
def to(arr):
    return arr.numpy().reshape(y_range.shape[0], x_range.shape[0])

actual_u_der = pattern.params["D_u"]*(pattern.c_xx[0,:, : , -1] + pattern.c_yy[0,:, : , -1]) - pattern.c_t[0,:, : , -1]
actual_v_der = pattern.params["D_v"]*(pattern.c_xx[1,:, : , -1] + pattern.c_yy[1,:, : , -1]) - pattern.c_t[1,:, : , -1]

u_der = pattern.params["D_u"]*( to(u_xx) + to(u_yy))# - to(u_t2)[-1, ...]
v_der = pattern.params["D_v"]*( to(v_xx)+ to(v_yy))# - to(v_t2)[-1, ...]
# X and Y are misoriented
u_der = u_der.T
v_der = v_der.T

u = pattern.c[0,:, : , -1]
v = pattern.c[1,:, : , -1]
f = u * u * v / (1.0 + kappa_u * u * u)
f_u =  rho_u * f - mu_u * u + sigma_u
f_v =  - rho_v * f + sigma_v

# %%
plt.figure(figsize=(12, 8))
plt.subplot(341)
plt.imshow(to(u_xx).T)
plt.colorbar()
plt.subplot(342)
plt.imshow(pattern.c_xx[0,:, : , -1])
plt.colorbar()
plt.subplot(343)
plt.imshow(to(u_yy).T)
plt.colorbar()
plt.subplot(344)
plt.imshow(pattern.c_yy[0,:, : , -1])
plt.colorbar()
plt.subplot(345)
plt.imshow(to(v_xx).T)
plt.colorbar()
plt.subplot(346)
plt.imshow(pattern.c_xx[1,:, : , -1])
plt.colorbar()
plt.subplot(347)
plt.imshow(to(v_yy).T)
plt.colorbar()
plt.subplot(3,4,8)
plt.imshow(pattern.c_yy[1,:, : , -1])
plt.colorbar()
plt.tight_layout()
plt.subplot(3,4,9)
plt.imshow(to(u_t))
plt.colorbar()
plt.subplot(3,4,10)
plt.imshow(pattern.c_t[0,:, : , -1])
plt.colorbar()
plt.subplot(3,4,11)
plt.imshow(to(v_t))
plt.colorbar()
plt.subplot(3,4,12)
plt.imshow(pattern.c_t[1,:, : , -1])
plt.colorbar()
plt.tight_layout()
plt.show()


plt.figure(figsize=(12, 8))
plt.subplot(221)
plt.imshow(u_der)
plt.colorbar()
plt.subplot(222)
plt.imshow(actual_u_der)
plt.colorbar()
plt.subplot(223)
plt.imshow(v_der)
plt.colorbar()
plt.subplot(224)
plt.imshow(actual_v_der)
plt.colorbar()

# %%
actual_u_der.shape
# Out:
# (100, 100)

# %%
def SE(ar1, ar2):
    return np.sum((ar1 - ar2)**2)
def RMSE(ar1, ar2):
    return np.sqrt(np.mean((ar1 - ar2)**2))
def RMSE_relative(ar1, ar2):
    return np.sqrt(np.mean((ar1/(ar2 + 1e-16) - 1)**2))
def max_diff(ar1, ar2):
    return np.max(np.abs(ar1 - ar2))

# %%
losses2[-1]
# Out:
# array([0.00011667, 0.01656414])

# %%
SE(f_u, -u_der)
# Out:
# 0.000116151976

# %%
SE(f_v, -v_der)
# Out:
# 0.014049141

# %%
plt.figure(figsize=(12, 5))
plt.subplot(131)
plt.imshow(f_u)
plt.colorbar()
plt.subplot(132)
plt.imshow(u_der)
plt.colorbar()
plt.subplot(133)
plt.imshow(u_der+f_u)
plt.colorbar()

# %%
plt.figure(figsize=(12, 5))
plt.subplot(221)
plt.imshow(u_der)
plt.colorbar()
plt.subplot(222)
plt.imshow(actual_u_der)
plt.colorbar()
plt.subplot(223)
plt.imshow(u.reshape(100, 100))
plt.colorbar()
plt.subplot(224)
plt.imshow(pattern.c[0, :, :, -1])
plt.colorbar()
plt.show()

# %%
plt.figure(figsize=(12, 5))
plt.subplot(221)
plt.imshow(v_der)
plt.colorbar()
plt.subplot(222)
plt.imshow(actual_v_der)
plt.colorbar()
plt.subplot(223)
plt.imshow(v.reshape(100, 100))
plt.colorbar()
plt.subplot(224)
plt.imshow(pattern.c[1, :, :, -1])
plt.colorbar()
plt.show()

# %%
print(SE(u_der, actual_u_der))
print(RMSE(u_der, actual_u_der))
print(RMSE_relative(u_der, actual_u_der))
print(max_diff(u_der, actual_u_der))

plt.figure(figsize=(12, 5))
plt.subplot(131)
plt.imshow(u_der)
plt.colorbar()
plt.subplot(132)
plt.imshow(u_der-actual_u_der)
plt.colorbar()
plt.subplot(133)
plt.imshow(actual_u_der)
plt.colorbar()
plt.show()
# Out:
# 0.00011614865021736388
# 0.00010777228317956518
# 0.7993511128400528
# 0.0012014837942123475

# %%
print(SE(v_der, actual_v_der))
print(RMSE(v_der, actual_v_der))
print(RMSE_relative(v_der, actual_v_der))
print(max_diff(v_der, actual_v_der))

plt.figure(figsize=(12, 5))
plt.subplot(131)
plt.imshow(v_der)
plt.colorbar()
plt.subplot(132)
plt.imshow(v_der-actual_v_der)
plt.colorbar()
plt.subplot(133)
plt.imshow(actual_v_der)
plt.colorbar()
plt.show()
# Out:
# 0.014049563978509295
# 0.0011853085665137705
# 0.3037958584843373
# 0.006301543626022976
