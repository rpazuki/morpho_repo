# %%
# %config Completer.use_jedi = False
import sys
import warnings
warnings.filterwarnings('ignore')

import os
os.environ["CUDA_VISIBLE_DEVICES"]="2"

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

GPU_NUM = 0
MEMORY = 4*1024

gpus = tf.config.list_physical_devices('GPU')
try:
    tf.config.set_logical_device_configuration(gpus[GPU_NUM],
                                              [tf.config.LogicalDeviceConfiguration(memory_limit=MEMORY)])
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
except RuntimeError as e:        
    # Memory growth must be set before GPUs have been initialized
    print(e)    
    

    
sys.path.append("/end/home/rh2310/morpho_repo/turing_codebase")
from turing.utils import *
from turing.tf_utils import *
import turing.pinns as tu
from turing.loss_functions import *
# Out:
# 2023-01-19 16:36:48.877858: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-19 16:36:49.100521: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-01-19 16:36:50.902557: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /end/home/rh2310/.conda/envs/tensorflow.2.10/lib/:/end/home/rh2310/.conda/envs/tensorflow.2.10/lib/:/end/home/rh2310/.conda/envs/tensorflow.2.10/lib/:/end/home/rh2310/lib:/end/soft/Linux_2.6_64/lib::/end/home/rh2310/.conda/envs/tensorflow.2.10/lib/
# 2023-01-19 16:36:50.903106: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /end/home/rh2310/.conda/envs/tensorflow.2.10/lib/:/end/home/rh2310/.conda/envs/tensorflow.2.10/lib/:/end/home/rh2310/.conda/envs/tensorflow.2.10/lib/:/end/home/rh2310/lib:/end/soft/Linux_2.6_64/lib::/end/home/rh2310/.conda/envs/tensorflow.2.10/lib/
# 2023-01-19 16:36:50.903124: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2023-01-19 16:36:55.100140: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-19 16:36:56.262467: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4096 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:e3:00.0, compute capability: 8.6
# 1 Physical GPUs, 1 Logical GPUs

# %%
@tf.function
def derivatives(pinn, x):
    y = pinn.net(x)
    p1, p2 = pinn.gradients(x, y)
    return y, p1, p2

# %% [markdown]
# # Two-dimensional data

# %%
def Gaussian_2d(x, y, locx=0.0, locy=0.0, scalex=1.0, scaley=1.0):
    return np.exp(-(x-locx)**2/(2*scalex**2)-(y-locy)**2/(2*scaley**2))

def Gaussian_2d_df_dx(x, y, locx=0.0, locy=0.0, scalex=1.0, scaley=1.0):
    return (-(x-locx)/(scalex**2))*Gaussian_2d(x, y, locx, locy, scalex, scaley)

def Gaussian_2d_df_dy(x, y, locx=0.0, locy=0.0, scalex=1.0, scaley=1.0):
    return (-(y-locy)/(scaley**2))*Gaussian_2d(x, y, locx, locy, scalex, scaley)

def Gaussian_2d_d2f_dx2(x, y, locx=0.0, locy=0.0, scalex=1.0, scaley=1.0):
    return ((-1.0/scalex**2)*Gaussian_2d(x, y, locx, locy, scalex, scaley)
            -((x-locx)/(scalex**2))*Gaussian_2d_df_dx(x, y, locx, locy, scalex, scaley))

def Gaussian_2d_d2f_dy2(x, y, locx=0.0, locy=0.0, scalex=1.0, scaley=1.0):
    return ((-1.0/scaley**2)*Gaussian_2d(x, y, locx, locy, scalex, scaley) 
            -((y-locy)/(scaley**2))*Gaussian_2d_df_dy(x, y, locx, locy, scalex, scaley))


data_2d_x = np.linspace(-2, 2, 128)[:,np.newaxis].astype(np.float32)
data_2d_y = np.linspace(-2, 2, 128)[:,np.newaxis].astype(np.float32)
X,Y = np.meshgrid(data_2d_x, data_2d_y,indexing='ij')

data_input = np.concatenate([X.flatten()[:,np.newaxis],
                             Y.flatten()[:,np.newaxis]], 
                              axis=1)

# %% [markdown]
# # Equal dispersion

# %%
data_2d_z_gaussian_equal = Gaussian_2d(X, Y, 0.0, 0.5, .5, .5)

data_2d_df_dx = Gaussian_2d_df_dx(X, Y, 0.0, 0.5, .5, .5)
data_2d_df_dy = Gaussian_2d_df_dy(X, Y, 0.0, 0.5, .5, .5)

data_2d_d2f_dx2 = Gaussian_2d_d2f_dx2(X, Y, 0.0, 0.5, .5, .5)
data_2d_d2f_dy2 = Gaussian_2d_d2f_dy2(X, Y, 0.0, 0.5, .5, .5)

ds_gaussian_2d_equal = TINN_Dataset(tf.float32, 
                              np.concatenate([X.flatten()[:,np.newaxis],
                                              Y.flatten()[:,np.newaxis],
                                              data_2d_z_gaussian_equal.flatten()[:,np.newaxis]], 
                              axis=1))

# %%
def plot(X, Y, Z, title=""):
    plt.title(title)
    plt.contourf(X, Y, Z)
    plt.colorbar()

# %%
_ = plt.figure(figsize=(12,6.5))
plt.subplot(231)
plot(X, Y, data_2d_z_gaussian_equal, "f(x,y)")
plt.subplot(232)
plot(X, Y, data_2d_df_dx, "df/dx")
plt.subplot(233)
plot(X, Y, data_2d_df_dy, "df/dy")
plt.subplot(234)
plot(X, Y, data_2d_d2f_dx2, "d2f/dx2")
plt.subplot(235)
plot(X, Y, data_2d_d2f_dy2, "d2f/dy2")
plt.tight_layout()
plt.show()

# %%
layers1 = [2, 128, 128, 1]
pinn1 = tu.NN(layers1, 
             lb= np.amin(np.concatenate([data_2d_x, data_2d_y], axis=1), 0),
             ub= np.amax(np.concatenate([data_2d_x, data_2d_y], axis=1), 0),
             dtype=tf.float32)

# %% [markdown]
# # Initial output of an untrained network

# %%
def RMSE(pred, actual, sqrt=True):
    if sqrt:
        return np.sqrt(np.mean((pred-actual)**2))
    else:
        return np.mean((pred-actual)**2)

# %%
def to_2d(x):
    return x.reshape((data_2d_x.shape[0], data_2d_x.shape[0]))

# %%
y, y_der_1, y_der_2 = derivatives(pinn1, data_input)


_ = plt.figure(figsize=(12,6))
plt.subplot(231)
plot(X, Y, to_2d(y.numpy()), 
     f"f(x,y), rmse={RMSE(data_2d_z_gaussian_equal, to_2d(y.numpy())):.10f}\n"
     f"mse={RMSE(data_2d_z_gaussian_equal, to_2d(y.numpy()), False):.10f}")
plt.subplot(232)
plot(X, Y, to_2d(y_der_1[0].numpy()[:,0]), 
     f"df/dx, rmse={RMSE(data_2d_df_dx, to_2d(y_der_1[0].numpy()[:,0])):.10f}\n"
     f"mse={RMSE(data_2d_df_dx, to_2d(y_der_1[0].numpy()[:,0]), False):.10f}")
plt.subplot(233)
plot(X, Y, to_2d(y_der_1[0].numpy()[:,1]), 
     f"df/dy, rmse={RMSE(data_2d_df_dy, to_2d(y_der_1[0].numpy()[:,1])):.10f}\n"
     f"mse={RMSE(data_2d_df_dy, to_2d(y_der_1[0].numpy()[:,1]),False):.10f}")
plt.subplot(234)
plot(X, Y, to_2d(y_der_2[0].numpy()[:,0]), 
     f"d2f/dx2, rmse={RMSE(data_2d_d2f_dx2, to_2d(y_der_2[0].numpy()[:,0])):.10f}\n"
    f"mse={RMSE(data_2d_d2f_dx2, to_2d(y_der_2[0].numpy()[:,0]),False):.10f}")
plt.subplot(235)
plot(X, Y, to_2d(y_der_2[0].numpy()[:,1]), 
     f"d2f/dy2, rmse={RMSE(data_2d_d2f_dy2, to_2d(y_der_2[0].numpy()[:,1])):.10f}\n"
    f"mse={RMSE(data_2d_d2f_dy2, to_2d(y_der_2[0].numpy()[:,1]),False):.10f}")
plt.tight_layout()
plt.show()
# Out:
# 2023-01-19 16:38:14.394183: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:630] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.

# %% [markdown]
# # Train the model

# %%
loss1 = Observation_Loss(layers1, residual_ret_names=("f(x,y)",), print_precision = ".10f")
model1 = tu.TINN(pinn1, [loss1], L2(),
                 optimizer=keras.optimizers.Adam(learning_rate=1e-4), print_precision = ".10f")
results1 = model1.train(200000+1, 4096, ds_gaussian_2d_equal, 
                        print_interval=5000, stop_threshold=5e-5,
                       regularise=False, sample_regularisations=False)
# Out:
# Start of epoch 0
# 2023-01-19 16:38:57.087067: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x7f5e1000f760 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-01-19 16:38:57.087121: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): NVIDIA RTX A6000, Compute Capability 8.6
# 2023-01-19 16:38:57.097007: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-01-19 16:38:57.423971: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# total loss: 0.2173731594, total regularised loss: 0.2173731625
# Observation_Loss ->
# (1)  f(x,y): 0.0543432898
# Time taken: 6.80s
#
# Start of epoch 5000
# total loss: 0.0016453590, total regularised loss: 0.0016453590
# Observation_Loss ->
# (1)  f(x,y): 0.0004113397
# Time taken: 219.89s
#
# Start of epoch 10000
# total loss: 0.0001985824, total regularised loss: 0.0001985824
# Observation_Loss ->
# (1)  f(x,y): 0.0000496456
# Time taken: 228.02s
#
# Start of epoch 15000
# total loss: 0.0001287481, total regularised loss: 0.0001287481
# Observation_Loss ->
# (1)  f(x,y): 0.0000321870
# Time taken: 245.89s
#
# Start of epoch 20000
# total loss: 0.0000981063, total regularised loss: 0.0000981063
# Observation_Loss ->
# (1)  f(x,y): 0.0000245266
# Time taken: 212.24s
#
# Start of epoch 25000
# total loss: 0.0001604034, total regularised loss: 0.0001604034
# Observation_Loss ->
# (1)  f(x,y): 0.0000401009
# Time taken: 206.47s
#
# Start of epoch 30000
# total loss: 0.0001222975, total regularised loss: 0.0001222975
# Observation_Loss ->
# (1)  f(x,y): 0.0000305744
# Time taken: 211.43s
# ############################################
# #               Early stop                 #
# ############################################

# %%
results2 = model1.train(100000+1, 4096, ds_gaussian_2d_equal, 
                        print_interval=5000, stop_threshold=5e-7,
                       regularise=False, sample_regularisations=False)
# Out:
# Start of epoch 0
# total loss: 0.0001001630, total regularised loss: 0.0001001630
# Observation_Loss ->
# (1)  f(x,y): 0.0000250407
# Time taken: 3.88s
#
# Start of epoch 5000
# total loss: 0.0002445184, total regularised loss: 0.0002445185
# Observation_Loss ->
# (1)  f(x,y): 0.0000611296
# Time taken: 211.21s
#
# Start of epoch 10000
# total loss: 0.0000614773, total regularised loss: 0.0000614773
# Observation_Loss ->
# (1)  f(x,y): 0.0000153693
# Time taken: 269.72s
#
# Start of epoch 15000
# total loss: 0.0000240069, total regularised loss: 0.0000240069
# Observation_Loss ->
# (1)  f(x,y): 0.0000060017
# Time taken: 233.22s
#
# Start of epoch 20000
# total loss: 0.0000201539, total regularised loss: 0.0000201539
# Observation_Loss ->
# (1)  f(x,y): 0.0000050385
# Time taken: 210.69s
#
# Start of epoch 25000
# total loss: 0.0000183800, total regularised loss: 0.0000183800
# Observation_Loss ->
# (1)  f(x,y): 0.0000045950
# Time taken: 211.30s
#
# Start of epoch 30000
# total loss: 0.0000169901, total regularised loss: 0.0000169901
# Observation_Loss ->
# (1)  f(x,y): 0.0000042475
# Time taken: 211.60s
#
# Start of epoch 35000
# total loss: 0.0000154006, total regularised loss: 0.0000154006
# Observation_Loss ->
# (1)  f(x,y): 0.0000038501
# Time taken: 212.28s
#
# Start of epoch 40000
# total loss: 0.0000607038, total regularised loss: 0.0000607038
# Observation_Loss ->
# (1)  f(x,y): 0.0000151759
# Time taken: 212.11s

# %%
model1.save(".", "Gaussian_2D_symmetric_f_x_y")

# %% [markdown]
# # After training

# %%
y, y_der_1, y_der_2 = derivatives(pinn1, data_input)


_ = plt.figure(figsize=(12,6))
plt.subplot(231)
plot(X, Y, to_2d(y.numpy()), 
     f"f(x,y), rmse={RMSE(data_2d_z_gaussian_equal, to_2d(y.numpy())):.10f}\n"
     f"mse={RMSE(data_2d_z_gaussian_equal, to_2d(y.numpy()), False):.10f}")
plt.subplot(232)
plot(X, Y, to_2d(y_der_1[0].numpy()[:,0]), 
     f"df/dx, rmse={RMSE(data_2d_df_dx, to_2d(y_der_1[0].numpy()[:,0])):.10f}\n"
     f"mse={RMSE(data_2d_df_dx, to_2d(y_der_1[0].numpy()[:,0]), False):.10f}")
plt.subplot(233)
plot(X, Y, to_2d(y_der_1[0].numpy()[:,1]), 
     f"df/dy, rmse={RMSE(data_2d_df_dy, to_2d(y_der_1[0].numpy()[:,1])):.10f}\n"
     f"mse={RMSE(data_2d_df_dy, to_2d(y_der_1[0].numpy()[:,1]),False):.10f}")
plt.subplot(234)
plot(X, Y, to_2d(y_der_2[0].numpy()[:,0]), 
     f"d2f/dx2, rmse={RMSE(data_2d_d2f_dx2, to_2d(y_der_2[0].numpy()[:,0])):.10f}\n"
    f"mse={RMSE(data_2d_d2f_dx2, to_2d(y_der_2[0].numpy()[:,0]),False):.10f}")
plt.subplot(235)
plot(X, Y, to_2d(y_der_2[0].numpy()[:,1]), 
     f"d2f/dy2, rmse={RMSE(data_2d_d2f_dy2, to_2d(y_der_2[0].numpy()[:,1])):.10f}\n"
    f"mse={RMSE(data_2d_d2f_dy2, to_2d(y_der_2[0].numpy()[:,1]),False):.10f}")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Asymmetrical: elongated in the X direction

# %%
data_2d_z_gaussian_elongated_x = Gaussian_2d(X, Y, 0.0, 0.5, 1., .5)

data_2d_df_dx_elongated_x = Gaussian_2d_df_dx(X, Y, 0.0, 0.5, 1., .5)
data_2d_df_dy_elongated_x = Gaussian_2d_df_dy(X, Y, 0.0, 0.5, 1., .5)

data_2d_d2f_dx2_elongated_x = Gaussian_2d_d2f_dx2(X, Y, 0.0, 0.5, 1., .5)
data_2d_d2f_dy2_elongated_x = Gaussian_2d_d2f_dy2(X, Y, 0.0, 0.5, 1., .5)

ds_gaussian_2d_elongated_x = TINN_Dataset(tf.float32, 
                              np.concatenate([X.flatten()[:,np.newaxis],
                                              Y.flatten()[:,np.newaxis],
                                              data_2d_z_gaussian_elongated_x.flatten()[:,np.newaxis]], 
                              axis=1))

# %%
_ = plt.figure(figsize=(12,6.5))
plt.subplot(231)
plot(X, Y, data_2d_z_gaussian_elongated_x, "f(x,y)")
plt.subplot(232)
plot(X, Y, data_2d_df_dx_elongated_x, "df/dx")
plt.subplot(233)
plot(X, Y, data_2d_df_dy_elongated_x, "df/dy")
plt.subplot(234)
plot(X, Y, data_2d_d2f_dx2_elongated_x, "d2f/dx2")
plt.subplot(235)
plot(X, Y, data_2d_d2f_dy2_elongated_x, "d2f/dy2")
plt.tight_layout()
plt.show()

# %%
layers2 = [2, 128, 128, 1]
pinn2 = tu.NN(layers2, 
             lb= np.amin(np.concatenate([data_2d_x, data_2d_y], axis=1), 0),
             ub= np.amax(np.concatenate([data_2d_x, data_2d_y], axis=1), 0),
             dtype=tf.float32)

# %%
loss2 = Observation_Loss(layers2, residual_ret_names=("f(x,y)",), print_precision = ".10f")
model2 = tu.TINN(pinn2, [loss2], L2(),
                 optimizer=keras.optimizers.Adam(learning_rate=1e-4), print_precision = ".10f")
results2 = model2.train(200000+1, 4096, ds_gaussian_2d_elongated_x, 
                        print_interval=5000, stop_threshold=5e-7,
                       regularise=False, sample_regularisations=False)
# Out:
# Start of epoch 0
# total loss: 0.4349001665, total regularised loss: 0.4349001646
# Observation_Loss ->
# (1)  f(x,y): 0.1087250416
# Time taken: 1.73s
#
# Start of epoch 5000
# total loss: 0.0004965240, total regularised loss: 0.0004965240
# Observation_Loss ->
# (1)  f(x,y): 0.0001241310
# Time taken: 125.10s
#
# Start of epoch 10000
# total loss: 0.0000727471, total regularised loss: 0.0000727471
# Observation_Loss ->
# (1)  f(x,y): 0.0000181868
# Time taken: 126.86s
#
# Start of epoch 15000
# total loss: 0.0000409337, total regularised loss: 0.0000409337
# Observation_Loss ->
# (1)  f(x,y): 0.0000102334
# Time taken: 126.26s
#
# Start of epoch 20000
# total loss: 0.0000273742, total regularised loss: 0.0000273742
# Observation_Loss ->
# (1)  f(x,y): 0.0000068435
# Time taken: 128.54s
#
# Start of epoch 25000
# total loss: 0.0000207550, total regularised loss: 0.0000207550
# Observation_Loss ->
# (1)  f(x,y): 0.0000051888
# Time taken: 124.88s
#
# Start of epoch 30000
# total loss: 0.0000170591, total regularised loss: 0.0000170591
# Observation_Loss ->
# (1)  f(x,y): 0.0000042648
# Time taken: 123.07s
#
# Start of epoch 35000
# total loss: 0.0000157658, total regularised loss: 0.0000157658
# Observation_Loss ->
# (1)  f(x,y): 0.0000039414
# Time taken: 123.47s
#
# Start of epoch 40000
# total loss: 0.0000455626, total regularised loss: 0.0000455626
# Observation_Loss ->
# (1)  f(x,y): 0.0000113907
# Time taken: 123.53s
#
# Start of epoch 45000
# total loss: 0.0000107354, total regularised loss: 0.0000107354
# Observation_Loss ->
# (1)  f(x,y): 0.0000026838
# Time taken: 126.76s
#
# Start of epoch 50000
# total loss: 0.0000101235, total regularised loss: 0.0000101235
# Observation_Loss ->
# (1)  f(x,y): 0.0000025309
# Time taken: 122.54s
#
# Start of epoch 55000
# total loss: 0.0000084777, total regularised loss: 0.0000084777
# Observation_Loss ->
# (1)  f(x,y): 0.0000021194
# Time taken: 126.14s
#
# Start of epoch 60000
# total loss: 0.0000255893, total regularised loss: 0.0000255893
# Observation_Loss ->
# (1)  f(x,y): 0.0000063973
# Time taken: 128.59s
#
# Start of epoch 65000
# total loss: 0.0000141849, total regularised loss: 0.0000141849
# Observation_Loss ->
# (1)  f(x,y): 0.0000035462
# Time taken: 127.69s
#
# Start of epoch 70000
# total loss: 0.0004842200, total regularised loss: 0.0004842200
# Observation_Loss ->
# (1)  f(x,y): 0.0001210550
# Time taken: 123.89s
#
# Start of epoch 75000
# total loss: 0.0000058882, total regularised loss: 0.0000058882
# Observation_Loss ->
# (1)  f(x,y): 0.0000014721
# Time taken: 124.90s
#
# Start of epoch 80000
# total loss: 0.0000054475, total regularised loss: 0.0000054475
# Observation_Loss ->
# (1)  f(x,y): 0.0000013619
# Time taken: 128.32s
#
# Start of epoch 85000
# total loss: 0.0000050533, total regularised loss: 0.0000050533
# Observation_Loss ->
# (1)  f(x,y): 0.0000012633
# Time taken: 121.77s
#
# Start of epoch 90000
# total loss: 0.0000167640, total regularised loss: 0.0000167640
# Observation_Loss ->
# (1)  f(x,y): 0.0000041910
# Time taken: 130.44s
#
# Start of epoch 95000
# total loss: 0.0000044027, total regularised loss: 0.0000044027
# Observation_Loss ->
# (1)  f(x,y): 0.0000011007
# Time taken: 128.46s
#
# Start of epoch 100000
# total loss: 0.0000048985, total regularised loss: 0.0000048985
# Observation_Loss ->
# (1)  f(x,y): 0.0000012246
# Time taken: 128.27s
#
# Start of epoch 105000
# total loss: 0.0000240685, total regularised loss: 0.0000240685
# Observation_Loss ->
# (1)  f(x,y): 0.0000060171
# Time taken: 125.47s
#
# Start of epoch 110000
# total loss: 0.0000036345, total regularised loss: 0.0000036345
# Observation_Loss ->
# (1)  f(x,y): 0.0000009086
# Time taken: 124.48s
#
# Start of epoch 115000
# total loss: 0.0000034128, total regularised loss: 0.0000034128
# Observation_Loss ->
# (1)  f(x,y): 0.0000008532
# Time taken: 121.78s
#
# Start of epoch 120000
# total loss: 0.0000032119, total regularised loss: 0.0000032119
# Observation_Loss ->
# (1)  f(x,y): 0.0000008030
# Time taken: 128.21s
#
# Start of epoch 125000
# total loss: 0.0000030273, total regularised loss: 0.0000030273
# Observation_Loss ->
# (1)  f(x,y): 0.0000007568
# Time taken: 126.90s
#
# Start of epoch 130000
# total loss: 0.0000217563, total regularised loss: 0.0000217563
# Observation_Loss ->
# (1)  f(x,y): 0.0000054391
# Time taken: 128.07s
#
# Start of epoch 135000
# total loss: 0.0000026856, total regularised loss: 0.0000026856
# Observation_Loss ->
# (1)  f(x,y): 0.0000006714
# Time taken: 125.64s
#
# Start of epoch 140000
# total loss: 0.0000147321, total regularised loss: 0.0000147321
# Observation_Loss ->
# (1)  f(x,y): 0.0000036830
# Time taken: 123.01s
#
# Start of epoch 145000
# total loss: 0.0002030827, total regularised loss: 0.0002030827
# Observation_Loss ->
# (1)  f(x,y): 0.0000507707
# Time taken: 126.84s
#
# Start of epoch 150000
# total loss: 0.0000022380, total regularised loss: 0.0000022380
# Observation_Loss ->
# (1)  f(x,y): 0.0000005595
# Time taken: 123.27s
#
# Start of epoch 155000
# total loss: 0.0000120739, total regularised loss: 0.0000120739
# Observation_Loss ->
# (1)  f(x,y): 0.0000030185
# Time taken: 129.81s
#
# Start of epoch 160000
# total loss: 0.0000019660, total regularised loss: 0.0000019660
# Observation_Loss ->
# (1)  f(x,y): 0.0000004915
# Time taken: 127.10s
#
# Start of epoch 165000
# total loss: 0.0000022208, total regularised loss: 0.0000022208
# Observation_Loss ->
# (1)  f(x,y): 0.0000005552
# Time taken: 123.93s
#
# Start of epoch 170000
# total loss: 0.0000021346, total regularised loss: 0.0000021346
# Observation_Loss ->
# (1)  f(x,y): 0.0000005337
# Time taken: 124.88s
#
# Start of epoch 175000
# total loss: 0.0000016459, total regularised loss: 0.0000016459
# Observation_Loss ->
# (1)  f(x,y): 0.0000004115
# Time taken: 127.28s
#
# Start of epoch 180000
# total loss: 0.0000015297, total regularised loss: 0.0000015297
# Observation_Loss ->
# (1)  f(x,y): 0.0000003824
# Time taken: 127.49s
#
# Start of epoch 185000
# total loss: 0.0000014513, total regularised loss: 0.0000014513
# Observation_Loss ->
# (1)  f(x,y): 0.0000003628
# Time taken: 126.51s
#
# Start of epoch 190000
# total loss: 0.0000027520, total regularised loss: 0.0000027520
# Observation_Loss ->
# (1)  f(x,y): 0.0000006880
# Time taken: 126.09s
#
# Start of epoch 195000
# total loss: 0.0000013272, total regularised loss: 0.0000013272
# Observation_Loss ->
# (1)  f(x,y): 0.0000003318
# Time taken: 125.75s
#
# Start of epoch 200000
# total loss: 0.0000677211, total regularised loss: 0.0000677211
# Observation_Loss ->
# (1)  f(x,y): 0.0000169303
# Time taken: 126.20s

# %%
model1.save(".", "Gaussian_2D_elongetd_x_f_x_y")

# %%
y, y_der_1, y_der_2 = derivatives(pinn2, data_input)


_ = plt.figure(figsize=(12,6))
plt.subplot(231)
plot(X, Y, to_2d(y.numpy()), 
     f"f(x,y), rmse={RMSE(data_2d_z_gaussian_elongated_x, to_2d(y.numpy())):.10f}\n"
     f"mse={RMSE(data_2d_z_gaussian_elongated_x, to_2d(y.numpy()), False):.10f}")
plt.subplot(232)
plot(X, Y, to_2d(y_der_1[0].numpy()[:,0]), 
     f"df/dx, rmse={RMSE(data_2d_df_dx_elongated_x, to_2d(y_der_1[0].numpy()[:,0])):.10f}\n"
     f"mse={RMSE(data_2d_df_dx_elongated_x, to_2d(y_der_1[0].numpy()[:,0]), False):.10f}")
plt.subplot(233)
plot(X, Y, to_2d(y_der_1[0].numpy()[:,1]), 
     f"df/dy, rmse={RMSE(data_2d_df_dy_elongated_x, to_2d(y_der_1[0].numpy()[:,1])):.10f}\n"
     f"mse={RMSE(data_2d_df_dy_elongated_x, to_2d(y_der_1[0].numpy()[:,1]),False):.10f}")
plt.subplot(234)
plot(X, Y, to_2d(y_der_2[0].numpy()[:,0]), 
     f"d2f/dx2, rmse={RMSE(data_2d_d2f_dx2_elongated_x, to_2d(y_der_2[0].numpy()[:,0])):.10f}\n"
    f"mse={RMSE(data_2d_d2f_dx2_elongated_x, to_2d(y_der_2[0].numpy()[:,0]),False):.10f}")
plt.subplot(235)
plot(X, Y, to_2d(y_der_2[0].numpy()[:,1]), 
     f"d2f/dy2, rmse={RMSE(data_2d_d2f_dy2_elongated_x, to_2d(y_der_2[0].numpy()[:,1])):.10f}\n"
    f"mse={RMSE(data_2d_d2f_dy2_elongated_x, to_2d(y_der_2[0].numpy()[:,1]),False):.10f}")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Asymmetrical: elongated in the Y direction

# %%
data_2d_z_gaussian_elongated_y = Gaussian_2d(X, Y, 0.0, 0.0, .5, 1.0)

data_2d_df_dx_elongated_y = Gaussian_2d_df_dx(X, Y, 0.0, 0.0, .5, 1.0)
data_2d_df_dy_elongated_y = Gaussian_2d_df_dy(X, Y, 0.0, 0.0, .5, 1.0)

data_2d_d2f_dx2_elongated_y = Gaussian_2d_d2f_dx2(X, Y, 0.0, 0.0, .5, 1.0)
data_2d_d2f_dy2_elongated_y = Gaussian_2d_d2f_dy2(X, Y, 0.0, 0.0, .5, 1.0)

ds_gaussian_2d_elongated_y = TINN_Dataset(tf.float32, 
                              np.concatenate([X.flatten()[:,np.newaxis],
                                              Y.flatten()[:,np.newaxis],
                                              data_2d_z_gaussian_elongated_y.flatten()[:,np.newaxis]], 
                              axis=1))

# %%
_ = plt.figure(figsize=(12,6.5))
plt.subplot(231)
plot(X, Y, data_2d_z_gaussian_elongated_y, "f(x,y)")
plt.subplot(232)
plot(X, Y, data_2d_df_dx_elongated_y, "df/dx")
plt.subplot(233)
plot(X, Y, data_2d_df_dy_elongated_y, "df/dy")
plt.subplot(234)
plot(X, Y, data_2d_d2f_dx2_elongated_y, "d2f/dx2")
plt.subplot(235)
plot(X, Y, data_2d_d2f_dy2_elongated_y, "d2f/dy2")
plt.tight_layout()
plt.show()

# %%
layers3 = [2, 128, 128, 1]
pinn3 = tu.NN(layers3, 
             lb= np.amin(np.concatenate([data_2d_x, data_2d_y], axis=1), 0),
             ub= np.amax(np.concatenate([data_2d_x, data_2d_y], axis=1), 0),
             dtype=tf.float32)

# %%
loss3 = Observation_Loss(layers3, residual_ret_names=("f(x,y)",), print_precision = ".10f")
model3 = tu.TINN(pinn3, [loss3], L2(),
                 optimizer=keras.optimizers.Adam(learning_rate=1e-4), print_precision = ".10f")
results3 = model3.train(200000+1, 4096, ds_gaussian_2d_elongated_y, 
                        print_interval=5000, stop_threshold=5e-7,
                       regularise=False, sample_regularisations=False)
# Out:
# Start of epoch 0
# total loss: 0.4514427595, total regularised loss: 0.4514427781
# Observation_Loss ->
# (1)  f(x,y): 0.1128606899
# Time taken: 1.94s
#
# Start of epoch 5000
# total loss: 0.0031619915, total regularised loss: 0.0031619915
# Observation_Loss ->
# (1)  f(x,y): 0.0007904979
# Time taken: 121.93s
#
# Start of epoch 10000
# total loss: 0.0015385438, total regularised loss: 0.0015385437
# Observation_Loss ->
# (1)  f(x,y): 0.0003846360
# Time taken: 122.90s
#
# Start of epoch 15000
# total loss: 0.0000833667, total regularised loss: 0.0000833667
# Observation_Loss ->
# (1)  f(x,y): 0.0000208417
# Time taken: 122.87s
#
# Start of epoch 20000
# total loss: 0.0000333717, total regularised loss: 0.0000333717
# Observation_Loss ->
# (1)  f(x,y): 0.0000083429
# Time taken: 122.94s
#
# Start of epoch 25000
# total loss: 0.0000752460, total regularised loss: 0.0000752460
# Observation_Loss ->
# (1)  f(x,y): 0.0000188115
# Time taken: 123.17s
#
# Start of epoch 30000
# total loss: 0.0000298425, total regularised loss: 0.0000298425
# Observation_Loss ->
# (1)  f(x,y): 0.0000074606
# Time taken: 124.28s
#
# Start of epoch 35000
# total loss: 0.0000244795, total regularised loss: 0.0000244795
# Observation_Loss ->
# (1)  f(x,y): 0.0000061199
# Time taken: 122.55s
#
# Start of epoch 40000
# total loss: 0.0000132966, total regularised loss: 0.0000132966
# Observation_Loss ->
# (1)  f(x,y): 0.0000033241
# Time taken: 128.98s
#
# Start of epoch 45000
# total loss: 0.0000116963, total regularised loss: 0.0000116963
# Observation_Loss ->
# (1)  f(x,y): 0.0000029241
# Time taken: 131.47s
#
# Start of epoch 50000
# total loss: 0.0000103216, total regularised loss: 0.0000103216
# Observation_Loss ->
# (1)  f(x,y): 0.0000025804
# Time taken: 132.57s
#
# Start of epoch 55000
# total loss: 0.0000091148, total regularised loss: 0.0000091148
# Observation_Loss ->
# (1)  f(x,y): 0.0000022787
# Time taken: 135.31s
#
# Start of epoch 60000
# total loss: 0.0000080794, total regularised loss: 0.0000080794
# Observation_Loss ->
# (1)  f(x,y): 0.0000020199
# Time taken: 129.53s
#
# Start of epoch 65000
# total loss: 0.0000576942, total regularised loss: 0.0000576942
# Observation_Loss ->
# (1)  f(x,y): 0.0000144236
# Time taken: 129.81s
#
# Start of epoch 70000
# total loss: 0.0000063545, total regularised loss: 0.0000063545
# Observation_Loss ->
# (1)  f(x,y): 0.0000015886
# Time taken: 128.45s
#
# Start of epoch 75000
# total loss: 0.0000056890, total regularised loss: 0.0000056890
# Observation_Loss ->
# (1)  f(x,y): 0.0000014223
# Time taken: 131.30s
#
# Start of epoch 80000
# total loss: 0.0000051806, total regularised loss: 0.0000051806
# Observation_Loss ->
# (1)  f(x,y): 0.0000012951
# Time taken: 128.97s
#
# Start of epoch 85000
# total loss: 0.0000048116, total regularised loss: 0.0000048116
# Observation_Loss ->
# (1)  f(x,y): 0.0000012029
# Time taken: 126.66s
#
# Start of epoch 90000
# total loss: 0.0000061825, total regularised loss: 0.0000061825
# Observation_Loss ->
# (1)  f(x,y): 0.0000015456
# Time taken: 127.04s
#
# Start of epoch 95000
# total loss: 0.0000042275, total regularised loss: 0.0000042275
# Observation_Loss ->
# (1)  f(x,y): 0.0000010569
# Time taken: 122.30s
#
# Start of epoch 100000
# total loss: 0.0000214578, total regularised loss: 0.0000214578
# Observation_Loss ->
# (1)  f(x,y): 0.0000053645
# Time taken: 120.59s
#
# Start of epoch 105000
# total loss: 0.0000240072, total regularised loss: 0.0000240072
# Observation_Loss ->
# (1)  f(x,y): 0.0000060018
# Time taken: 119.74s
#
# Start of epoch 110000
# total loss: 0.0000050548, total regularised loss: 0.0000050548
# Observation_Loss ->
# (1)  f(x,y): 0.0000012637
# Time taken: 120.57s
#
# Start of epoch 115000
# total loss: 0.0000134191, total regularised loss: 0.0000134191
# Observation_Loss ->
# (1)  f(x,y): 0.0000033548
# Time taken: 119.44s
#
# Start of epoch 120000
# total loss: 0.0000344012, total regularised loss: 0.0000344012
# Observation_Loss ->
# (1)  f(x,y): 0.0000086003
# Time taken: 121.50s
#
# Start of epoch 125000
# total loss: 0.0000054275, total regularised loss: 0.0000054275
# Observation_Loss ->
# (1)  f(x,y): 0.0000013569
# Time taken: 123.20s
#
# Start of epoch 130000
# total loss: 0.0000125019, total regularised loss: 0.0000125019
# Observation_Loss ->
# (1)  f(x,y): 0.0000031255
# Time taken: 119.50s
#
# Start of epoch 135000
# total loss: 0.0000035017, total regularised loss: 0.0000035017
# Observation_Loss ->
# (1)  f(x,y): 0.0000008754
# Time taken: 120.04s
#
# Start of epoch 140000
# total loss: 0.0000051300, total regularised loss: 0.0000051300
# Observation_Loss ->
# (1)  f(x,y): 0.0000012825
# Time taken: 122.03s
#
# Start of epoch 145000
# total loss: 0.0000151859, total regularised loss: 0.0000151859
# Observation_Loss ->
# (1)  f(x,y): 0.0000037965
# Time taken: 121.60s
#
# Start of epoch 150000
# total loss: 0.0000082455, total regularised loss: 0.0000082455
# Observation_Loss ->
# (1)  f(x,y): 0.0000020614
# Time taken: 121.87s
#
# Start of epoch 155000
# total loss: 0.0000023874, total regularised loss: 0.0000023874
# Observation_Loss ->
# (1)  f(x,y): 0.0000005969
# Time taken: 123.63s
#
# Start of epoch 160000
# total loss: 0.0000198599, total regularised loss: 0.0000198599
# Observation_Loss ->
# (1)  f(x,y): 0.0000049650
# Time taken: 125.71s
#
# Start of epoch 165000
# total loss: 0.0000043792, total regularised loss: 0.0000043792
# Observation_Loss ->
# (1)  f(x,y): 0.0000010948
# Time taken: 129.09s
#
# Start of epoch 170000
# total loss: 0.0000021862, total regularised loss: 0.0000021862
# Observation_Loss ->
# (1)  f(x,y): 0.0000005465
# Time taken: 126.35s
#
# Start of epoch 175000
# total loss: 0.0000017534, total regularised loss: 0.0000017534
# Observation_Loss ->
# (1)  f(x,y): 0.0000004384
# Time taken: 127.52s
#
# Start of epoch 180000
# total loss: 0.0000037421, total regularised loss: 0.0000037421
# Observation_Loss ->
# (1)  f(x,y): 0.0000009355
# Time taken: 124.94s
#
# Start of epoch 185000
# total loss: 0.0000016106, total regularised loss: 0.0000016106
# Observation_Loss ->
# (1)  f(x,y): 0.0000004026
# Time taken: 123.69s
#
# Start of epoch 190000
# total loss: 0.0000016992, total regularised loss: 0.0000016992
# Observation_Loss ->
# (1)  f(x,y): 0.0000004248
# Time taken: 129.50s
#
# Start of epoch 195000
# total loss: 0.0000370005, total regularised loss: 0.0000370005
# Observation_Loss ->
# (1)  f(x,y): 0.0000092501
# Time taken: 127.43s
#
# Start of epoch 200000
# total loss: 0.0000014067, total regularised loss: 0.0000014067
# Observation_Loss ->
# (1)  f(x,y): 0.0000003517
# Time taken: 126.44s

# %%
model1.save(".", "Gaussian_2D_elongetd_y_f_x_y")

# %%
y, y_der_1, y_der_2 = derivatives(pinn3, data_input)


_ = plt.figure(figsize=(12,6))
plt.subplot(231)
plot(X, Y, to_2d(y.numpy()), 
     f"f(x,y), rmse={RMSE(data_2d_z_gaussian_elongated_y, to_2d(y.numpy())):.10f}\n"
     f"mse={RMSE(data_2d_z_gaussian_elongated_y, to_2d(y.numpy()), False):.10f}")
plt.subplot(232)
plot(X, Y, to_2d(y_der_1[0].numpy()[:,0]), 
     f"df/dx, rmse={RMSE(data_2d_df_dx_elongated_y, to_2d(y_der_1[0].numpy()[:,0])):.10f}\n"
     f"mse={RMSE(data_2d_df_dx_elongated_y, to_2d(y_der_1[0].numpy()[:,0]), False):.10f}")
plt.subplot(233)
plot(X, Y, to_2d(y_der_1[0].numpy()[:,1]), 
     f"df/dy, rmse={RMSE(data_2d_df_dy_elongated_y, to_2d(y_der_1[0].numpy()[:,1])):.10f}\n"
     f"mse={RMSE(data_2d_df_dy_elongated_y, to_2d(y_der_1[0].numpy()[:,1]),False):.10f}")
plt.subplot(234)
plot(X, Y, to_2d(y_der_2[0].numpy()[:,0]), 
     f"d2f/dx2, rmse={RMSE(data_2d_d2f_dx2_elongated_y, to_2d(y_der_2[0].numpy()[:,0])):.10f}\n"
    f"mse={RMSE(data_2d_d2f_dx2_elongated_y, to_2d(y_der_2[0].numpy()[:,0]),False):.10f}")
plt.subplot(235)
plot(X, Y, to_2d(y_der_2[0].numpy()[:,1]), 
     f"d2f/dy2, rmse={RMSE(data_2d_d2f_dy2_elongated_y, to_2d(y_der_2[0].numpy()[:,1])):.10f}\n"
    f"mse={RMSE(data_2d_d2f_dy2_elongated_y, to_2d(y_der_2[0].numpy()[:,1]),False):.10f}")
plt.tight_layout()
plt.show()
